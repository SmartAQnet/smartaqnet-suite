# %%
from __future__ import print_function
import sqlite3
import paho.mqtt.client as mqtt
import csv
import datetime
import os
import json
import requests
import sys
from kafka import KafkaProducer
from kafka import SimpleProducer, KafkaClient
#basepath = '/root/sftp/volumes/saqn/

# %%
smartaqnetHome = 'smartaqnet-dev.teco.edu'

#smartaqnetHome = 'smartaqnet-dev.teco.edu'
#smartaqnetHome = 'localhost'

def on_connect(client, userdata, flags, rc):
     print('Starting to log data.')
     client.subscribe("v1.0/Things")
     client.subscribe("v1.0/Datastreams")
     client.subscribe("v1.0/Locations")
     client.subscribe("v1.0/HistoricalLocations")
     client.subscribe("v1.0/Sensors")
     client.subscribe("v1.0/ObservedProperties")
     client.subscribe("v1.0/FeaturesOfInterest")
     client.subscribe("v1.0/Observations")

     if rc==0:
        print('connection established')

     else:
        print('Bad connection (return code = %d).' % rc)

def on_message(client, userdata, msg):
    payload = msg.payload
    topic = msg.topic.split('/')[-1]

    print("Receiving new message with topic: " + topic)
    print(topic)
    print(payload)

    data = json.loads(payload.decode("utf-8"))

    iot_id = data.get('@iot.id')
    print(iot_id)
    producer.send(topic, key= str(iot_id), value=msg.payload)
    producer.flush()

# %%
kafka = KafkaClient( smartaqnetHome +':9092')

#producer = SimpleProducer(kafka, async=True)
#producer.send_messages(b'my-topic', b'async message')
producer = KafkaProducer(bootstrap_servers=smartaqnetHome + ':9092',value_serializer=lambda v: json.dumps(v).encode('utf-8'), compression_type='gzip')

#producer.send('fizzbuzz', key= 'uid', value={'foo': 'bar'})
client = mqtt.Client()
client.on_connect = on_connect
client.on_message = on_message

client.connect(smartaqnetHome, 1883, 60)
client.loop_forever()
# Out:
# Starting to log data.
# connection established
# Receiving new message with topic: Observations
# Observations
# {
#   "phenomenonTime" : "2017-02-07T18:02:00.000Z",
#   "resultTime" : "2017-02-07T18:02:05.000Z",
#   "result" : "1.8",
#   "Datastream@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('2b22bdaa-54f7-11e8-a120-4f0e65e3bb06')/Datastream",
#   "Datastream" : {
#     "unitOfMeasurement" : {
#       "name" : null,
#       "symbol" : null,
#       "definition" : null
#     },
#     "@iot.id" : "edu.teco.wang/IBADENWR82/Datastreams/Air-Temperature-IBADENWR82"
#   },
#   "FeatureOfInterest@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('2b22bdaa-54f7-11e8-a120-4f0e65e3bb06')/FeatureOfInterest",
#   "FeatureOfInterest" : {
#     "@iot.id" : "2b2136ce-54f7-11e8-a120-ab192bf18719"
#   },
#   "@iot.id" : "2b22bdaa-54f7-11e8-a120-4f0e65e3bb06",
#   "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('2b22bdaa-54f7-11e8-a120-4f0e65e3bb06')"
# }
# 2b22bdaa-54f7-11e8-a120-4f0e65e3bb06
# Receiving new message with topic: Observations
# Observations
# {
#   "phenomenonTime" : "2017-02-07T18:02:00.000Z",
#   "resultTime" : "2017-02-07T18:02:05.000Z",
#   "result" : "1.8",
#   "Datastream@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('992d6a74-54f8-11e8-a120-7703b907fcfa')/Datastream",
#   "Datastream" : {
#     "unitOfMeasurement" : {
#       "name" : null,
#       "symbol" : null,
#       "definition" : null
#     },
#     "@iot.id" : "edu.teco.wang/IBADENWR82/Datastreams/Air-Temperature-IBADENWR82"
#   },
#   "FeatureOfInterest@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('992d6a74-54f8-11e8-a120-7703b907fcfa')/FeatureOfInterest",
#   "FeatureOfInterest" : {
#     "@iot.id" : "2b2136ce-54f7-11e8-a120-ab192bf18719"
#   },
#   "@iot.id" : "992d6a74-54f8-11e8-a120-7703b907fcfa",
#   "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('992d6a74-54f8-11e8-a120-7703b907fcfa')"
# }
# 992d6a74-54f8-11e8-a120-7703b907fcfa
# Receiving new message with topic: Observations
# Observations
# {
#   "phenomenonTime" : "2017-02-07T18:02:00.000Z",
#   "resultTime" : "2017-02-07T18:02:05.000Z",
#   "result" : "1.8",
#   "Datastream@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('99406e44-54f8-11e8-a120-0bed9646fdf7')/Datastream",
#   "Datastream" : {
#     "unitOfMeasurement" : {
#       "name" : null,
#       "symbol" : null,
#       "definition" : null
#     },
#     "@iot.id" : "edu.teco.wang/IBADENWR82/Datastreams/Air-Temperature-IBADENWR82"
#   },
#   "FeatureOfInterest@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('99406e44-54f8-11e8-a120-0bed9646fdf7')/FeatureOfInterest",
#   "FeatureOfInterest" : {
#     "@iot.id" : "2b2136ce-54f7-11e8-a120-ab192bf18719"
#   },
#   "@iot.id" : "99406e44-54f8-11e8-a120-0bed9646fdf7",
#   "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('99406e44-54f8-11e8-a120-0bed9646fdf7')"
# }
# 99406e44-54f8-11e8-a120-0bed9646fdf7
# Receiving new message with topic: Observations
# Observations
# {
#   "phenomenonTime" : "2017-02-07T18:02:00.000Z",
#   "resultTime" : "2017-02-07T18:02:05.000Z",
#   "result" : "2.0",
#   "Datastream@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('9946d2e8-54f8-11e8-a120-4b2522312cbd')/Datastream",
#   "Datastream" : {
#     "unitOfMeasurement" : {
#       "name" : null,
#       "symbol" : null,
#       "definition" : null
#     },
#     "@iot.id" : "edu.teco.wang/IBADENWR82/Datastreams/Air-Temperature-IBADENWR82"
#   },
#   "FeatureOfInterest@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('9946d2e8-54f8-11e8-a120-4b2522312cbd')/FeatureOfInterest",
#   "FeatureOfInterest" : {
#     "@iot.id" : "2b2136ce-54f7-11e8-a120-ab192bf18719"
#   },
#   "@iot.id" : "9946d2e8-54f8-11e8-a120-4b2522312cbd",
#   "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('9946d2e8-54f8-11e8-a120-4b2522312cbd')"
# }
# 9946d2e8-54f8-11e8-a120-4b2522312cbd
# Receiving new message with topic: Observations
# Observations
# {
#   "phenomenonTime" : "2017-02-07T18:02:00.000Z",
#   "resultTime" : "2017-02-07T18:02:05.000Z",
#   "result" : "2.1",
#   "Datastream@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('994a85f0-54f8-11e8-a120-57a9b4741e5f')/Datastream",
#   "Datastream" : {
#     "unitOfMeasurement" : {
#       "name" : null,
#       "symbol" : null,
#       "definition" : null
#     },
#     "@iot.id" : "edu.teco.wang/IBADENWR82/Datastreams/Air-Temperature-IBADENWR82"
#   },
#   "FeatureOfInterest@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('994a85f0-54f8-11e8-a120-57a9b4741e5f')/FeatureOfInterest",
#   "FeatureOfInterest" : {
#     "@iot.id" : "2b2136ce-54f7-11e8-a120-ab192bf18719"
#   },
#   "@iot.id" : "994a85f0-54f8-11e8-a120-57a9b4741e5f",
#   "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('994a85f0-54f8-11e8-a120-57a9b4741e5f')"
# }
# 994a85f0-54f8-11e8-a120-57a9b4741e5f
# Receiving new message with topic: Observations
# Observations
# {
#   "phenomenonTime" : "2017-02-07T18:02:00.000Z",
#   "resultTime" : "2017-02-07T18:02:05.000Z",
#   "result" : "2.4",
#   "Datastream@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('994e9726-54f8-11e8-a120-ff4daf1b277c')/Datastream",
#   "Datastream" : {
#     "unitOfMeasurement" : {
#       "name" : null,
#       "symbol" : null,
#       "definition" : null
#     },
#     "@iot.id" : "edu.teco.wang/IBADENWR82/Datastreams/Air-Temperature-IBADENWR82"
#   },
#   "FeatureOfInterest@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('994e9726-54f8-11e8-a120-ff4daf1b277c')/FeatureOfInterest",
#   "FeatureOfInterest" : {
#     "@iot.id" : "2b2136ce-54f7-11e8-a120-ab192bf18719"
#   },
#   "@iot.id" : "994e9726-54f8-11e8-a120-ff4daf1b277c",
#   "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('994e9726-54f8-11e8-a120-ff4daf1b277c')"
# }
# 994e9726-54f8-11e8-a120-ff4daf1b277c
# Receiving new message with topic: Observations
# Observations
# {
#   "phenomenonTime" : "2017-02-07T18:02:00.000Z",
#   "resultTime" : "2017-02-07T18:02:05.000Z",
#   "result" : "2.6",
#   "Datastream@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('995318aa-54f8-11e8-a120-7b318a76f026')/Datastream",
#   "Datastream" : {
#     "unitOfMeasurement" : {
#       "name" : null,
#       "symbol" : null,
#       "definition" : null
#     },
#     "@iot.id" : "edu.teco.wang/IBADENWR82/Datastreams/Air-Temperature-IBADENWR82"
#   },
#   "FeatureOfInterest@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('995318aa-54f8-11e8-a120-7b318a76f026')/FeatureOfInterest",
#   "FeatureOfInterest" : {
#     "@iot.id" : "2b2136ce-54f7-11e8-a120-ab192bf18719"
#   },
#   "@iot.id" : "995318aa-54f8-11e8-a120-7b318a76f026",
#   "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('995318aa-54f8-11e8-a120-7b318a76f026')"
# }
# 995318aa-54f8-11e8-a120-7b318a76f026
# Receiving new message with topic: Observations
# Observations
# {
#   "phenomenonTime" : "2017-02-07T18:02:00.000Z",
#   "resultTime" : "2017-02-07T18:02:05.000Z",
#   "result" : "2.7",
#   "Datastream@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('9956bb68-54f8-11e8-a120-132dee0cfc01')/Datastream",
#   "Datastream" : {
#     "unitOfMeasurement" : {
#       "name" : null,
#       "symbol" : null,
#       "definition" : null
#     },
#     "@iot.id" : "edu.teco.wang/IBADENWR82/Datastreams/Air-Temperature-IBADENWR82"
#   },
#   "FeatureOfInterest@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('9956bb68-54f8-11e8-a120-132dee0cfc01')/FeatureOfInterest",
#   "FeatureOfInterest" : {
#     "@iot.id" : "2b2136ce-54f7-11e8-a120-ab192bf18719"
#   },
#   "@iot.id" : "9956bb68-54f8-11e8-a120-132dee0cfc01",
#   "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('9956bb68-54f8-11e8-a120-132dee0cfc01')"
# }
# 9956bb68-54f8-11e8-a120-132dee0cfc01
# Receiving new message with topic: Observations
# Observations
# {
#   "phenomenonTime" : "2017-02-07T18:02:00.000Z",
#   "resultTime" : "2017-02-07T18:02:05.000Z",
#   "result" : "2.8",
#   "Datastream@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('995b5d80-54f8-11e8-a120-7f83493cb6e2')/Datastream",
#   "Datastream" : {
#     "unitOfMeasurement" : {
#       "name" : null,
#       "symbol" : null,
#       "definition" : null
#     },
#     "@iot.id" : "edu.teco.wang/IBADENWR82/Datastreams/Air-Temperature-IBADENWR82"
#   },
#   "FeatureOfInterest@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('995b5d80-54f8-11e8-a120-7f83493cb6e2')/FeatureOfInterest",
#   "FeatureOfInterest" : {
#     "@iot.id" : "2b2136ce-54f7-11e8-a120-ab192bf18719"
#   },
#   "@iot.id" : "995b5d80-54f8-11e8-a120-7f83493cb6e2",
#   "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('995b5d80-54f8-11e8-a120-7f83493cb6e2')"
# }
# 995b5d80-54f8-11e8-a120-7f83493cb6e2
# Receiving new message with topic: Observations
# Observations
# {
#   "phenomenonTime" : "2017-02-07T18:02:00.000Z",
#   "resultTime" : "2017-02-07T18:02:05.000Z",
#   "result" : "3.0",
#   "Datastream@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('995ec33a-54f8-11e8-a120-578b0d2d636f')/Datastream",
#   "Datastream" : {
#     "unitOfMeasurement" : {
#       "name" : null,
#       "symbol" : null,
#       "definition" : null
#     },
#     "@iot.id" : "edu.teco.wang/IBADENWR82/Datastreams/Air-Temperature-IBADENWR82"
#   },
#   "FeatureOfInterest@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('995ec33a-54f8-11e8-a120-578b0d2d636f')/FeatureOfInterest",
#   "FeatureOfInterest" : {
#     "@iot.id" : "2b2136ce-54f7-11e8-a120-ab192bf18719"
#   },
#   "@iot.id" : "995ec33a-54f8-11e8-a120-578b0d2d636f",
#   "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('995ec33a-54f8-11e8-a120-578b0d2d636f')"
# }
# 995ec33a-54f8-11e8-a120-578b0d2d636f
# Receiving new message with topic: Observations
# Observations
# {
#   "phenomenonTime" : "2017-02-07T18:02:00.000Z",
#   "resultTime" : "2017-02-07T18:02:05.000Z",
#   "result" : "3.1",
#   "Datastream@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('9962221e-54f8-11e8-a120-1b1fa21402b6')/Datastream",
#   "Datastream" : {
#     "unitOfMeasurement" : {
#       "name" : null,
#       "symbol" : null,
#       "definition" : null
#     },
#     "@iot.id" : "edu.teco.wang/IBADENWR82/Datastreams/Air-Temperature-IBADENWR82"
#   },
#   "FeatureOfInterest@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('9962221e-54f8-11e8-a120-1b1fa21402b6')/FeatureOfInterest",
#   "FeatureOfInterest" : {
#     "@iot.id" : "2b2136ce-54f7-11e8-a120-ab192bf18719"
#   },
#   "@iot.id" : "9962221e-54f8-11e8-a120-1b1fa21402b6",
#   "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('9962221e-54f8-11e8-a120-1b1fa21402b6')"
# }
# 9962221e-54f8-11e8-a120-1b1fa21402b6
# Receiving new message with topic: Observations
# Observations
# {
#   "phenomenonTime" : "2017-02-07T18:02:00.000Z",
#   "resultTime" : "2017-02-07T18:02:05.000Z",
#   "result" : "3.0",
#   "Datastream@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('99662ddc-54f8-11e8-a120-67b7b24942ea')/Datastream",
#   "Datastream" : {
#     "unitOfMeasurement" : {
#       "name" : null,
#       "symbol" : null,
#       "definition" : null
#     },
#     "@iot.id" : "edu.teco.wang/IBADENWR82/Datastreams/Air-Temperature-IBADENWR82"
#   },
#   "FeatureOfInterest@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('99662ddc-54f8-11e8-a120-67b7b24942ea')/FeatureOfInterest",
#   "FeatureOfInterest" : {
#     "@iot.id" : "2b2136ce-54f7-11e8-a120-ab192bf18719"
#   },
#   "@iot.id" : "99662ddc-54f8-11e8-a120-67b7b24942ea",
#   "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('99662ddc-54f8-11e8-a120-67b7b24942ea')"
# }
# 99662ddc-54f8-11e8-a120-67b7b24942ea
# Receiving new message with topic: Observations
# Observations
# {
#   "phenomenonTime" : "2017-02-07T18:02:00.000Z",
#   "resultTime" : "2017-02-07T18:02:05.000Z",
#   "result" : "3.2",
#   "Datastream@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('996af074-54f8-11e8-a120-8fdb1666a7df')/Datastream",
#   "Datastream" : {
#     "unitOfMeasurement" : {
#       "name" : null,
#       "symbol" : null,
#       "definition" : null
#     },
#     "@iot.id" : "edu.teco.wang/IBADENWR82/Datastreams/Air-Temperature-IBADENWR82"
#   },
#   "FeatureOfInterest@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('996af074-54f8-11e8-a120-8fdb1666a7df')/FeatureOfInterest",
#   "FeatureOfInterest" : {
#     "@iot.id" : "2b2136ce-54f7-11e8-a120-ab192bf18719"
#   },
#   "@iot.id" : "996af074-54f8-11e8-a120-8fdb1666a7df",
#   "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('996af074-54f8-11e8-a120-8fdb1666a7df')"
# }
# 996af074-54f8-11e8-a120-8fdb1666a7df
# Receiving new message with topic: Observations
# Observations
# {
#   "phenomenonTime" : "2017-02-07T18:02:00.000Z",
#   "resultTime" : "2017-02-07T18:02:05.000Z",
#   "result" : "3.7",
#   "Datastream@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('997363c6-54f8-11e8-a120-377d735c6972')/Datastream",
#   "Datastream" : {
#     "unitOfMeasurement" : {
#       "name" : null,
#       "symbol" : null,
#       "definition" : null
#     },
#     "@iot.id" : "edu.teco.wang/IBADENWR82/Datastreams/Air-Temperature-IBADENWR82"
#   },
#   "FeatureOfInterest@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('997363c6-54f8-11e8-a120-377d735c6972')/FeatureOfInterest",
#   "FeatureOfInterest" : {
#     "@iot.id" : "2b2136ce-54f7-11e8-a120-ab192bf18719"
#   },
#   "@iot.id" : "997363c6-54f8-11e8-a120-377d735c6972",
#   "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('997363c6-54f8-11e8-a120-377d735c6972')"
# }
# 997363c6-54f8-11e8-a120-377d735c6972
# Receiving new message with topic: Observations
# Observations
# {
#   "phenomenonTime" : "2017-02-07T18:02:00.000Z",
#   "resultTime" : "2017-02-07T18:02:05.000Z",
#   "result" : "4.1",
#   "Datastream@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('997d3d60-54f8-11e8-a120-071051202eed')/Datastream",
#   "Datastream" : {
#     "unitOfMeasurement" : {
#       "name" : null,
#       "symbol" : null,
#       "definition" : null
#     },
#     "@iot.id" : "edu.teco.wang/IBADENWR82/Datastreams/Air-Temperature-IBADENWR82"
#   },
#   "FeatureOfInterest@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('997d3d60-54f8-11e8-a120-071051202eed')/FeatureOfInterest",
#   "FeatureOfInterest" : {
#     "@iot.id" : "2b2136ce-54f7-11e8-a120-ab192bf18719"
#   },
#   "@iot.id" : "997d3d60-54f8-11e8-a120-071051202eed",
#   "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('997d3d60-54f8-11e8-a120-071051202eed')"
# }
# 997d3d60-54f8-11e8-a120-071051202eed
# Receiving new message with topic: Observations
# Observations
# {
#   "phenomenonTime" : "2017-02-07T18:02:00.000Z",
#   "resultTime" : "2017-02-07T18:02:05.000Z",
#   "result" : "4.8",
#   "Datastream@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('9980f23e-54f8-11e8-a120-7b3148418852')/Datastream",
#   "Datastream" : {
#     "unitOfMeasurement" : {
#       "name" : null,
#       "symbol" : null,
#       "definition" : null
#     },
#     "@iot.id" : "edu.teco.wang/IBADENWR82/Datastreams/Air-Temperature-IBADENWR82"
#   },
#   "FeatureOfInterest@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('9980f23e-54f8-11e8-a120-7b3148418852')/FeatureOfInterest",
#   "FeatureOfInterest" : {
#     "@iot.id" : "2b2136ce-54f7-11e8-a120-ab192bf18719"
#   },
#   "@iot.id" : "9980f23e-54f8-11e8-a120-7b3148418852",
#   "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('9980f23e-54f8-11e8-a120-7b3148418852')"
# }
# 9980f23e-54f8-11e8-a120-7b3148418852
# Receiving new message with topic: Observations
# Observations
# {
#   "phenomenonTime" : "2017-02-07T18:02:00.000Z",
#   "resultTime" : "2017-02-07T18:02:05.000Z",
#   "result" : "5.3",
#   "Datastream@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('99846464-54f8-11e8-a120-2f80e7fb29cc')/Datastream",
#   "Datastream" : {
#     "unitOfMeasurement" : {
#       "name" : null,
#       "symbol" : null,
#       "definition" : null
#     },
#     "@iot.id" : "edu.teco.wang/IBADENWR82/Datastreams/Air-Temperature-IBADENWR82"
#   },
#   "FeatureOfInterest@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('99846464-54f8-11e8-a120-2f80e7fb29cc')/FeatureOfInterest",
#   "FeatureOfInterest" : {
#     "@iot.id" : "2b2136ce-54f7-11e8-a120-ab192bf18719"
#   },
#   "@iot.id" : "99846464-54f8-11e8-a120-2f80e7fb29cc",
#   "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('99846464-54f8-11e8-a120-2f80e7fb29cc')"
# }
# 99846464-54f8-11e8-a120-2f80e7fb29cc
# Receiving new message with topic: Observations
# Observations
# {
#   "phenomenonTime" : "2017-02-07T18:02:00.000Z",
#   "resultTime" : "2017-02-07T18:02:05.000Z",
#   "result" : "5.7",
#   "Datastream@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('9987ee0e-54f8-11e8-a120-5fa7218ba919')/Datastream",
#   "Datastream" : {
#     "unitOfMeasurement" : {
#       "name" : null,
#       "symbol" : null,
#       "definition" : null
#     },
#     "@iot.id" : "edu.teco.wang/IBADENWR82/Datastreams/Air-Temperature-IBADENWR82"
#   },
#   "FeatureOfInterest@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('9987ee0e-54f8-11e8-a120-5fa7218ba919')/FeatureOfInterest",
#   "FeatureOfInterest" : {
#     "@iot.id" : "2b2136ce-54f7-11e8-a120-ab192bf18719"
#   },
#   "@iot.id" : "9987ee0e-54f8-11e8-a120-5fa7218ba919",
#   "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('9987ee0e-54f8-11e8-a120-5fa7218ba919')"
# }
# 9987ee0e-54f8-11e8-a120-5fa7218ba919
# Receiving new message with topic: Observations
# Observations
# {
#   "phenomenonTime" : "2017-02-07T18:02:00.000Z",
#   "resultTime" : "2017-02-07T18:02:05.000Z",
#   "result" : "6.2",
#   "Datastream@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('998b5314-54f8-11e8-a120-b31b8a4e7043')/Datastream",
#   "Datastream" : {
#     "unitOfMeasurement" : {
#       "name" : null,
#       "symbol" : null,
#       "definition" : null
#     },
#     "@iot.id" : "edu.teco.wang/IBADENWR82/Datastreams/Air-Temperature-IBADENWR82"
#   },
#   "FeatureOfInterest@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('998b5314-54f8-11e8-a120-b31b8a4e7043')/FeatureOfInterest",
#   "FeatureOfInterest" : {
#     "@iot.id" : "2b2136ce-54f7-11e8-a120-ab192bf18719"
#   },
#   "@iot.id" : "998b5314-54f8-11e8-a120-b31b8a4e7043",
#   "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('998b5314-54f8-11e8-a120-b31b8a4e7043')"
# }
# 998b5314-54f8-11e8-a120-b31b8a4e7043
# Receiving new message with topic: Observations
# Observations
# {
#   "phenomenonTime" : "2017-02-07T18:02:00.000Z",
#   "resultTime" : "2017-02-07T18:02:05.000Z",
#   "result" : "6.9",
#   "Datastream@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('998f3efc-54f8-11e8-a120-c73cc02f2dd8')/Datastream",
#   "Datastream" : {
#     "unitOfMeasurement" : {
#       "name" : null,
#       "symbol" : null,
#       "definition" : null
#     },
#     "@iot.id" : "edu.teco.wang/IBADENWR82/Datastreams/Air-Temperature-IBADENWR82"
#   },
#   "FeatureOfInterest@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('998f3efc-54f8-11e8-a120-c73cc02f2dd8')/FeatureOfInterest",
#   "FeatureOfInterest" : {
#     "@iot.id" : "2b2136ce-54f7-11e8-a120-ab192bf18719"
#   },
#   "@iot.id" : "998f3efc-54f8-11e8-a120-c73cc02f2dd8",
#   "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('998f3efc-54f8-11e8-a120-c73cc02f2dd8')"
# }
# 998f3efc-54f8-11e8-a120-c73cc02f2dd8
# Receiving new message with topic: Observations
# Observations
# {
#   "phenomenonTime" : "2017-02-07T18:02:00.000Z",
#   "resultTime" : "2017-02-07T18:02:05.000Z",
#   "result" : "7.2",
#   "Datastream@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('9992ad58-54f8-11e8-a120-5341d0338f41')/Datastream",
#   "Datastream" : {
#     "unitOfMeasurement" : {
#       "name" : null,
#       "symbol" : null,
#       "definition" : null
#     },
#     "@iot.id" : "edu.teco.wang/IBADENWR82/Datastreams/Air-Temperature-IBADENWR82"
#   },
#   "FeatureOfInterest@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('9992ad58-54f8-11e8-a120-5341d0338f41')/FeatureOfInterest",
#   "FeatureOfInterest" : {
#     "@iot.id" : "2b2136ce-54f7-11e8-a120-ab192bf18719"
#   },
#   "@iot.id" : "9992ad58-54f8-11e8-a120-5341d0338f41",
#   "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('9992ad58-54f8-11e8-a120-5341d0338f41')"
# }
# 9992ad58-54f8-11e8-a120-5341d0338f41
# Receiving new message with topic: Observations
# Observations
# {
#   "phenomenonTime" : "2017-02-07T18:02:00.000Z",
#   "resultTime" : "2017-02-07T18:02:05.000Z",
#   "result" : "7.3",
#   "Datastream@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('999605e8-54f8-11e8-a120-573aafe1a7e5')/Datastream",
#   "Datastream" : {
#     "unitOfMeasurement" : {
#       "name" : null,
#       "symbol" : null,
#       "definition" : null
#     },
#     "@iot.id" : "edu.teco.wang/IBADENWR82/Datastreams/Air-Temperature-IBADENWR82"
#   },
#   "FeatureOfInterest@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('999605e8-54f8-11e8-a120-573aafe1a7e5')/FeatureOfInterest",
#   "FeatureOfInterest" : {
#     "@iot.id" : "2b2136ce-54f7-11e8-a120-ab192bf18719"
#   },
#   "@iot.id" : "999605e8-54f8-11e8-a120-573aafe1a7e5",
#   "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('999605e8-54f8-11e8-a120-573aafe1a7e5')"
# }
# 999605e8-54f8-11e8-a120-573aafe1a7e5
# Receiving new message with topic: Observations
# Observations
# {
#   "phenomenonTime" : "2017-02-07T18:02:00.000Z",
#   "resultTime" : "2017-02-07T18:02:05.000Z",
#   "result" : "7.2",
#   "Datastream@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('999a5666-54f8-11e8-a120-93cab25de1fe')/Datastream",
#   "Datastream" : {
#     "unitOfMeasurement" : {
#       "name" : null,
#       "symbol" : null,
#       "definition" : null
#     },
#     "@iot.id" : "edu.teco.wang/IBADENWR82/Datastreams/Air-Temperature-IBADENWR82"
#   },
#   "FeatureOfInterest@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('999a5666-54f8-11e8-a120-93cab25de1fe')/FeatureOfInterest",
#   "FeatureOfInterest" : {
#     "@iot.id" : "2b2136ce-54f7-11e8-a120-ab192bf18719"
#   },
#   "@iot.id" : "999a5666-54f8-11e8-a120-93cab25de1fe",
#   "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('999a5666-54f8-11e8-a120-93cab25de1fe')"
# }
# 999a5666-54f8-11e8-a120-93cab25de1fe
# Receiving new message with topic: Observations
# Observations
# {
#   "phenomenonTime" : "2017-02-07T18:02:00.000Z",
#   "resultTime" : "2017-02-07T18:02:05.000Z",
#   "result" : "7.1",
#   "Datastream@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('999d862e-54f8-11e8-a120-034fff3b7ad2')/Datastream",
#   "Datastream" : {
#     "unitOfMeasurement" : {
#       "name" : null,
#       "symbol" : null,
#       "definition" : null
#     },
#     "@iot.id" : "edu.teco.wang/IBADENWR82/Datastreams/Air-Temperature-IBADENWR82"
#   },
#   "FeatureOfInterest@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('999d862e-54f8-11e8-a120-034fff3b7ad2')/FeatureOfInterest",
#   "FeatureOfInterest" : {
#     "@iot.id" : "2b2136ce-54f7-11e8-a120-ab192bf18719"
#   },
#   "@iot.id" : "999d862e-54f8-11e8-a120-034fff3b7ad2",
#   "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('999d862e-54f8-11e8-a120-034fff3b7ad2')"
# }
# 999d862e-54f8-11e8-a120-034fff3b7ad2
# Receiving new message with topic: Observations
# Observations
# {
#   "phenomenonTime" : "2017-02-07T18:02:00.000Z",
#   "resultTime" : "2017-02-07T18:02:05.000Z",
#   "result" : "4.9",
#   "Datastream@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('99a18f30-54f8-11e8-a120-db229c9230ef')/Datastream",
#   "Datastream" : {
#     "unitOfMeasurement" : {
#       "name" : null,
#       "symbol" : null,
#       "definition" : null
#     },
#     "@iot.id" : "edu.teco.wang/IBADENWR82/Datastreams/Air-Temperature-IBADENWR82"
#   },
#   "FeatureOfInterest@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('99a18f30-54f8-11e8-a120-db229c9230ef')/FeatureOfInterest",
#   "FeatureOfInterest" : {
#     "@iot.id" : "2b2136ce-54f7-11e8-a120-ab192bf18719"
#   },
#   "@iot.id" : "99a18f30-54f8-11e8-a120-db229c9230ef",
#   "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('99a18f30-54f8-11e8-a120-db229c9230ef')"
# }
# 99a18f30-54f8-11e8-a120-db229c9230ef
# Receiving new message with topic: Observations
# Observations
# {
#   "phenomenonTime" : "2017-02-07T18:02:00.000Z",
#   "resultTime" : "2017-02-07T18:02:05.000Z",
#   "result" : "3.4",
#   "Datastream@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('99a4567a-54f8-11e8-a120-b7d06b5973ae')/Datastream",
#   "Datastream" : {
#     "unitOfMeasurement" : {
#       "name" : null,
#       "symbol" : null,
#       "definition" : null
#     },
#     "@iot.id" : "edu.teco.wang/IBADENWR82/Datastreams/Air-Temperature-IBADENWR82"
#   },
#   "FeatureOfInterest@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('99a4567a-54f8-11e8-a120-b7d06b5973ae')/FeatureOfInterest",
#   "FeatureOfInterest" : {
#     "@iot.id" : "2b2136ce-54f7-11e8-a120-ab192bf18719"
#   },
#   "@iot.id" : "99a4567a-54f8-11e8-a120-b7d06b5973ae",
#   "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('99a4567a-54f8-11e8-a120-b7d06b5973ae')"
# }
# 99a4567a-54f8-11e8-a120-b7d06b5973ae
# Receiving new message with topic: Observations
# Observations
# {
#   "phenomenonTime" : "2017-02-07T18:02:00.000Z",
#   "resultTime" : "2017-02-07T18:02:05.000Z",
#   "result" : "2.4",
#   "Datastream@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('99a7fb36-54f8-11e8-a120-3f6a42c488d8')/Datastream",
#   "Datastream" : {
#     "unitOfMeasurement" : {
#       "name" : null,
#       "symbol" : null,
#       "definition" : null
#     },
#     "@iot.id" : "edu.teco.wang/IBADENWR82/Datastreams/Air-Temperature-IBADENWR82"
#   },
#   "FeatureOfInterest@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('99a7fb36-54f8-11e8-a120-3f6a42c488d8')/FeatureOfInterest",
#   "FeatureOfInterest" : {
#     "@iot.id" : "2b2136ce-54f7-11e8-a120-ab192bf18719"
#   },
#   "@iot.id" : "99a7fb36-54f8-11e8-a120-3f6a42c488d8",
#   "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('99a7fb36-54f8-11e8-a120-3f6a42c488d8')"
# }
# 99a7fb36-54f8-11e8-a120-3f6a42c488d8
# Receiving new message with topic: Observations
# Observations
# {
#   "phenomenonTime" : "2017-02-07T18:02:00.000Z",
#   "resultTime" : "2017-02-07T18:02:05.000Z",
#   "result" : "1.9",
#   "Datastream@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('99aa5c64-54f8-11e8-a120-03a977b456f5')/Datastream",
#   "Datastream" : {
#     "unitOfMeasurement" : {
#       "name" : null,
#       "symbol" : null,
#       "definition" : null
#     },
#     "@iot.id" : "edu.teco.wang/IBADENWR82/Datastreams/Air-Temperature-IBADENWR82"
#   },
#   "FeatureOfInterest@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('99aa5c64-54f8-11e8-a120-03a977b456f5')/FeatureOfInterest",
#   "FeatureOfInterest" : {
#     "@iot.id" : "2b2136ce-54f7-11e8-a120-ab192bf18719"
#   },
#   "@iot.id" : "99aa5c64-54f8-11e8-a120-03a977b456f5",
#   "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('99aa5c64-54f8-11e8-a120-03a977b456f5')"
# }
# 99aa5c64-54f8-11e8-a120-03a977b456f5
# Receiving new message with topic: Observations
# Observations
# {
#   "phenomenonTime" : "2017-02-07T18:02:00.000Z",
#   "resultTime" : "2017-02-07T18:02:05.000Z",
#   "result" : "2.0",
#   "Datastream@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('99ad257a-54f8-11e8-a120-7be2e2886c4f')/Datastream",
#   "Datastream" : {
#     "unitOfMeasurement" : {
#       "name" : null,
#       "symbol" : null,
#       "definition" : null
#     },
#     "@iot.id" : "edu.teco.wang/IBADENWR82/Datastreams/Air-Temperature-IBADENWR82"
#   },
#   "FeatureOfInterest@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('99ad257a-54f8-11e8-a120-7be2e2886c4f')/FeatureOfInterest",
#   "FeatureOfInterest" : {
#     "@iot.id" : "2b2136ce-54f7-11e8-a120-ab192bf18719"
#   },
#   "@iot.id" : "99ad257a-54f8-11e8-a120-7be2e2886c4f",
#   "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('99ad257a-54f8-11e8-a120-7be2e2886c4f')"
# }
# 99ad257a-54f8-11e8-a120-7be2e2886c4f
# Receiving new message with topic: Observations
# Observations
# {
#   "phenomenonTime" : "2017-02-07T18:02:00.000Z",
#   "resultTime" : "2017-02-07T18:02:05.000Z",
#   "result" : "2.1",
#   "Datastream@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('99b0f498-54f8-11e8-a120-a30d51ef8366')/Datastream",
#   "Datastream" : {
#     "unitOfMeasurement" : {
#       "name" : null,
#       "symbol" : null,
#       "definition" : null
#     },
#     "@iot.id" : "edu.teco.wang/IBADENWR82/Datastreams/Air-Temperature-IBADENWR82"
#   },
#   "FeatureOfInterest@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('99b0f498-54f8-11e8-a120-a30d51ef8366')/FeatureOfInterest",
#   "FeatureOfInterest" : {
#     "@iot.id" : "2b2136ce-54f7-11e8-a120-ab192bf18719"
#   },
#   "@iot.id" : "99b0f498-54f8-11e8-a120-a30d51ef8366",
#   "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('99b0f498-54f8-11e8-a120-a30d51ef8366')"
# }
# 99b0f498-54f8-11e8-a120-a30d51ef8366
# Receiving new message with topic: Observations
# Observations
# {
#   "phenomenonTime" : "2017-02-07T18:02:00.000Z",
#   "resultTime" : "2017-02-07T18:02:05.000Z",
#   "result" : "1.9",
#   "Datastream@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('99b4a2d2-54f8-11e8-a120-3bec03b77c86')/Datastream",
#   "Datastream" : {
#     "unitOfMeasurement" : {
#       "name" : null,
#       "symbol" : null,
#       "definition" : null
#     },
#     "@iot.id" : "edu.teco.wang/IBADENWR82/Datastreams/Air-Temperature-IBADENWR82"
#   },
#   "FeatureOfInterest@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('99b4a2d2-54f8-11e8-a120-3bec03b77c86')/FeatureOfInterest",
#   "FeatureOfInterest" : {
#     "@iot.id" : "2b2136ce-54f7-11e8-a120-ab192bf18719"
#   },
#   "@iot.id" : "99b4a2d2-54f8-11e8-a120-3bec03b77c86",
#   "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('99b4a2d2-54f8-11e8-a120-3bec03b77c86')"
# }
# 99b4a2d2-54f8-11e8-a120-3bec03b77c86
# Receiving new message with topic: Observations
# Observations
# {
#   "phenomenonTime" : "2017-02-07T18:02:00.000Z",
#   "resultTime" : "2017-02-07T18:02:05.000Z",
#   "result" : "1.8",
#   "Datastream@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('99b82150-54f8-11e8-a120-5f08427872ec')/Datastream",
#   "Datastream" : {
#     "unitOfMeasurement" : {
#       "name" : null,
#       "symbol" : null,
#       "definition" : null
#     },
#     "@iot.id" : "edu.teco.wang/IBADENWR82/Datastreams/Air-Temperature-IBADENWR82"
#   },
#   "FeatureOfInterest@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('99b82150-54f8-11e8-a120-5f08427872ec')/FeatureOfInterest",
#   "FeatureOfInterest" : {
#     "@iot.id" : "2b2136ce-54f7-11e8-a120-ab192bf18719"
#   },
#   "@iot.id" : "99b82150-54f8-11e8-a120-5f08427872ec",
#   "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('99b82150-54f8-11e8-a120-5f08427872ec')"
# }
# 99b82150-54f8-11e8-a120-5f08427872ec
# Receiving new message with topic: Observations
# Observations
# {
#   "phenomenonTime" : "2017-02-07T18:02:00.000Z",
#   "resultTime" : "2017-02-07T18:02:05.000Z",
#   "result" : "1.6",
#   "Datastream@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('99babbb8-54f8-11e8-a120-6b97a9194085')/Datastream",
#   "Datastream" : {
#     "unitOfMeasurement" : {
#       "name" : null,
#       "symbol" : null,
#       "definition" : null
#     },
#     "@iot.id" : "edu.teco.wang/IBADENWR82/Datastreams/Air-Temperature-IBADENWR82"
#   },
#   "FeatureOfInterest@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('99babbb8-54f8-11e8-a120-6b97a9194085')/FeatureOfInterest",
#   "FeatureOfInterest" : {
#     "@iot.id" : "2b2136ce-54f7-11e8-a120-ab192bf18719"
#   },
#   "@iot.id" : "99babbb8-54f8-11e8-a120-6b97a9194085",
#   "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('99babbb8-54f8-11e8-a120-6b97a9194085')"
# }
# 99babbb8-54f8-11e8-a120-6b97a9194085
# Receiving new message with topic: Observations
# Observations
# {
#   "phenomenonTime" : "2017-02-07T18:02:00.000Z",
#   "resultTime" : "2017-02-07T18:02:05.000Z",
#   "result" : "1.5",
#   "Datastream@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('99bd7218-54f8-11e8-a120-67c608cc053a')/Datastream",
#   "Datastream" : {
#     "unitOfMeasurement" : {
#       "name" : null,
#       "symbol" : null,
#       "definition" : null
#     },
#     "@iot.id" : "edu.teco.wang/IBADENWR82/Datastreams/Air-Temperature-IBADENWR82"
#   },
#   "FeatureOfInterest@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('99bd7218-54f8-11e8-a120-67c608cc053a')/FeatureOfInterest",
#   "FeatureOfInterest" : {
#     "@iot.id" : "2b2136ce-54f7-11e8-a120-ab192bf18719"
#   },
#   "@iot.id" : "99bd7218-54f8-11e8-a120-67c608cc053a",
#   "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('99bd7218-54f8-11e8-a120-67c608cc053a')"
# }
# 99bd7218-54f8-11e8-a120-67c608cc053a
# Receiving new message with topic: Observations
# Observations
# {
#   "phenomenonTime" : "2017-02-07T18:02:00.000Z",
#   "resultTime" : "2017-02-07T18:02:05.000Z",
#   "result" : "1.3",
#   "Datastream@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('99c056a4-54f8-11e8-a120-0bdd80e6857e')/Datastream",
#   "Datastream" : {
#     "unitOfMeasurement" : {
#       "name" : null,
#       "symbol" : null,
#       "definition" : null
#     },
#     "@iot.id" : "edu.teco.wang/IBADENWR82/Datastreams/Air-Temperature-IBADENWR82"
#   },
#   "FeatureOfInterest@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('99c056a4-54f8-11e8-a120-0bdd80e6857e')/FeatureOfInterest",
#   "FeatureOfInterest" : {
#     "@iot.id" : "2b2136ce-54f7-11e8-a120-ab192bf18719"
#   },
#   "@iot.id" : "99c056a4-54f8-11e8-a120-0bdd80e6857e",
#   "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('99c056a4-54f8-11e8-a120-0bdd80e6857e')"
# }
# 99c056a4-54f8-11e8-a120-0bdd80e6857e
# Receiving new message with topic: Observations
# Observations
# {
#   "phenomenonTime" : "2017-02-07T18:02:00.000Z",
#   "resultTime" : "2017-02-07T18:02:05.000Z",
#   "result" : "1.3",
#   "Datastream@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('99c3a0a2-54f8-11e8-a120-2f8c7766ad58')/Datastream",
#   "Datastream" : {
#     "unitOfMeasurement" : {
#       "name" : null,
#       "symbol" : null,
#       "definition" : null
#     },
#     "@iot.id" : "edu.teco.wang/IBADENWR82/Datastreams/Air-Temperature-IBADENWR82"
#   },
#   "FeatureOfInterest@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('99c3a0a2-54f8-11e8-a120-2f8c7766ad58')/FeatureOfInterest",
#   "FeatureOfInterest" : {
#     "@iot.id" : "2b2136ce-54f7-11e8-a120-ab192bf18719"
#   },
#   "@iot.id" : "99c3a0a2-54f8-11e8-a120-2f8c7766ad58",
#   "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('99c3a0a2-54f8-11e8-a120-2f8c7766ad58')"
# }
# 99c3a0a2-54f8-11e8-a120-2f8c7766ad58
# Receiving new message with topic: Observations
# Observations
# {
#   "phenomenonTime" : "2016-03-01T22:00:00.000Z",
#   "resultTime" : "2016-03-01T22:00:00.000Z",
#   "result" : "1.8",
#   "Datastream@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('c62c6f4c-54f9-11e8-a120-a38effb66126')/Datastream",
#   "Datastream" : {
#     "unitOfMeasurement" : {
#       "name" : null,
#       "symbol" : null,
#       "definition" : null
#     },
#     "@iot.id" : "edu.teco.wang/IBADENWR82/Datastreams/Air-Temperature-IBADENWR82"
#   },
#   "FeatureOfInterest@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('c62c6f4c-54f9-11e8-a120-a38effb66126')/FeatureOfInterest",
#   "FeatureOfInterest" : {
#     "@iot.id" : "2b2136ce-54f7-11e8-a120-ab192bf18719"
#   },
#   "@iot.id" : "c62c6f4c-54f9-11e8-a120-a38effb66126",
#   "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('c62c6f4c-54f9-11e8-a120-a38effb66126')"
# }
# c62c6f4c-54f9-11e8-a120-a38effb66126
# Receiving new message with topic: Observations
# Observations
# {
#   "phenomenonTime" : "2016-03-01T22:50:00.000Z",
#   "resultTime" : "2016-03-01T22:50:00.000Z",
#   "result" : "1.8",
#   "Datastream@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('c63704d4-54f9-11e8-a120-833e876e6890')/Datastream",
#   "Datastream" : {
#     "unitOfMeasurement" : {
#       "name" : null,
#       "symbol" : null,
#       "definition" : null
#     },
#     "@iot.id" : "edu.teco.wang/IBADENWR82/Datastreams/Air-Temperature-IBADENWR82"
#   },
#   "FeatureOfInterest@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('c63704d4-54f9-11e8-a120-833e876e6890')/FeatureOfInterest",
#   "FeatureOfInterest" : {
#     "@iot.id" : "2b2136ce-54f7-11e8-a120-ab192bf18719"
#   },
#   "@iot.id" : "c63704d4-54f9-11e8-a120-833e876e6890",
#   "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('c63704d4-54f9-11e8-a120-833e876e6890')"
# }
# c63704d4-54f9-11e8-a120-833e876e6890
# Receiving new message with topic: Observations
# Observations
# {
#   "phenomenonTime" : "2016-03-01T23:30:00.000Z",
#   "resultTime" : "2016-03-01T23:30:00.000Z",
#   "result" : "2.0",
#   "Datastream@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('c63c3616-54f9-11e8-a120-e3baddcdd003')/Datastream",
#   "Datastream" : {
#     "unitOfMeasurement" : {
#       "name" : null,
#       "symbol" : null,
#       "definition" : null
#     },
#     "@iot.id" : "edu.teco.wang/IBADENWR82/Datastreams/Air-Temperature-IBADENWR82"
#   },
#   "FeatureOfInterest@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('c63c3616-54f9-11e8-a120-e3baddcdd003')/FeatureOfInterest",
#   "FeatureOfInterest" : {
#     "@iot.id" : "2b2136ce-54f7-11e8-a120-ab192bf18719"
#   },
#   "@iot.id" : "c63c3616-54f9-11e8-a120-e3baddcdd003",
#   "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('c63c3616-54f9-11e8-a120-e3baddcdd003')"
# }
# c63c3616-54f9-11e8-a120-e3baddcdd003
# Receiving new message with topic: Observations
# Observations
# {
#   "phenomenonTime" : "2016-03-02T00:10:00.000Z",
#   "resultTime" : "2016-03-02T00:10:00.000Z",
#   "result" : "2.1",
#   "Datastream@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('c6414a52-54f9-11e8-a120-5fe9a4698870')/Datastream",
#   "Datastream" : {
#     "unitOfMeasurement" : {
#       "name" : null,
#       "symbol" : null,
#       "definition" : null
#     },
#     "@iot.id" : "edu.teco.wang/IBADENWR82/Datastreams/Air-Temperature-IBADENWR82"
#   },
#   "FeatureOfInterest@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('c6414a52-54f9-11e8-a120-5fe9a4698870')/FeatureOfInterest",
#   "FeatureOfInterest" : {
#     "@iot.id" : "2b2136ce-54f7-11e8-a120-ab192bf18719"
#   },
#   "@iot.id" : "c6414a52-54f9-11e8-a120-5fe9a4698870",
#   "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('c6414a52-54f9-11e8-a120-5fe9a4698870')"
# }
# c6414a52-54f9-11e8-a120-5fe9a4698870
# Receiving new message with topic: Observations
# Observations
# {
#   "phenomenonTime" : "2016-03-02T00:55:00.000Z",
#   "resultTime" : "2016-03-02T00:55:00.000Z",
#   "result" : "2.4",
#   "Datastream@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('c644b386-54f9-11e8-a120-ab95ada1cd16')/Datastream",
#   "Datastream" : {
#     "unitOfMeasurement" : {
#       "name" : null,
#       "symbol" : null,
#       "definition" : null
#     },
#     "@iot.id" : "edu.teco.wang/IBADENWR82/Datastreams/Air-Temperature-IBADENWR82"
#   },
#   "FeatureOfInterest@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('c644b386-54f9-11e8-a120-ab95ada1cd16')/FeatureOfInterest",
#   "FeatureOfInterest" : {
#     "@iot.id" : "2b2136ce-54f7-11e8-a120-ab192bf18719"
#   },
#   "@iot.id" : "c644b386-54f9-11e8-a120-ab95ada1cd16",
#   "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('c644b386-54f9-11e8-a120-ab95ada1cd16')"
# }
# c644b386-54f9-11e8-a120-ab95ada1cd16
# Receiving new message with topic: Observations
# Observations
# {
#   "phenomenonTime" : "2016-03-02T01:40:00.000Z",
#   "resultTime" : "2016-03-02T01:40:00.000Z",
#   "result" : "2.6",
#   "Datastream@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('c6487ab6-54f9-11e8-a120-2fe1351d6558')/Datastream",
#   "Datastream" : {
#     "unitOfMeasurement" : {
#       "name" : null,
#       "symbol" : null,
#       "definition" : null
#     },
#     "@iot.id" : "edu.teco.wang/IBADENWR82/Datastreams/Air-Temperature-IBADENWR82"
#   },
#   "FeatureOfInterest@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('c6487ab6-54f9-11e8-a120-2fe1351d6558')/FeatureOfInterest",
#   "FeatureOfInterest" : {
#     "@iot.id" : "2b2136ce-54f7-11e8-a120-ab192bf18719"
#   },
#   "@iot.id" : "c6487ab6-54f9-11e8-a120-2fe1351d6558",
#   "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('c6487ab6-54f9-11e8-a120-2fe1351d6558')"
# }
# c6487ab6-54f9-11e8-a120-2fe1351d6558
# Receiving new message with topic: Observations
# Observations
# {
#   "phenomenonTime" : "2016-03-02T02:20:00.000Z",
#   "resultTime" : "2016-03-02T02:20:00.000Z",
#   "result" : "2.7",
#   "Datastream@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('c64d04b4-54f9-11e8-a120-f36557bfaa37')/Datastream",
#   "Datastream" : {
#     "unitOfMeasurement" : {
#       "name" : null,
#       "symbol" : null,
#       "definition" : null
#     },
#     "@iot.id" : "edu.teco.wang/IBADENWR82/Datastreams/Air-Temperature-IBADENWR82"
#   },
#   "FeatureOfInterest@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('c64d04b4-54f9-11e8-a120-f36557bfaa37')/FeatureOfInterest",
#   "FeatureOfInterest" : {
#     "@iot.id" : "2b2136ce-54f7-11e8-a120-ab192bf18719"
#   },
#   "@iot.id" : "c64d04b4-54f9-11e8-a120-f36557bfaa37",
#   "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('c64d04b4-54f9-11e8-a120-f36557bfaa37')"
# }
# c64d04b4-54f9-11e8-a120-f36557bfaa37
# Receiving new message with topic: Observations
# Observations
# {
#   "phenomenonTime" : "2016-03-02T02:55:00.000Z",
#   "resultTime" : "2016-03-02T02:55:00.000Z",
#   "result" : "2.8",
#   "Datastream@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('c64fbd30-54f9-11e8-a120-ef16b27964a3')/Datastream",
#   "Datastream" : {
#     "unitOfMeasurement" : {
#       "name" : null,
#       "symbol" : null,
#       "definition" : null
#     },
#     "@iot.id" : "edu.teco.wang/IBADENWR82/Datastreams/Air-Temperature-IBADENWR82"
#   },
#   "FeatureOfInterest@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('c64fbd30-54f9-11e8-a120-ef16b27964a3')/FeatureOfInterest",
#   "FeatureOfInterest" : {
#     "@iot.id" : "2b2136ce-54f7-11e8-a120-ab192bf18719"
#   },
#   "@iot.id" : "c64fbd30-54f9-11e8-a120-ef16b27964a3",
#   "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('c64fbd30-54f9-11e8-a120-ef16b27964a3')"
# }
# c64fbd30-54f9-11e8-a120-ef16b27964a3
# Receiving new message with topic: Observations
# Observations
# {
#   "phenomenonTime" : "2016-03-02T03:30:00.000Z",
#   "resultTime" : "2016-03-02T03:30:00.000Z",
#   "result" : "3.0",
#   "Datastream@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('c65373d0-54f9-11e8-a120-c3cb57e03279')/Datastream",
#   "Datastream" : {
#     "unitOfMeasurement" : {
#       "name" : null,
#       "symbol" : null,
#       "definition" : null
#     },
#     "@iot.id" : "edu.teco.wang/IBADENWR82/Datastreams/Air-Temperature-IBADENWR82"
#   },
#   "FeatureOfInterest@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('c65373d0-54f9-11e8-a120-c3cb57e03279')/FeatureOfInterest",
#   "FeatureOfInterest" : {
#     "@iot.id" : "2b2136ce-54f7-11e8-a120-ab192bf18719"
#   },
#   "@iot.id" : "c65373d0-54f9-11e8-a120-c3cb57e03279",
#   "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('c65373d0-54f9-11e8-a120-c3cb57e03279')"
# }
# c65373d0-54f9-11e8-a120-c3cb57e03279
# Receiving new message with topic: Observations
# Observations
# {
#   "phenomenonTime" : "2016-03-02T04:15:00.000Z",
#   "resultTime" : "2016-03-02T04:15:00.000Z",
#   "result" : "3.1",
#   "Datastream@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('c656b36a-54f9-11e8-a120-07bbba753721')/Datastream",
#   "Datastream" : {
#     "unitOfMeasurement" : {
#       "name" : null,
#       "symbol" : null,
#       "definition" : null
#     },
#     "@iot.id" : "edu.teco.wang/IBADENWR82/Datastreams/Air-Temperature-IBADENWR82"
#   },
#   "FeatureOfInterest@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('c656b36a-54f9-11e8-a120-07bbba753721')/FeatureOfInterest",
#   "FeatureOfInterest" : {
#     "@iot.id" : "2b2136ce-54f7-11e8-a120-ab192bf18719"
#   },
#   "@iot.id" : "c656b36a-54f9-11e8-a120-07bbba753721",
#   "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('c656b36a-54f9-11e8-a120-07bbba753721')"
# }
# c656b36a-54f9-11e8-a120-07bbba753721
# Receiving new message with topic: Observations
# Observations
# {
#   "phenomenonTime" : "2016-03-02T04:55:00.000Z",
#   "resultTime" : "2016-03-02T04:55:00.000Z",
#   "result" : "3.0",
#   "Datastream@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('c65a94e4-54f9-11e8-a120-23c426c44aa0')/Datastream",
#   "Datastream" : {
#     "unitOfMeasurement" : {
#       "name" : null,
#       "symbol" : null,
#       "definition" : null
#     },
#     "@iot.id" : "edu.teco.wang/IBADENWR82/Datastreams/Air-Temperature-IBADENWR82"
#   },
#   "FeatureOfInterest@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('c65a94e4-54f9-11e8-a120-23c426c44aa0')/FeatureOfInterest",
#   "FeatureOfInterest" : {
#     "@iot.id" : "2b2136ce-54f7-11e8-a120-ab192bf18719"
#   },
#   "@iot.id" : "c65a94e4-54f9-11e8-a120-23c426c44aa0",
#   "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('c65a94e4-54f9-11e8-a120-23c426c44aa0')"
# }
# c65a94e4-54f9-11e8-a120-23c426c44aa0
# Receiving new message with topic: Observations
# Observations
# {
#   "phenomenonTime" : "2016-03-02T05:35:00.000Z",
#   "resultTime" : "2016-03-02T05:35:00.000Z",
#   "result" : "3.2",
#   "Datastream@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('c65dc632-54f9-11e8-a120-33ad4db18b75')/Datastream",
#   "Datastream" : {
#     "unitOfMeasurement" : {
#       "name" : null,
#       "symbol" : null,
#       "definition" : null
#     },
#     "@iot.id" : "edu.teco.wang/IBADENWR82/Datastreams/Air-Temperature-IBADENWR82"
#   },
#   "FeatureOfInterest@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('c65dc632-54f9-11e8-a120-33ad4db18b75')/FeatureOfInterest",
#   "FeatureOfInterest" : {
#     "@iot.id" : "2b2136ce-54f7-11e8-a120-ab192bf18719"
#   },
#   "@iot.id" : "c65dc632-54f9-11e8-a120-33ad4db18b75",
#   "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('c65dc632-54f9-11e8-a120-33ad4db18b75')"
# }
# c65dc632-54f9-11e8-a120-33ad4db18b75
# Receiving new message with topic: Observations
# Observations
# {
#   "phenomenonTime" : "2016-03-02T06:15:00.000Z",
#   "resultTime" : "2016-03-02T06:15:00.000Z",
#   "result" : "3.7",
#   "Datastream@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('c665c0d0-54f9-11e8-a120-035cfbca0590')/Datastream",
#   "Datastream" : {
#     "unitOfMeasurement" : {
#       "name" : null,
#       "symbol" : null,
#       "definition" : null
#     },
#     "@iot.id" : "edu.teco.wang/IBADENWR82/Datastreams/Air-Temperature-IBADENWR82"
#   },
#   "FeatureOfInterest@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Observations('c665c0d0-54f9-11e8-a120-035cfbca0590')/FeatureOfInterest",
#   "FeatureOfInterest" : {
#     "@iot.id" : "2b2136ce-54f7-11e8-a120-ab192bf18719"
#   },
#   "@iot.id" : "c665c0d0-54f9-11e8-a120-035cfbca0590",
# ...
#   "Sensor" : {
#     "@iot.id" : "edu.teco.wang/IBAYERNK9-Air-Temperature"
#   },
#   "ObservedProperty@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Datastreams('edu.teco.wang/IBAYERNK9/Datastreams/Air-Temperature-IBAYERNK9')/ObservedProperty",
#   "ObservedProperty" : {
#     "@iot.id" : "/ObservedProperty/Air-Temperature"
#   },
#   "Thing@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Datastreams('edu.teco.wang/IBAYERNK9/Datastreams/Air-Temperature-IBAYERNK9')/Thing",
#   "Thing" : {
#     "@iot.id" : "edu.teco.wang/IBAYERNK9"
#   },
#   "Observations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Datastreams('edu.teco.wang/IBAYERNK9/Datastreams/Air-Temperature-IBAYERNK9')/Observations",
#   "@iot.id" : "edu.teco.wang/IBAYERNK9/Datastreams/Air-Temperature-IBAYERNK9",
#   "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Datastreams('edu.teco.wang/IBAYERNK9/Datastreams/Air-Temperature-IBAYERNK9')"
# }
# edu.teco.wang/IBAYERNK9/Datastreams/Air-Temperature-IBAYERNK9
# Receiving new message with topic: Datastreams
# Datastreams
# {
#   "name" : "Air-Humidity-DS",
#   "description" : "Datastream for recording temperature",
#   "observationType" : "http://www.opengis.net/def/observationType/OGC-OM/2.0/OM_Measurement",
#   "unitOfMeasurement" : {
#     "name" : "Degree Celsius",
#     "symbol" : "degC",
#     "definition" : "http://www.qudt.org/qudt/owl/1.0.0/unit/Instances.html#DegreeCelsius"
#   },
#   "Sensor@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Datastreams('edu.teco.wang/IBAYERNK9/Datastreams/Air-Humidity-IBAYERNK9')/Sensor",
#   "Sensor" : {
#     "@iot.id" : "edu.teco.wang/IBAYERNK9-Air-Humidity"
#   },
#   "ObservedProperty@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Datastreams('edu.teco.wang/IBAYERNK9/Datastreams/Air-Humidity-IBAYERNK9')/ObservedProperty",
#   "ObservedProperty" : {
#     "@iot.id" : "/ObservedProperty/Air-Humidity"
#   },
#   "Thing@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Datastreams('edu.teco.wang/IBAYERNK9/Datastreams/Air-Humidity-IBAYERNK9')/Thing",
#   "Thing" : {
#     "@iot.id" : "edu.teco.wang/IBAYERNK9"
#   },
#   "Observations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Datastreams('edu.teco.wang/IBAYERNK9/Datastreams/Air-Humidity-IBAYERNK9')/Observations",
#   "@iot.id" : "edu.teco.wang/IBAYERNK9/Datastreams/Air-Humidity-IBAYERNK9",
#   "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Datastreams('edu.teco.wang/IBAYERNK9/Datastreams/Air-Humidity-IBAYERNK9')"
# }
# edu.teco.wang/IBAYERNK9/Datastreams/Air-Humidity-IBAYERNK9
# Receiving new message with topic: Datastreams
# Datastreams
# {
#   "name" : "Air-Pressure-DS",
#   "description" : "Datastream for recording temperature",
#   "observationType" : "http://www.opengis.net/def/observationType/OGC-OM/2.0/OM_Measurement",
#   "unitOfMeasurement" : {
#     "name" : "Degree Celsius",
#     "symbol" : "degC",
#     "definition" : "http://www.qudt.org/qudt/owl/1.0.0/unit/Instances.html#DegreeCelsius"
#   },
#   "Sensor@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Datastreams('edu.teco.wang/IBAYERNK9/Datastreams/Air-Pressure-IBAYERNK9')/Sensor",
#   "Sensor" : {
#     "@iot.id" : "edu.teco.wang/IBAYERNK9-Air-Pressure"
#   },
#   "ObservedProperty@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Datastreams('edu.teco.wang/IBAYERNK9/Datastreams/Air-Pressure-IBAYERNK9')/ObservedProperty",
#   "ObservedProperty" : {
#     "@iot.id" : "/ObservedProperty/Air-Pressure"
#   },
#   "Thing@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Datastreams('edu.teco.wang/IBAYERNK9/Datastreams/Air-Pressure-IBAYERNK9')/Thing",
#   "Thing" : {
#     "@iot.id" : "edu.teco.wang/IBAYERNK9"
#   },
#   "Observations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Datastreams('edu.teco.wang/IBAYERNK9/Datastreams/Air-Pressure-IBAYERNK9')/Observations",
#   "@iot.id" : "edu.teco.wang/IBAYERNK9/Datastreams/Air-Pressure-IBAYERNK9",
#   "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Datastreams('edu.teco.wang/IBAYERNK9/Datastreams/Air-Pressure-IBAYERNK9')"
# }
# edu.teco.wang/IBAYERNK9/Datastreams/Air-Pressure-IBAYERNK9
# Receiving new message with topic: FeaturesOfInterest
# FeaturesOfInterest
# {
#   "name" : "Weather Station-IBAYERNK9",
#   "description" : "Weather Station-IBAYERNK9",
#   "encodingType" : "application/vnd.geo+json",
#   "feature" : {"type":"Point","coordinates":[48.157,10.32]},
#   "Observations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/FeaturesOfInterest('edu.teco.wang/IBAYERNK9/FoI/IBAYERNK9')/Observations",
#   "@iot.id" : "edu.teco.wang/IBAYERNK9/FoI/IBAYERNK9",
#   "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/FeaturesOfInterest('edu.teco.wang/IBAYERNK9/FoI/IBAYERNK9')"
# }
# edu.teco.wang/IBAYERNK9/FoI/IBAYERNK9
# Receiving new message with topic: Things
# Things
# {
#   "name" : "DWD-Sensor-IARRACH2",
#   "description" : "This is DWD-Sensor-IARRACH2",
#   "Locations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('edu.teco.wang/IARRACH2')/Locations",
#   "HistoricalLocations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('edu.teco.wang/IARRACH2')/HistoricalLocations",
#   "Datastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('edu.teco.wang/IARRACH2')/Datastreams",
#   "MultiDatastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('edu.teco.wang/IARRACH2')/MultiDatastreams",
#   "@iot.id" : "edu.teco.wang/IARRACH2",
#   "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Things('edu.teco.wang/IARRACH2')"
# }
# edu.teco.wang/IARRACH2
# Receiving new message with topic: Locations
# Locations
# {
#   "name" : "edu.teco.wang/IARRACH2",
#   "description" : "This is the location of DWD-Sensor-IARRACH2",
#   "encodingType" : "application/vnd.geo+json",
#   "location" : {"type":"Point","coordinates":[49.163,12.989]},
#   "HistoricalLocations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Locations('Location/edu.teco.wang/IARRACH2')/HistoricalLocations",
#   "Things@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Locations('Location/edu.teco.wang/IARRACH2')/Things",
#   "@iot.id" : "Location/edu.teco.wang/IARRACH2",
#   "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Locations('Location/edu.teco.wang/IARRACH2')"
# }
# Location/edu.teco.wang/IARRACH2
# Receiving new message with topic: Sensors
# Sensors
# {
#   "name" : "DWD-Sensor-IARRACH2-Air-Temperature",
#   "description" : "This is a Sensor from Netatmo Weather Station",
#   "encodingType" : "application/pdf",
#   "metadata" : "https://www.wunderground.com/personal-weather-station/dashboard?ID=IARRACH2",
#   "Datastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Sensors('edu.teco.wang/IARRACH2-Air-Temperature')/Datastreams",
#   "MultiDatastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Sensors('edu.teco.wang/IARRACH2-Air-Temperature')/MultiDatastreams",
#   "@iot.id" : "edu.teco.wang/IARRACH2-Air-Temperature",
#   "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Sensors('edu.teco.wang/IARRACH2-Air-Temperature')"
# }
# edu.teco.wang/IARRACH2-Air-Temperature
# Receiving new message with topic: Sensors
# Sensors
# {
#   "name" : "DWD-Sensor-IARRACH2-Air-Humidity",
#   "description" : "This is a Sensor from Netatmo Weather Station",
#   "encodingType" : "application/pdf",
#   "metadata" : "https://www.wunderground.com/personal-weather-station/dashboard?ID=IARRACH2",
#   "Datastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Sensors('edu.teco.wang/IARRACH2-Air-Humidity')/Datastreams",
#   "MultiDatastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Sensors('edu.teco.wang/IARRACH2-Air-Humidity')/MultiDatastreams",
#   "@iot.id" : "edu.teco.wang/IARRACH2-Air-Humidity",
#   "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Sensors('edu.teco.wang/IARRACH2-Air-Humidity')"
# }
# edu.teco.wang/IARRACH2-Air-Humidity
# Receiving new message with topic: Sensors
# Sensors
# {
#   "name" : "DWD-Sensor-IARRACH2-Air-Pressure",
#   "description" : "This is a Sensor from Netatmo Weather Station",
#   "encodingType" : "application/pdf",
#   "metadata" : "https://www.wunderground.com/personal-weather-station/dashboard?ID=IARRACH2",
#   "Datastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Sensors('edu.teco.wang/IARRACH2-Air-Pressure')/Datastreams",
#   "MultiDatastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Sensors('edu.teco.wang/IARRACH2-Air-Pressure')/MultiDatastreams",
#   "@iot.id" : "edu.teco.wang/IARRACH2-Air-Pressure",
#   "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Sensors('edu.teco.wang/IARRACH2-Air-Pressure')"
# }
# edu.teco.wang/IARRACH2-Air-Pressure
# Receiving new message with topic: Datastreams
# Datastreams
# {
#   "name" : "Air-Temperature-DS",
#   "description" : "Datastream for recording temperature",
#   "observationType" : "http://www.opengis.net/def/observationType/OGC-OM/2.0/OM_Measurement",
#   "unitOfMeasurement" : {
#     "name" : "Degree Celsius",
#     "symbol" : "degC",
#     "definition" : "http://www.qudt.org/qudt/owl/1.0.0/unit/Instances.html#DegreeCelsius"
#   },
#   "Sensor@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Datastreams('edu.teco.wang/IARRACH2/Datastreams/Air-Temperature-IARRACH2')/Sensor",
#   "Sensor" : {
#     "@iot.id" : "edu.teco.wang/IARRACH2-Air-Temperature"
#   },
#   "ObservedProperty@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Datastreams('edu.teco.wang/IARRACH2/Datastreams/Air-Temperature-IARRACH2')/ObservedProperty",
#   "ObservedProperty" : {
#     "@iot.id" : "/ObservedProperty/Air-Temperature"
#   },
#   "Thing@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Datastreams('edu.teco.wang/IARRACH2/Datastreams/Air-Temperature-IARRACH2')/Thing",
#   "Thing" : {
#     "@iot.id" : "edu.teco.wang/IARRACH2"
#   },
#   "Observations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Datastreams('edu.teco.wang/IARRACH2/Datastreams/Air-Temperature-IARRACH2')/Observations",
#   "@iot.id" : "edu.teco.wang/IARRACH2/Datastreams/Air-Temperature-IARRACH2",
#   "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Datastreams('edu.teco.wang/IARRACH2/Datastreams/Air-Temperature-IARRACH2')"
# }
# edu.teco.wang/IARRACH2/Datastreams/Air-Temperature-IARRACH2
# Receiving new message with topic: Datastreams
# Datastreams
# {
#   "name" : "Air-Humidity-DS",
#   "description" : "Datastream for recording temperature",
#   "observationType" : "http://www.opengis.net/def/observationType/OGC-OM/2.0/OM_Measurement",
#   "unitOfMeasurement" : {
#     "name" : "Degree Celsius",
#     "symbol" : "degC",
#     "definition" : "http://www.qudt.org/qudt/owl/1.0.0/unit/Instances.html#DegreeCelsius"
#   },
#   "Sensor@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Datastreams('edu.teco.wang/IARRACH2/Datastreams/Air-Humidity-IARRACH2')/Sensor",
#   "Sensor" : {
#     "@iot.id" : "edu.teco.wang/IARRACH2-Air-Humidity"
#   },
#   "ObservedProperty@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Datastreams('edu.teco.wang/IARRACH2/Datastreams/Air-Humidity-IARRACH2')/ObservedProperty",
#   "ObservedProperty" : {
#     "@iot.id" : "/ObservedProperty/Air-Humidity"
#   },
#   "Thing@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Datastreams('edu.teco.wang/IARRACH2/Datastreams/Air-Humidity-IARRACH2')/Thing",
#   "Thing" : {
#     "@iot.id" : "edu.teco.wang/IARRACH2"
#   },
#   "Observations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Datastreams('edu.teco.wang/IARRACH2/Datastreams/Air-Humidity-IARRACH2')/Observations",
#   "@iot.id" : "edu.teco.wang/IARRACH2/Datastreams/Air-Humidity-IARRACH2",
#   "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Datastreams('edu.teco.wang/IARRACH2/Datastreams/Air-Humidity-IARRACH2')"
# }
# edu.teco.wang/IARRACH2/Datastreams/Air-Humidity-IARRACH2
# Receiving new message with topic: Datastreams
# Datastreams
# {
#   "name" : "Air-Pressure-DS",
#   "description" : "Datastream for recording temperature",
#   "observationType" : "http://www.opengis.net/def/observationType/OGC-OM/2.0/OM_Measurement",
#   "unitOfMeasurement" : {
#     "name" : "Degree Celsius",
#     "symbol" : "degC",
#     "definition" : "http://www.qudt.org/qudt/owl/1.0.0/unit/Instances.html#DegreeCelsius"
#   },
#   "Sensor@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Datastreams('edu.teco.wang/IARRACH2/Datastreams/Air-Pressure-IARRACH2')/Sensor",
#   "Sensor" : {
#     "@iot.id" : "edu.teco.wang/IARRACH2-Air-Pressure"
#   },
#   "ObservedProperty@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Datastreams('edu.teco.wang/IARRACH2/Datastreams/Air-Pressure-IARRACH2')/ObservedProperty",
#   "ObservedProperty" : {
#     "@iot.id" : "/ObservedProperty/Air-Pressure"
#   },
#   "Thing@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Datastreams('edu.teco.wang/IARRACH2/Datastreams/Air-Pressure-IARRACH2')/Thing",
#   "Thing" : {
#     "@iot.id" : "edu.teco.wang/IARRACH2"
#   },
#   "Observations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Datastreams('edu.teco.wang/IARRACH2/Datastreams/Air-Pressure-IARRACH2')/Observations",
#   "@iot.id" : "edu.teco.wang/IARRACH2/Datastreams/Air-Pressure-IARRACH2",
#   "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Datastreams('edu.teco.wang/IARRACH2/Datastreams/Air-Pressure-IARRACH2')"
# }
# edu.teco.wang/IARRACH2/Datastreams/Air-Pressure-IARRACH2
# Receiving new message with topic: FeaturesOfInterest
# FeaturesOfInterest
# {
#   "name" : "Weather Station-IARRACH2",
#   "description" : "Weather Station-IARRACH2",
#   "encodingType" : "application/vnd.geo+json",
#   "feature" : {"type":"Point","coordinates":[49.163,12.989]},
#   "Observations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/FeaturesOfInterest('edu.teco.wang/IARRACH2/FoI/IARRACH2')/Observations",
#   "@iot.id" : "edu.teco.wang/IARRACH2/FoI/IARRACH2",
#   "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/FeaturesOfInterest('edu.teco.wang/IARRACH2/FoI/IARRACH2')"
# }
# edu.teco.wang/IARRACH2/FoI/IARRACH2
# Receiving new message with topic: Locations
# Locations
# {
#   "name" : "edu.teco.wang/IAACHEN117",
#   "description" : "This is the location of DWD-Sensor-IAACHEN117",
#   "encodingType" : "application/vnd.geo+json",
#   "location" : {"type":"Point","coordinates":[50.695,6.178]},
#   "HistoricalLocations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Locations('Location/edu.teco.wang/IAACHEN117')/HistoricalLocations",
#   "Things@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Locations('Location/edu.teco.wang/IAACHEN117')/Things",
#   "@iot.id" : "Location/edu.teco.wang/IAACHEN117",
#   "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Locations('Location/edu.teco.wang/IAACHEN117')"
# }
# Location/edu.teco.wang/IAACHEN117
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-8b5696ca89be> in <module>()
#      11
#      12 client.connect(smartaqnetHome, 1883, 60)
# ---> 13 client.loop_forever()
#
# /home/wang/anaconda3/envs/kafkTest27/lib/python2.7/site-packages/paho/mqtt/client.pyc in loop_forever(self, timeout, max_packets, retry_first_connection)
#    1479             rc = MQTT_ERR_SUCCESS
#    1480             while rc == MQTT_ERR_SUCCESS:
# -> 1481                 rc = self.loop(timeout, max_packets)
#    1482                 # We don't need to worry about locking here, because we've
#    1483                 # either called loop_forever() when in single threaded mode, or
#
# /home/wang/anaconda3/envs/kafkTest27/lib/python2.7/site-packages/paho/mqtt/client.pyc in loop(self, timeout, max_packets)
#     986         rlist = [self._sock, self._sockpairR]
#     987         try:
# --> 988             socklist = select.select(rlist, wlist, [], timeout)
#     989         except TypeError:
#     990             # Socket isn't correct type, in likelihood connection is lost
#
# KeyboardInterrupt:

# %%
producer.send('fizzbuzz', key= 'uid', value={'foo': 'bar'})

# %%
import paho.mqtt.client as paho
 
def on_connect(client, userdata, flags, rc):
    print("CONNACK received with code %d." % (rc))
 
client = paho.Client()
client.on_connect = on_connect
client.connect("smartaqnet.teco.edu", 8083)
# Out:
# 0

# %%
#!/usr/bin/env python
import threading, logging, time
import multiprocessing

from kafka import KafkaConsumer, KafkaProducer

kafkaUrl = "smartaqnet-dev.teco.edu"
kafkaUrl = "smartaqnet.teco.edu"
class Producer(threading.Thread):
    def __init__(self):
        threading.Thread.__init__(self)
        self.stop_event = threading.Event()
        
    def stop(self):
        self.stop_event.set()

    def run(self):
        producer = KafkaProducer(bootstrap_servers=kafkaUrl+':9092')

        while not self.stop_event.is_set():
            producer.send('Things', "TTT")
            producer.send('Things', b"\xc2Hola, mundo!")
            time.sleep(1)

        producer.close()

class Consumer(multiprocessing.Process):
    def __init__(self):
        multiprocessing.Process.__init__(self)
        self.stop_event = multiprocessing.Event()
        
    def stop(self):
        self.stop_event.set()
        
    def run(self):
        consumer = KafkaConsumer(bootstrap_servers= kafkaUrl + ':9092',
                                 auto_offset_reset='latest',
                                 consumer_timeout_ms=1000)
        consumer.subscribe(['Things'])

        while not self.stop_event.is_set():
            for message in consumer:
                print(message)
                if self.stop_event.is_set():
                    break

        consumer.close()

# %%
tasks = [
        Producer(),
        Consumer()
]
for t in tasks:
        t.start()

time.sleep(3)
for t in tasks:
        t.stop()
# Out:
# ConsumerRecord(topic=u'Things', partition=0, offset=87, timestamp=1525342996936, timestamp_type=0, key=None, value='TTT', checksum=None, serialized_key_size=-1, serialized_value_size=3)
# ConsumerRecord(topic=u'Things', partition=0, offset=88, timestamp=1525342996937, timestamp_type=0, key=None, value='\xc2Hola, mundo!', checksum=None, serialized_key_size=-1, serialized_value_size=13)
# ConsumerRecord(topic=u'Things', partition=0, offset=89, timestamp=1525342997938, timestamp_type=0, key=None, value='TTT', checksum=None, serialized_key_size=-1, serialized_value_size=3)
# ConsumerRecord(topic=u'Things', partition=0, offset=90, timestamp=1525342997938, timestamp_type=0, key=None, value='\xc2Hola, mundo!', checksum=None, serialized_key_size=-1, serialized_value_size=13)

# %%
for t in tasks:
        t.stop()
