# %% [markdown]
# ## Kriging Use Case
# Fetches wunderground data from Kafka, use them to predict air temperature. Predictions are validated with observations from deutsche Wetterdienst
# How-tos:
#     1. Get data from Kafka to Spark
#     2. Get data as File from HDFS to Spark
#     3. Manipulate SparkDF
#     4. Do some computing: Kriging, in parallel with partitioning

# %%
import csv
import re
import math
import time
import random
import numpy as np
import sys
import os
from shapely.geometry import shape, Point 
import folium
from matplotlib.pyplot import axis
from numpy import shape

import copy
import matplotlib
import datetime
import matplotlib as mpl
import pandas as pd

from sklearn.gaussian_process.kernels import Matern
import matplotlib.colors as colors
import matplotlib.pyplot as plt


#    Spark
from pyspark import SparkContext
from pyspark.sql import SparkSession
from pyspark.conf import SparkConf
#    Spark Streaming
from pyspark.streaming import StreamingContext  
#    Kafka
from pyspark.streaming.kafka import KafkaUtils  
#    json parsing
import json 


#

# %% [markdown]
# ## Set system env
#  <pre>
#  1. 2. Specify which python will be used by spark so that the installed packages can be distributed across the cluster in HDFS
#  3. Include pacages for kafka-spark connection
#  </pre>

# %%
## ChangeME
os.environ['PYSPARK_DRIVER_PYTHON'] = "/gpfs/smartdata/urdxb/.conda/envs/pySparkEnv/bin/ipython"
## ChangeME
os.environ['PYSPARK_PYTHON'] = "/gpfs/smartdata/urdxb/.conda/envs/pySparkEnv/bin/python"
os.environ['PYSPARK_SUBMIT_ARGS'] = '--packages org.apache.spark:spark-sql-kafka-0-10_2.11:2.3.0 pyspark-shell'

# %% [markdown]
# ## Create a sparksession

# %%
conf = SparkConf().setMaster("local[*]").setAppName('Kriging example')
ss = SparkSession.builder.config(conf=conf).getOrCreate()
sc = ss.sparkContext

# %% [markdown]
# ## Convertion of Kafka Stream to DataStream
# 1. Create dataframe that readStream from Kafka. For more infos: https://spark.apache.org/docs/2.3.0/structured-streaming-kafka-integration.html
# 2. Convert \$key and \$ value to string where the key is the uid of the observation and the value is the message in JSON
# 3. Extract the informations in the message

# %%
from pyspark.sql import functions as F
from pyspark.sql.functions import udf
from pyspark.sql.types import *
# import helper.py, you may want to put the variables or functions there
import Helper

kafkaHome = "kafka-vm0.teco.edu"
brokerUrl = kafkaHome + ":9092"

# %%
# Declare a data frame that subscribes to the topic Observations and take the messages from the very begining (offset=0)
df = ss.readStream.format("kafka").option("kafka.bootstrap.servers", brokerUrl) \
        .option("subscribe", "Observations")\
        .option("startingOffsets","earliest")\
        .load()
df = df.selectExpr("CAST(key AS STRING)", "CAST(value AS STRING)")

# %%
## Function that parses the value in the message to a Row in SparkSQL
def valToJSON(s):
    if s is not None:
        import ast
        d = ast.literal_eval(s)
        return d#json.loads(d)['result']
def getID(d):
    if d is not None:
        try:
            return json.loads(d)['Datastream']['@iot.id']
        except:
            return None
def getTime(d):
    if d is not None:
        try:
            return json.loads(d)['resultTime']
        except:
            return None

def getLat(d):
    if d is not None:
        try:
            latlon = json.loads(d)['FeatureOfInterest']['@iot.id']
        
            return latlon.split("/")[-1].split(":")[0]
        except:
            return None
def getLon(d):

    if d is not None:
        try:
            latlon = json.loads(d)['FeatureOfInterest']['@iot.id']
        
            return latlon.split("/")[-1].split(":")[1]
        except:
            return None
def getTemp(d):
    if d is not None:
        try:
            return json.loads(d)['result']
        except:
            return None

dateStr, timeStr = "2015-12-01","22:00:00"
        

myValToJSON = udf(valToJSON)
myGetID = udf(getID)
myGetTime = udf(getTime)
myGetLat = udf(getLat)
myGetLon = udf(getLon)
myGetTemp = udf(getTemp)

#df = df.select(df.key, myValToJSON("value").alias("value"))
df = df.select(df.key, df.value, myGetTime(df.value).alias("DateTimeString"))
df = df.filter(df.DateTimeString.contains(dateStr) & df.DateTimeString.contains("T"+ timeStr[0:2])).drop(df.DateTimeString)
#df = df.drop(df.DateTimeString)
df = df.groupBy(df.key).agg(F.last(df.value).alias("value"))

df = df.select(myGetID(df.value).alias("ID"),
               myGetTime(df.value).alias("Time"),
               myGetLat(df.value).alias("Latitude"),
               myGetLon(df.value).alias("Longitude"),
               myGetTemp(df.value).alias("AirTemperature"))

## Start the query based on the Spark dataframe and its processing (select,filter,group and so on)
q = df.writeStream.queryName('TemperatureMap').outputMode("complete").format("memory").start()

# %%
#
x = ss.sql("select * from TemperatureMap").rdd.collect()
if(len(x)!= 0):
    print(len(x))
    print(x[0])

# %% [markdown]
# ## Perform partitioning
# 1. Transform the SparkDF to PandasDF
# 2. Partition according to the density of the weather stations

# %%
# Select the observations from streaming data as a SparkDF and convert it to a PandasDF
observations = pd.DataFrame(ss.sql("select Latitude,Longitude,AirTemperature from TemperatureMap").rdd.collect(),columns =['Latitude','Longitude','AirTemperature'] )
observations[['Latitude','Longitude','AirTemperature']] = observations[['Latitude','Longitude','AirTemperature']].apply(pd.to_numeric,errors="coerce")
observations["key"] = 0
oldNoKeys = 0
# Create a PandasDF for the purpose of partitioning
tileTable = observations.loc[:,['key','Latitude','Longitude']].groupby("key").agg(["min","max"])
krigingRange = [47.2, 55.1,  5.2 , 15.2]
tileTable.loc[0] =krigingRange
# Partition the observations according to their location (lat lon)
while(oldNoKeys != tileTable.shape[0]):
    oldNoKeys = tileTable.shape[0]
    print(oldNoKeys)
    #Create new Tiles
    for aIndex in tileTable.index:
        if(aIndex <= 0):
            newIndexs = [4 * aIndex - 1, 4*aIndex - 2, 4*aIndex - 3, 4*aIndex - 4]
            # 1 2
            # 3 4
            latMax = tileTable.loc[aIndex,"Latitude"]["max"]
            latMin = tileTable.loc[aIndex,"Latitude"]["min"]
            lonMax = tileTable.loc[aIndex,"Longitude"]["max"]
            lonMin = tileTable.loc[aIndex,"Longitude"]["min"]
            newTiles = [[latMin, (latMax + latMin)/2, lonMin, (lonMax + lonMin)/2],
                        [(latMax + latMin)/2, latMax, lonMin, (lonMax + lonMin)/2],
                        [latMin, (latMax + latMin)/2, (lonMax + lonMin)/2, lonMax],
                        [(latMax + latMin)/2, latMax, (lonMax + lonMin)/2, lonMax]]
            forceSplit = False
            split = True
            for aNewTile in newTiles:
                
                aCtr = observations.loc[(observations.Latitude >= aNewTile[0]) & (observations.Latitude <= aNewTile[1])
             & (observations.Longitude >= aNewTile[2]) & (observations.Longitude <= aNewTile[3])].shape[0]
                
                if( aCtr < 10):
                    split = False
                elif(aCtr >= 200):
                    forceSplit = True
                    split = True
                #print(str(aIndex)+" "+str(aCtr))
            
            if(forceSplit or split):
                for i in range(0,4):
                    #split remove old
                    tileTable.loc[newIndexs[i]] = newTiles[i]
                    observations.loc[(observations.Latitude >= newTiles[i][0]) & (observations.Latitude <= newTiles[i][1])
             & (observations.Longitude >= newTiles[i][2]) & (observations.Longitude <= newTiles[i][3]),"key"] = -newIndexs[i]
                    
                    #create new
            else:
                #keep old
                tileTable.loc[-aIndex] = tileTable.loc[aIndex]
            tileTable = tileTable.drop([aIndex])
# Out:
# 1
# 4
# 16
# 46
# 112
# 148
# 157

# %%
# Stop the query if you want
q.stop()

# %% [markdown]
# ## Draw partition lines
# Check the result of partitioning, can also be skipped
# 1. Convert partioning result to a geoJSON
# 2. Plot using Folium

# %%
tileTable["P1"] = tileTable.Longitude["min"].map(lambda x: [x]) + tileTable.Latitude["min"].map(lambda x: [x])
tileTable["P2"] = tileTable.Longitude["min"].map(lambda x: [x]) + tileTable.Latitude["max"].map(lambda x: [x])
tileTable["P3"] = tileTable.Longitude["max"].map(lambda x: [x]) + tileTable.Latitude["max"].map(lambda x: [x])
tileTable["P4"] = tileTable.Longitude["max"].map(lambda x: [x]) + tileTable.Latitude["min"].map(lambda x: [x])
tileTable["Ps"] = tileTable.P1.map(lambda x: [x]) + tileTable.P2.map(lambda x: [x]) + tileTable.P3.map(lambda x: [x]) + tileTable.P4.map(lambda x: [x])
tileTable["Ps"] = tileTable.Ps.map(lambda x: [x])
#keys["JSONstr"] = keys.P1.map(lambda x:)

#tileTable[["idx","Ps"]].iloc[0].idx.values[0]
#tileTable[["idx","Ps"]].iloc[0].Ps.values[0]
#tileTable

# %%
myFeatures = []
for aKey in tileTable.index:
    aFeature = {"type":"Feature",
                "id":aKey,
                "properties":{"name":aKey},
                "geometry":{"type":"Polygon","coordinates":tileTable.loc[aKey].Ps.values[0]}}
    #print(json.dumps(aFeature))
    myFeatures.append(aFeature)
    #print(keys.loc[aKey].idx.values[0])

myMultiPolygon = {"type":"FeatureCollection","features":myFeatures}
myJSON = json.loads(json.dumps(myMultiPolygon))
myJSON
# Out:
# {u'features': [{u'geometry': {u'coordinates': [[[5.2, 47.2],
#       [5.2, 49.175000000000004],
#       [7.699999999999999, 49.175000000000004],
#       [7.699999999999999, 47.2]]],
#     u'type': u'Polygon'},
#    u'id': 5,
#    u'properties': {u'name': 5},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[5.2, 53.125],
#       [5.2, 55.1],
#       [7.699999999999999, 55.1],
#       [7.699999999999999, 53.125]]],
#     u'type': u'Polygon'},
#    u'id': 10,
#    u'properties': {u'name': 10},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[12.7, 47.2],
#       [12.7, 49.175000000000004],
#       [15.2, 49.175000000000004],
#       [15.2, 47.2]]],
#     u'type': u'Polygon'},
#    u'id': 15,
#    u'properties': {u'name': 15},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[12.7, 49.175000000000004],
#       [12.7, 51.150000000000006],
#       [15.2, 51.150000000000006],
#       [15.2, 49.175000000000004]]],
#     u'type': u'Polygon'},
#    u'id': 16,
#    u'properties': {u'name': 16},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[10.2, 53.125],
#       [10.2, 55.1],
#       [12.7, 55.1],
#       [12.7, 53.125]]],
#     u'type': u'Polygon'},
#    u'id': 18,
#    u'properties': {u'name': 18},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[12.7, 53.125],
#       [12.7, 55.1],
#       [15.2, 55.1],
#       [15.2, 53.125]]],
#     u'type': u'Polygon'},
#    u'id': 20,
#    u'properties': {u'name': 20},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[5.2, 49.175000000000004],
#       [5.2, 50.16250000000001],
#       [6.449999999999999, 50.16250000000001],
#       [6.449999999999999, 49.175000000000004]]],
#     u'type': u'Polygon'},
#    u'id': 25,
#    u'properties': {u'name': 25},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[5.2, 50.16250000000001],
#       [5.2, 51.150000000000006],
#       [6.449999999999999, 51.150000000000006],
#       [6.449999999999999, 50.16250000000001]]],
#     u'type': u'Polygon'},
#    u'id': 26,
#    u'properties': {u'name': 26},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[7.699999999999999, 47.2],
#       [7.699999999999999, 48.1875],
#       [8.95, 48.1875],
#       [8.95, 47.2]]],
#     u'type': u'Polygon'},
#    u'id': 29,
#    u'properties': {u'name': 29},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[8.95, 47.2],
#       [8.95, 48.1875],
#       [10.2, 48.1875],
#       [10.2, 47.2]]],
#     u'type': u'Polygon'},
#    u'id': 31,
#    u'properties': {u'name': 31},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[5.2, 51.150000000000006],
#       [5.2, 52.1375],
#       [6.449999999999999, 52.1375],
#       [6.449999999999999, 51.150000000000006]]],
#     u'type': u'Polygon'},
#    u'id': 37,
#    u'properties': {u'name': 37},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[5.2, 52.1375],
#       [5.2, 53.125],
#       [6.449999999999999, 53.125],
#       [6.449999999999999, 52.1375]]],
#     u'type': u'Polygon'},
#    u'id': 38,
#    u'properties': {u'name': 38},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[6.449999999999999, 52.1375],
#       [6.449999999999999, 53.125],
#       [7.699999999999999, 53.125],
#       [7.699999999999999, 52.1375]]],
#     u'type': u'Polygon'},
#    u'id': 40,
#    u'properties': {u'name': 40},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[8.95, 52.1375],
#       [8.95, 53.125],
#       [10.2, 53.125],
#       [10.2, 52.1375]]],
#     u'type': u'Polygon'},
#    u'id': 48,
#    u'properties': {u'name': 48},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[7.699999999999999, 53.125],
#       [7.699999999999999, 54.1125],
#       [8.95, 54.1125],
#       [8.95, 53.125]]],
#     u'type': u'Polygon'},
#    u'id': 49,
#    u'properties': {u'name': 49},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[7.699999999999999, 54.1125],
#       [7.699999999999999, 55.1],
#       [8.95, 55.1],
#       [8.95, 54.1125]]],
#     u'type': u'Polygon'},
#    u'id': 50,
#    u'properties': {u'name': 50},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[8.95, 54.1125],
#       [8.95, 55.1],
#       [10.2, 55.1],
#       [10.2, 54.1125]]],
#     u'type': u'Polygon'},
#    u'id': 52,
#    u'properties': {u'name': 52},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[10.2, 47.2],
#       [10.2, 48.1875],
#       [11.45, 48.1875],
#       [11.45, 47.2]]],
#     u'type': u'Polygon'},
#    u'id': 53,
#    u'properties': {u'name': 53},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[11.45, 47.2],
#       [11.45, 48.1875],
#       [12.7, 48.1875],
#       [12.7, 47.2]]],
#     u'type': u'Polygon'},
#    u'id': 55,
#    u'properties': {u'name': 55},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[10.2, 52.1375],
#       [10.2, 53.125],
#       [11.45, 53.125],
#       [11.45, 52.1375]]],
#     u'type': u'Polygon'},
#    u'id': 70,
#    u'properties': {u'name': 70},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[11.45, 52.1375],
#       [11.45, 53.125],
#       [12.7, 53.125],
#       [12.7, 52.1375]]],
#     u'type': u'Polygon'},
#    u'id': 72,
#    u'properties': {u'name': 72},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[12.7, 51.150000000000006],
#       [12.7, 52.1375],
#       [13.95, 52.1375],
#       [13.95, 51.150000000000006]]],
#     u'type': u'Polygon'},
#    u'id': 77,
#    u'properties': {u'name': 77},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[13.95, 51.150000000000006],
#       [13.95, 52.1375],
#       [15.2, 52.1375],
#       [15.2, 51.150000000000006]]],
#     u'type': u'Polygon'},
#    u'id': 79,
#    u'properties': {u'name': 79},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[13.95, 52.1375],
#       [13.95, 53.125],
#       [15.2, 53.125],
#       [15.2, 52.1375]]],
#     u'type': u'Polygon'},
#    u'id': 80,
#    u'properties': {u'name': 80},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[6.449999999999999, 49.175000000000004],
#       [6.449999999999999, 49.66875],
#       [7.074999999999999, 49.66875],
#       [7.074999999999999, 49.175000000000004]]],
#     u'type': u'Polygon'},
#    u'id': 109,
#    u'properties': {u'name': 109},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[6.449999999999999, 49.66875],
#       [6.449999999999999, 50.16250000000001],
#       [7.074999999999999, 50.16250000000001],
#       [7.074999999999999, 49.66875]]],
#     u'type': u'Polygon'},
#    u'id': 110,
#    u'properties': {u'name': 110},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[7.074999999999999, 49.175000000000004],
#       [7.074999999999999, 49.66875],
#       [7.699999999999999, 49.66875],
#       [7.699999999999999, 49.175000000000004]]],
#     u'type': u'Polygon'},
#    u'id': 111,
#    u'properties': {u'name': 111},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[7.074999999999999, 49.66875],
#       [7.074999999999999, 50.16250000000001],
#       [7.699999999999999, 50.16250000000001],
#       [7.699999999999999, 49.66875]]],
#     u'type': u'Polygon'},
#    u'id': 112,
#    u'properties': {u'name': 112},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[6.449999999999999, 50.16250000000001],
#       [6.449999999999999, 50.65625000000001],
#       [7.074999999999999, 50.65625000000001],
#       [7.074999999999999, 50.16250000000001]]],
#     u'type': u'Polygon'},
#    u'id': 113,
#    u'properties': {u'name': 113},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[7.074999999999999, 50.65625000000001],
#       [7.074999999999999, 51.150000000000006],
#       [7.699999999999999, 51.150000000000006],
#       [7.699999999999999, 50.65625000000001]]],
#     u'type': u'Polygon'},
#    u'id': 116,
#    u'properties': {u'name': 116},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[7.699999999999999, 48.1875],
#       [7.699999999999999, 48.681250000000006],
#       [8.325, 48.681250000000006],
#       [8.325, 48.1875]]],
#     u'type': u'Polygon'},
#    u'id': 121,
#    u'properties': {u'name': 121},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[7.699999999999999, 48.681250000000006],
#       [7.699999999999999, 49.175000000000004],
#       [8.325, 49.175000000000004],
#       [8.325, 48.681250000000006]]],
#     u'type': u'Polygon'},
#    u'id': 122,
#    u'properties': {u'name': 122},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[8.325, 48.1875],
#       [8.325, 48.681250000000006],
#       [8.95, 48.681250000000006],
#       [8.95, 48.1875]]],
#     u'type': u'Polygon'},
#    u'id': 123,
#    u'properties': {u'name': 123},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[8.95, 48.1875],
#       [8.95, 48.681250000000006],
#       [9.575, 48.681250000000006],
#       [9.575, 48.1875]]],
#     u'type': u'Polygon'},
#    u'id': 129,
#    u'properties': {u'name': 129},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[9.575, 48.681250000000006],
#       [9.575, 49.175000000000004],
#       [10.2, 49.175000000000004],
#       [10.2, 48.681250000000006]]],
#     u'type': u'Polygon'},
#    u'id': 132,
#    u'properties': {u'name': 132},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[7.699999999999999, 49.175000000000004],
#       [7.699999999999999, 49.66875],
#       [8.325, 49.66875],
#       [8.325, 49.175000000000004]]],
#     u'type': u'Polygon'},
#    u'id': 133,
#    u'properties': {u'name': 133},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[7.699999999999999, 50.16250000000001],
#       [7.699999999999999, 50.65625000000001],
#       [8.325, 50.65625000000001],
#       [8.325, 50.16250000000001]]],
#     u'type': u'Polygon'},
#    u'id': 137,
#    u'properties': {u'name': 137},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[7.699999999999999, 50.65625000000001],
#       [7.699999999999999, 51.150000000000006],
#       [8.325, 51.150000000000006],
#       [8.325, 50.65625000000001]]],
#     u'type': u'Polygon'},
#    u'id': 138,
#    u'properties': {u'name': 138},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[8.325, 50.65625000000001],
#       [8.325, 51.150000000000006],
#       [8.95, 51.150000000000006],
#       [8.95, 50.65625000000001]]],
#     u'type': u'Polygon'},
#    u'id': 140,
#    u'properties': {u'name': 140},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[8.95, 49.175000000000004],
#       [8.95, 49.66875],
#       [9.575, 49.66875],
#       [9.575, 49.175000000000004]]],
#     u'type': u'Polygon'},
#    u'id': 141,
#    u'properties': {u'name': 141},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[8.95, 49.66875],
#       [8.95, 50.16250000000001],
#       [9.575, 50.16250000000001],
#       [9.575, 49.66875]]],
#     u'type': u'Polygon'},
#    u'id': 142,
#    u'properties': {u'name': 142},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[9.575, 49.175000000000004],
#       [9.575, 49.66875],
#       [10.2, 49.66875],
#       [10.2, 49.175000000000004]]],
#     u'type': u'Polygon'},
#    u'id': 143,
#    u'properties': {u'name': 143},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[9.575, 49.66875],
#       [9.575, 50.16250000000001],
#       [10.2, 50.16250000000001],
#       [10.2, 49.66875]]],
#     u'type': u'Polygon'},
#    u'id': 144,
#    u'properties': {u'name': 144},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[8.95, 50.16250000000001],
#       [8.95, 50.65625000000001],
#       [9.575, 50.65625000000001],
#       [9.575, 50.16250000000001]]],
#     u'type': u'Polygon'},
#    u'id': 145,
#    u'properties': {u'name': 145},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[8.95, 50.65625000000001],
#       [8.95, 51.150000000000006],
#       [9.575, 51.150000000000006],
#       [9.575, 50.65625000000001]]],
#     u'type': u'Polygon'},
#    u'id': 146,
#    u'properties': {u'name': 146},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[9.575, 50.16250000000001],
#       [9.575, 50.65625000000001],
#       [10.2, 50.65625000000001],
#       [10.2, 50.16250000000001]]],
#     u'type': u'Polygon'},
#    u'id': 147,
#    u'properties': {u'name': 147},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[9.575, 50.65625000000001],
#       [9.575, 51.150000000000006],
#       [10.2, 51.150000000000006],
#       [10.2, 50.65625000000001]]],
#     u'type': u'Polygon'},
#    u'id': 148,
#    u'properties': {u'name': 148},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[6.449999999999999, 51.643750000000004],
#       [6.449999999999999, 52.1375],
#       [7.074999999999999, 52.1375],
#       [7.074999999999999, 51.643750000000004]]],
#     u'type': u'Polygon'},
#    u'id': 158,
#    u'properties': {u'name': 158},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[7.074999999999999, 51.643750000000004],
#       [7.074999999999999, 52.1375],
#       [7.699999999999999, 52.1375],
#       [7.699999999999999, 51.643750000000004]]],
#     u'type': u'Polygon'},
#    u'id': 160,
#    u'properties': {u'name': 160},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[7.699999999999999, 51.150000000000006],
#       [7.699999999999999, 51.643750000000004],
#       [8.325, 51.643750000000004],
#       [8.325, 51.150000000000006]]],
#     u'type': u'Polygon'},
#    u'id': 181,
#    u'properties': {u'name': 181},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[7.699999999999999, 51.643750000000004],
#       [7.699999999999999, 52.1375],
#       [8.325, 52.1375],
#       [8.325, 51.643750000000004]]],
#     u'type': u'Polygon'},
#    u'id': 182,
#    u'properties': {u'name': 182},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[8.325, 51.150000000000006],
#       [8.325, 51.643750000000004],
#       [8.95, 51.643750000000004],
#       [8.95, 51.150000000000006]]],
#     u'type': u'Polygon'},
#    u'id': 183,
#    u'properties': {u'name': 183},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[8.325, 51.643750000000004],
#       [8.325, 52.1375],
#       [8.95, 52.1375],
#       [8.95, 51.643750000000004]]],
#     u'type': u'Polygon'},
#    u'id': 184,
#    u'properties': {u'name': 184},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[7.699999999999999, 52.1375],
#       [7.699999999999999, 52.63125],
#       [8.325, 52.63125],
#       [8.325, 52.1375]]],
#     u'type': u'Polygon'},
#    u'id': 185,
#    u'properties': {u'name': 185},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[7.699999999999999, 52.63125],
#       [7.699999999999999, 53.125],
#       [8.325, 53.125],
#       [8.325, 52.63125]]],
#     u'type': u'Polygon'},
#    u'id': 186,
#    u'properties': {u'name': 186},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[8.325, 52.1375],
#       [8.325, 52.63125],
#       [8.95, 52.63125],
#       [8.95, 52.1375]]],
#     u'type': u'Polygon'},
#    u'id': 187,
#    u'properties': {u'name': 187},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[8.325, 52.63125],
#       [8.325, 53.125],
#       [8.95, 53.125],
#       [8.95, 52.63125]]],
#     u'type': u'Polygon'},
#    u'id': 188,
#    u'properties': {u'name': 188},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[8.95, 51.150000000000006],
#       [8.95, 51.643750000000004],
#       [9.575, 51.643750000000004],
#       [9.575, 51.150000000000006]]],
#     u'type': u'Polygon'},
#    u'id': 189,
#    u'properties': {u'name': 189},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[8.95, 51.643750000000004],
#       [8.95, 52.1375],
#       [9.575, 52.1375],
#       [9.575, 51.643750000000004]]],
#     u'type': u'Polygon'},
#    u'id': 190,
#    u'properties': {u'name': 190},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[9.575, 51.150000000000006],
#       [9.575, 51.643750000000004],
#       [10.2, 51.643750000000004],
#       [10.2, 51.150000000000006]]],
#     u'type': u'Polygon'},
#    u'id': 191,
#    u'properties': {u'name': 191},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[9.575, 51.643750000000004],
#       [9.575, 52.1375],
#       [10.2, 52.1375],
#       [10.2, 51.643750000000004]]],
#     u'type': u'Polygon'},
#    u'id': 192,
#    u'properties': {u'name': 192},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[8.95, 53.125],
#       [8.95, 53.61875],
#       [9.575, 53.61875],
#       [9.575, 53.125]]],
#     u'type': u'Polygon'},
#    u'id': 205,
#    u'properties': {u'name': 205},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[8.95, 53.61875],
#       [8.95, 54.1125],
#       [9.575, 54.1125],
#       [9.575, 53.61875]]],
#     u'type': u'Polygon'},
#    u'id': 206,
#    u'properties': {u'name': 206},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[9.575, 53.125],
#       [9.575, 53.61875],
#       [10.2, 53.61875],
#       [10.2, 53.125]]],
#     u'type': u'Polygon'},
#    u'id': 207,
#    u'properties': {u'name': 207},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[9.575, 53.61875],
#       [9.575, 54.1125],
#       [10.2, 54.1125],
#       [10.2, 53.61875]]],
#     u'type': u'Polygon'},
#    u'id': 208,
#    u'properties': {u'name': 208},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[10.2, 48.1875],
#       [10.2, 48.681250000000006],
#       [10.825, 48.681250000000006],
#       [10.825, 48.1875]]],
#     u'type': u'Polygon'},
#    u'id': 217,
#    u'properties': {u'name': 217},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[10.2, 48.681250000000006],
#       [10.2, 49.175000000000004],
#       [10.825, 49.175000000000004],
#       [10.825, 48.681250000000006]]],
#     u'type': u'Polygon'},
#    u'id': 218,
#    u'properties': {u'name': 218},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[10.825, 48.1875],
#       [10.825, 48.681250000000006],
#       [11.45, 48.681250000000006],
#       [11.45, 48.1875]]],
#     u'type': u'Polygon'},
#    u'id': 219,
#    u'properties': {u'name': 219},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[10.825, 48.681250000000006],
#       [10.825, 49.175000000000004],
#       [11.45, 49.175000000000004],
#       [11.45, 48.681250000000006]]],
#     u'type': u'Polygon'},
#    u'id': 220,
#    u'properties': {u'name': 220},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[11.45, 48.1875],
#       [11.45, 48.681250000000006],
#       [12.075, 48.681250000000006],
#       [12.075, 48.1875]]],
#     u'type': u'Polygon'},
#    u'id': 225,
#    u'properties': {u'name': 225},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[11.45, 48.681250000000006],
#       [11.45, 49.175000000000004],
#       [12.075, 49.175000000000004],
#       [12.075, 48.681250000000006]]],
#     u'type': u'Polygon'},
#    u'id': 226,
#    u'properties': {u'name': 226},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[12.075, 48.1875],
#       [12.075, 48.681250000000006],
#       [12.7, 48.681250000000006],
#       [12.7, 48.1875]]],
#     u'type': u'Polygon'},
#    u'id': 227,
#    u'properties': {u'name': 227},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[12.075, 48.681250000000006],
#       [12.075, 49.175000000000004],
#       [12.7, 49.175000000000004],
#       [12.7, 48.681250000000006]]],
#     u'type': u'Polygon'},
#    u'id': 228,
#    u'properties': {u'name': 228},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[10.2, 49.175000000000004],
#       [10.2, 49.66875],
#       [10.825, 49.66875],
#       [10.825, 49.175000000000004]]],
#     u'type': u'Polygon'},
#    u'id': 229,
#    u'properties': {u'name': 229},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[10.2, 49.66875],
#       [10.2, 50.16250000000001],
#       [10.825, 50.16250000000001],
#       [10.825, 49.66875]]],
#     u'type': u'Polygon'},
#    u'id': 230,
#    u'properties': {u'name': 230},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[10.825, 49.66875],
#       [10.825, 50.16250000000001],
#       [11.45, 50.16250000000001],
#       [11.45, 49.66875]]],
#     u'type': u'Polygon'},
#    u'id': 232,
#    u'properties': {u'name': 232},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[10.2, 50.16250000000001],
#       [10.2, 50.65625000000001],
#       [10.825, 50.65625000000001],
#       [10.825, 50.16250000000001]]],
#     u'type': u'Polygon'},
#    u'id': 233,
#    u'properties': {u'name': 233},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[10.2, 50.65625000000001],
#       [10.2, 51.150000000000006],
#       [10.825, 51.150000000000006],
#       [10.825, 50.65625000000001]]],
#     u'type': u'Polygon'},
#    u'id': 234,
#    u'properties': {u'name': 234},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[10.825, 50.16250000000001],
#       [10.825, 50.65625000000001],
#       [11.45, 50.65625000000001],
#       [11.45, 50.16250000000001]]],
#     u'type': u'Polygon'},
#    u'id': 235,
#    u'properties': {u'name': 235},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[10.825, 50.65625000000001],
#       [10.825, 51.150000000000006],
#       [11.45, 51.150000000000006],
#       [11.45, 50.65625000000001]]],
#     u'type': u'Polygon'},
#    u'id': 236,
#    u'properties': {u'name': 236},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[11.45, 49.175000000000004],
#       [11.45, 49.66875],
#       [12.075, 49.66875],
#       [12.075, 49.175000000000004]]],
#     u'type': u'Polygon'},
#    u'id': 237,
#    u'properties': {u'name': 237},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[11.45, 49.66875],
#       [11.45, 50.16250000000001],
#       [12.075, 50.16250000000001],
#       [12.075, 49.66875]]],
#     u'type': u'Polygon'},
#    u'id': 238,
#    u'properties': {u'name': 238},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[12.075, 49.175000000000004],
#       [12.075, 49.66875],
#       [12.7, 49.66875],
#       [12.7, 49.175000000000004]]],
#     u'type': u'Polygon'},
#    u'id': 239,
#    u'properties': {u'name': 239},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[12.075, 49.66875],
#       [12.075, 50.16250000000001],
#       [12.7, 50.16250000000001],
#       [12.7, 49.66875]]],
#     u'type': u'Polygon'},
#    u'id': 240,
#    u'properties': {u'name': 240},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[11.45, 50.16250000000001],
#       [11.45, 50.65625000000001],
#       [12.075, 50.65625000000001],
#       [12.075, 50.16250000000001]]],
#     u'type': u'Polygon'},
#    u'id': 241,
#    u'properties': {u'name': 241},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[11.45, 50.65625000000001],
#       [11.45, 51.150000000000006],
#       [12.075, 51.150000000000006],
#       [12.075, 50.65625000000001]]],
#     u'type': u'Polygon'},
#    u'id': 242,
#    u'properties': {u'name': 242},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[12.075, 50.16250000000001],
#       [12.075, 50.65625000000001],
#       [12.7, 50.65625000000001],
#       [12.7, 50.16250000000001]]],
#     u'type': u'Polygon'},
#    u'id': 243,
#    u'properties': {u'name': 243},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[12.075, 50.65625000000001],
#       [12.075, 51.150000000000006],
#       [12.7, 51.150000000000006],
#       [12.7, 50.65625000000001]]],
#     u'type': u'Polygon'},
#    u'id': 244,
#    u'properties': {u'name': 244},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[10.2, 51.150000000000006],
#       [10.2, 51.643750000000004],
#       [10.825, 51.643750000000004],
#       [10.825, 51.150000000000006]]],
#     u'type': u'Polygon'},
#    u'id': 277,
#    u'properties': {u'name': 277},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[10.2, 51.643750000000004],
#       [10.2, 52.1375],
#       [10.825, 52.1375],
#       [10.825, 51.643750000000004]]],
#     u'type': u'Polygon'},
#    u'id': 278,
#    u'properties': {u'name': 278},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[10.825, 51.150000000000006],
#       [10.825, 51.643750000000004],
#       [11.45, 51.643750000000004],
#       [11.45, 51.150000000000006]]],
#     u'type': u'Polygon'},
#    u'id': 279,
#    u'properties': {u'name': 279},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[10.825, 51.643750000000004],
#       [10.825, 52.1375],
#       [11.45, 52.1375],
#       [11.45, 51.643750000000004]]],
#     u'type': u'Polygon'},
#    u'id': 280,
#    u'properties': {u'name': 280},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[11.45, 51.150000000000006],
#       [11.45, 51.643750000000004],
#       [12.075, 51.643750000000004],
#       [12.075, 51.150000000000006]]],
#     u'type': u'Polygon'},
#    u'id': 285,
#    u'properties': {u'name': 285},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[11.45, 51.643750000000004],
#       [11.45, 52.1375],
#       [12.075, 52.1375],
#       [12.075, 51.643750000000004]]],
#     u'type': u'Polygon'},
#    u'id': 286,
#    u'properties': {u'name': 286},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[12.075, 51.150000000000006],
#       [12.075, 51.643750000000004],
#       [12.7, 51.643750000000004],
#       [12.7, 51.150000000000006]]],
#     u'type': u'Polygon'},
#    u'id': 287,
#    u'properties': {u'name': 287},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[12.075, 51.643750000000004],
#       [12.075, 52.1375],
#       [12.7, 52.1375],
#       [12.7, 51.643750000000004]]],
#     u'type': u'Polygon'},
#    u'id': 288,
#    u'properties': {u'name': 288},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[12.7, 52.1375],
#       [12.7, 52.63125],
#       [13.325, 52.63125],
#       [13.325, 52.1375]]],
#     u'type': u'Polygon'},
#    u'id': 313,
#    u'properties': {u'name': 313},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[12.7, 52.63125],
#       [12.7, 53.125],
#       [13.325, 53.125],
#       [13.325, 52.63125]]],
#     u'type': u'Polygon'},
#    u'id': 314,
#    u'properties': {u'name': 314},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[13.325, 52.1375],
#       [13.325, 52.63125],
#       [13.95, 52.63125],
#       [13.95, 52.1375]]],
#     u'type': u'Polygon'},
#    u'id': 315,
#    u'properties': {u'name': 315},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[13.325, 52.63125],
#       [13.325, 53.125],
#       [13.95, 53.125],
#       [13.95, 52.63125]]],
#     u'type': u'Polygon'},
#    u'id': 316,
#    u'properties': {u'name': 316},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[6.449999999999999, 50.65625000000001],
#       [6.449999999999999, 50.903125],
#       [6.762499999999999, 50.903125],
#       [6.762499999999999, 50.65625000000001]]],
#     u'type': u'Polygon'},
#    u'id': 457,
#    u'properties': {u'name': 457},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[6.449999999999999, 50.903125],
#       [6.449999999999999, 51.150000000000006],
#       [6.762499999999999, 51.150000000000006],
#       [6.762499999999999, 50.903125]]],
#     u'type': u'Polygon'},
#    u'id': 458,
#    u'properties': {u'name': 458},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[6.762499999999999, 50.65625000000001],
#       [6.762499999999999, 50.903125],
#       [7.074999999999999, 50.903125],
#       [7.074999999999999, 50.65625000000001]]],
#     u'type': u'Polygon'},
#    u'id': 459,
#    u'properties': {u'name': 459},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[7.074999999999999, 50.16250000000001],
#       [7.074999999999999, 50.40937500000001],
#       [7.387499999999999, 50.40937500000001],
#       [7.387499999999999, 50.16250000000001]]],
#     u'type': u'Polygon'},
#    u'id': 461,
#    u'properties': {u'name': 461},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[7.074999999999999, 50.40937500000001],
#       [7.074999999999999, 50.65625000000001],
#       [7.387499999999999, 50.65625000000001],
#       [7.387499999999999, 50.40937500000001]]],
#     u'type': u'Polygon'},
#    u'id': 462,
#    u'properties': {u'name': 462},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[7.387499999999999, 50.16250000000001],
#       [7.387499999999999, 50.40937500000001],
#       [7.699999999999999, 50.40937500000001],
#       [7.699999999999999, 50.16250000000001]]],
#     u'type': u'Polygon'},
#    u'id': 463,
#    u'properties': {u'name': 463},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[7.387499999999999, 50.40937500000001],
#       [7.387499999999999, 50.65625000000001],
#       [7.699999999999999, 50.65625000000001],
#       [7.699999999999999, 50.40937500000001]]],
#     u'type': u'Polygon'},
#    u'id': 464,
#    u'properties': {u'name': 464},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[8.325, 48.681250000000006],
#       [8.325, 48.92812500000001],
#       [8.6375, 48.92812500000001],
#       [8.6375, 48.681250000000006]]],
#     u'type': u'Polygon'},
#    u'id': 497,
#    u'properties': {u'name': 497},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[8.325, 48.92812500000001],
#       [8.325, 49.175000000000004],
#       [8.6375, 49.175000000000004],
#       [8.6375, 48.92812500000001]]],
#     u'type': u'Polygon'},
#    u'id': 498,
#    u'properties': {u'name': 498},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[8.6375, 48.681250000000006],
#       [8.6375, 48.92812500000001],
#       [8.95, 48.92812500000001],
#       [8.95, 48.681250000000006]]],
#     u'type': u'Polygon'},
#    u'id': 499,
#    u'properties': {u'name': 499},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[8.6375, 48.92812500000001],
#       [8.6375, 49.175000000000004],
#       [8.95, 49.175000000000004],
#       [8.95, 48.92812500000001]]],
#     u'type': u'Polygon'},
#    u'id': 500,
#    u'properties': {u'name': 500},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[8.95, 48.681250000000006],
#       [8.95, 48.92812500000001],
#       [9.2625, 48.92812500000001],
#       [9.2625, 48.681250000000006]]],
#     u'type': u'Polygon'},
#    u'id': 521,
#    u'properties': {u'name': 521},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[8.95, 48.92812500000001],
#       [8.95, 49.175000000000004],
#       [9.2625, 49.175000000000004],
#       [9.2625, 48.92812500000001]]],
#     u'type': u'Polygon'},
#    u'id': 522,
#    u'properties': {u'name': 522},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[9.2625, 48.681250000000006],
#       [9.2625, 48.92812500000001],
#       [9.575, 48.92812500000001],
#       [9.575, 48.681250000000006]]],
#     u'type': u'Polygon'},
#    u'id': 523,
#    u'properties': {u'name': 523},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[9.2625, 48.92812500000001],
#       [9.2625, 49.175000000000004],
#       [9.575, 49.175000000000004],
#       [9.575, 48.92812500000001]]],
#     u'type': u'Polygon'},
#    u'id': 524,
#    u'properties': {u'name': 524},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[9.575, 48.1875],
#       [9.575, 48.434375],
#       [9.8875, 48.434375],
#       [9.8875, 48.1875]]],
#     u'type': u'Polygon'},
#    u'id': 525,
#    u'properties': {u'name': 525},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[9.575, 48.434375],
#       [9.575, 48.681250000000006],
#       [9.8875, 48.681250000000006],
#       [9.8875, 48.434375]]],
#     u'type': u'Polygon'},
#    u'id': 526,
#    u'properties': {u'name': 526},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[9.8875, 48.1875],
#       [9.8875, 48.434375],
#       [10.2, 48.434375],
#       [10.2, 48.1875]]],
#     u'type': u'Polygon'},
#    u'id': 527,
#    u'properties': {u'name': 527},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[9.8875, 48.434375],
#       [9.8875, 48.681250000000006],
#       [10.2, 48.681250000000006],
#       [10.2, 48.434375]]],
#     u'type': u'Polygon'},
#    u'id': 528,
#    u'properties': {u'name': 528},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[7.699999999999999, 49.66875],
#       [7.699999999999999, 49.915625000000006],
#       [8.0125, 49.915625000000006],
#       [8.0125, 49.66875]]],
#     u'type': u'Polygon'},
#    u'id': 537,
#    u'properties': {u'name': 537},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[7.699999999999999, 49.915625000000006],
#       [7.699999999999999, 50.16250000000001],
#       [8.0125, 50.16250000000001],
#       [8.0125, 49.915625000000006]]],
#     u'type': u'Polygon'},
#    u'id': 538,
#    u'properties': {u'name': 538},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[8.0125, 49.66875],
#       [8.0125, 49.915625000000006],
#       [8.325, 49.915625000000006],
#       [8.325, 49.66875]]],
#     u'type': u'Polygon'},
#    u'id': 539,
#    u'properties': {u'name': 539},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[8.0125, 49.915625000000006],
#       [8.0125, 50.16250000000001],
#       [8.325, 50.16250000000001],
#       [8.325, 49.915625000000006]]],
#     u'type': u'Polygon'},
#    u'id': 540,
#    u'properties': {u'name': 540},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[8.325, 49.175000000000004],
#       [8.325, 49.421875],
#       [8.6375, 49.421875],
#       [8.6375, 49.175000000000004]]],
#     u'type': u'Polygon'},
#    u'id': 541,
#    u'properties': {u'name': 541},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[8.325, 49.421875],
#       [8.325, 49.66875],
#       [8.6375, 49.66875],
#       [8.6375, 49.421875]]],
#     u'type': u'Polygon'},
#    u'id': 542,
#    u'properties': {u'name': 542},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[8.6375, 49.175000000000004],
#       [8.6375, 49.421875],
#       [8.95, 49.421875],
#       [8.95, 49.175000000000004]]],
#     u'type': u'Polygon'},
#    u'id': 543,
#    u'properties': {u'name': 543},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[8.6375, 49.421875],
#       [8.6375, 49.66875],
#       [8.95, 49.66875],
#       [8.95, 49.421875]]],
#     u'type': u'Polygon'},
#    u'id': 544,
#    u'properties': {u'name': 544},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[8.325, 49.66875],
#       [8.325, 49.915625000000006],
#       [8.6375, 49.915625000000006],
#       [8.6375, 49.66875]]],
#     u'type': u'Polygon'},
#    u'id': 545,
#    u'properties': {u'name': 545},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[8.325, 49.915625000000006],
#       [8.325, 50.16250000000001],
#       [8.6375, 50.16250000000001],
#       [8.6375, 49.915625000000006]]],
#     u'type': u'Polygon'},
#    u'id': 546,
#    u'properties': {u'name': 546},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[8.6375, 49.66875],
#       [8.6375, 49.915625000000006],
#       [8.95, 49.915625000000006],
#       [8.95, 49.66875]]],
#     u'type': u'Polygon'},
#    u'id': 547,
#    u'properties': {u'name': 547},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[8.6375, 49.915625000000006],
#       [8.6375, 50.16250000000001],
#       [8.95, 50.16250000000001],
#       [8.95, 49.915625000000006]]],
#     u'type': u'Polygon'},
#    u'id': 548,
#    u'properties': {u'name': 548},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[8.325, 50.16250000000001],
#       [8.325, 50.40937500000001],
#       [8.6375, 50.40937500000001],
#       [8.6375, 50.16250000000001]]],
#     u'type': u'Polygon'},
#    u'id': 557,
#    u'properties': {u'name': 557},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[8.325, 50.40937500000001],
#       [8.325, 50.65625000000001],
#       [8.6375, 50.65625000000001],
#       [8.6375, 50.40937500000001]]],
#     u'type': u'Polygon'},
#    u'id': 558,
#    u'properties': {u'name': 558},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[8.6375, 50.16250000000001],
#       [8.6375, 50.40937500000001],
#       [8.95, 50.40937500000001],
#       [8.95, 50.16250000000001]]],
#     u'type': u'Polygon'},
#    u'id': 559,
#    u'properties': {u'name': 559},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[8.6375, 50.40937500000001],
#       [8.6375, 50.65625000000001],
#       [8.95, 50.65625000000001],
#       [8.95, 50.40937500000001]]],
#     u'type': u'Polygon'},
#    u'id': 560,
#    u'properties': {u'name': 560},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[6.449999999999999, 51.150000000000006],
#       [6.449999999999999, 51.39687500000001],
#       [6.762499999999999, 51.39687500000001],
#       [6.762499999999999, 51.150000000000006]]],
#     u'type': u'Polygon'},
#    u'id': 629,
#    u'properties': {u'name': 629},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[6.449999999999999, 51.39687500000001],
#       [6.449999999999999, 51.643750000000004],
#       [6.762499999999999, 51.643750000000004],
#       [6.762499999999999, 51.39687500000001]]],
#     u'type': u'Polygon'},
#    u'id': 630,
#    u'properties': {u'name': 630},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[6.762499999999999, 51.39687500000001],
#       [6.762499999999999, 51.643750000000004],
#       [7.074999999999999, 51.643750000000004],
#       [7.074999999999999, 51.39687500000001]]],
#     u'type': u'Polygon'},
#    u'id': 632,
#    u'properties': {u'name': 632},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[7.074999999999999, 51.150000000000006],
#       [7.074999999999999, 51.39687500000001],
#       [7.387499999999999, 51.39687500000001],
#       [7.387499999999999, 51.150000000000006]]],
#     u'type': u'Polygon'},
#    u'id': 637,
#    u'properties': {u'name': 637},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[7.074999999999999, 51.39687500000001],
#       [7.074999999999999, 51.643750000000004],
#       [7.387499999999999, 51.643750000000004],
#       [7.387499999999999, 51.39687500000001]]],
#     u'type': u'Polygon'},
#    u'id': 638,
#    u'properties': {u'name': 638},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[7.387499999999999, 51.150000000000006],
#       [7.387499999999999, 51.39687500000001],
#       [7.699999999999999, 51.39687500000001],
#       [7.699999999999999, 51.150000000000006]]],
#     u'type': u'Polygon'},
#    u'id': 639,
#    u'properties': {u'name': 639},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[10.825, 49.175000000000004],
#       [10.825, 49.421875],
#       [11.1375, 49.421875],
#       [11.1375, 49.175000000000004]]],
#     u'type': u'Polygon'},
#    u'id': 925,
#    u'properties': {u'name': 925},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[10.825, 49.421875],
#       [10.825, 49.66875],
#       [11.1375, 49.66875],
#       [11.1375, 49.421875]]],
#     u'type': u'Polygon'},
#    u'id': 926,
#    u'properties': {u'name': 926},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[11.1375, 49.175000000000004],
#       [11.1375, 49.421875],
#       [11.45, 49.421875],
#       [11.45, 49.175000000000004]]],
#     u'type': u'Polygon'},
#    u'id': 927,
#    u'properties': {u'name': 927},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[11.1375, 49.421875],
#       [11.1375, 49.66875],
#       [11.45, 49.66875],
#       [11.45, 49.421875]]],
#     u'type': u'Polygon'},
#    u'id': 928,
#    u'properties': {u'name': 928},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[6.762499999999999, 50.903125],
#       [6.762499999999999, 51.026562500000004],
#       [6.918749999999999, 51.026562500000004],
#       [6.918749999999999, 50.903125]]],
#     u'type': u'Polygon'},
#    u'id': 1841,
#    u'properties': {u'name': 1841},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[6.762499999999999, 51.026562500000004],
#       [6.762499999999999, 51.150000000000006],
#       [6.918749999999999, 51.150000000000006],
#       [6.918749999999999, 51.026562500000004]]],
#     u'type': u'Polygon'},
#    u'id': 1842,
#    u'properties': {u'name': 1842},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[6.918749999999999, 50.903125],
#       [6.918749999999999, 51.026562500000004],
#       [7.074999999999999, 51.026562500000004],
#       [7.074999999999999, 50.903125]]],
#     u'type': u'Polygon'},
#    u'id': 1843,
#    u'properties': {u'name': 1843},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[6.918749999999999, 51.026562500000004],
#       [6.918749999999999, 51.150000000000006],
#       [7.074999999999999, 51.150000000000006],
#       [7.074999999999999, 51.026562500000004]]],
#     u'type': u'Polygon'},
#    u'id': 1844,
#    u'properties': {u'name': 1844},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[6.762499999999999, 51.150000000000006],
#       [6.762499999999999, 51.27343750000001],
#       [6.918749999999999, 51.27343750000001],
#       [6.918749999999999, 51.150000000000006]]],
#     u'type': u'Polygon'},
#    u'id': 2525,
#    u'properties': {u'name': 2525},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[6.762499999999999, 51.27343750000001],
#       [6.762499999999999, 51.39687500000001],
#       [6.918749999999999, 51.39687500000001],
#       [6.918749999999999, 51.27343750000001]]],
#     u'type': u'Polygon'},
#    u'id': 2526,
#    u'properties': {u'name': 2526},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[6.918749999999999, 51.150000000000006],
#       [6.918749999999999, 51.27343750000001],
#       [7.074999999999999, 51.27343750000001],
#       [7.074999999999999, 51.150000000000006]]],
#     u'type': u'Polygon'},
#    u'id': 2527,
#    u'properties': {u'name': 2527},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[6.918749999999999, 51.27343750000001],
#       [6.918749999999999, 51.39687500000001],
#       [7.074999999999999, 51.39687500000001],
#       [7.074999999999999, 51.27343750000001]]],
#     u'type': u'Polygon'},
#    u'id': 2528,
#    u'properties': {u'name': 2528},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[7.387499999999999, 51.39687500000001],
#       [7.387499999999999, 51.5203125],
#       [7.543749999999999, 51.5203125],
#       [7.543749999999999, 51.39687500000001]]],
#     u'type': u'Polygon'},
#    u'id': 2561,
#    u'properties': {u'name': 2561},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[7.387499999999999, 51.5203125],
#       [7.387499999999999, 51.643750000000004],
#       [7.543749999999999, 51.643750000000004],
#       [7.543749999999999, 51.5203125]]],
#     u'type': u'Polygon'},
#    u'id': 2562,
#    u'properties': {u'name': 2562},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[7.543749999999999, 51.39687500000001],
#       [7.543749999999999, 51.5203125],
#       [7.699999999999999, 51.5203125],
#       [7.699999999999999, 51.39687500000001]]],
#     u'type': u'Polygon'},
#    u'id': 2563,
#    u'properties': {u'name': 2563},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[7.543749999999999, 51.5203125],
#       [7.543749999999999, 51.643750000000004],
#       [7.699999999999999, 51.643750000000004],
#       [7.699999999999999, 51.5203125]]],
#     u'type': u'Polygon'},
#    u'id': 2564,
#    u'properties': {u'name': 2564},
#    u'type': u'Feature'}],
#  u'type': u'FeatureCollection'}

# %%
m = folium.Map([51, 9.], tiles='cartodbpositron', zoom_start=6)
folium.GeoJson(myJSON).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Kriging on DWD
# 1. Read observations into a RDD from DWD as files
# 2. Parse and select the observations from a specific date and time
# 3. Assign the selected observations to a partition created before
# 4. Run kriging on each partition in parallel
# 5. Plot the result using foliium

# %% [markdown]
# ## Read data from DWD

# %%
#sc = ss.sparkContext
# Read DWD Observations with some preprocessing to eliminate invalid data 
## ChangeME
dwdRdd = sc.wholeTextFiles(Helper.Helper.DWDData).flatMap(lambda (k,v):v.split("\n")).cache()
#dwdDf = ss.read.format("csv").load("data/DWDResult/xaa")
dwdRdd1516 = dwdRdd.filter(lambda x: len(x[1:-1].split(","))==6).cache()
dwdRdd1516 = dwdRdd1516.filter(lambda x: x[1:-1].split(",")[1][2:6]=="2015" or x[1:-1].split(",")[1][2:6]=="2016").cache()

# %%
dwdRdd1516 = dwdRdd1516.map(lambda x: x[1:-1].replace("'","").split(",")).cache()
from pyspark.sql.types import Row
def f(x):
    d = {}
    d["ID"] = x[0]
    d["Date"] = x[1].strip()
    d["Time"] = x[2].strip()
    d["Latitude"] = float(x[3].strip())
    d["Longitude"] = float(x[4].strip())
    d["AirTemperature"] = float(x[5].strip())
    return d
dwdDf = dwdRdd1516.map(lambda x: Row(**f(x))).toDF()

# %% [markdown]
# ## Select the observations from a specific date and time

# %%
dwdDf.createOrReplaceTempView("table1")
smalldf = ss.sql("select * from table1 where Time = '{1}' and Date = '{0}'".format(dateStr, timeStr)).cache()

# %%
## Convert to Pandas DF

# %%
cols = ["AirTemperature","Date","ID","Latitude","Longitude","Time"]
aDF =pd.DataFrame.from_records(smalldf.rdd.collect(), columns = cols)

# %%
def assignToTile(latlon):
    for aIndex in tileTable.index:
        if(latlon[0] >= tileTable.loc[aIndex,"Latitude"]["min"]
           and latlon[0] <= tileTable.loc[aIndex,"Latitude"]["max"]
           and latlon[1] >= tileTable.loc[aIndex,"Longitude"]["min"]
           and latlon[1] <= tileTable.loc[aIndex,"Longitude"]["max"]):
            return int(aIndex)
aDF.loc[:,"key"] = aDF.loc[:,"Latitude"].map(lambda x: [x])+aDF.loc[:,"Longitude"].map(lambda x: [x])
#tempDf["idx"] = tempDf["idx"].map(assignToTile2)
aDF.loc[:,"key"] = aDF.loc[:,"key"].map(assignToTile)

# %% [markdown]
# ## Assign the observations to partitions according the result of the partitioning

# %%
# A list to store the kriging result
sTotalResult = []
# A list of the tuple of WG-Observations, DWD-Observations, each tuple represents a partition
krigingPairs = []
for aIndex in tileTable.index.values:
    
    #aIndex = tileTable.index.values[0]
    aKnownPoints = observations.loc[observations.key == aIndex,["Latitude","Longitude","AirTemperature"]].dropna()
    aKrigingGrid = aDF.loc[aDF.key == aIndex,["Latitude","Longitude"]].apply(pd.to_numeric,errors="coerce")
    #aKrigingGrid["Observations"] =aDF.loc[aDF.key == aIndex,"AirTemperature"]
    krigingPairs.append((aKnownPoints,aKrigingGrid))

# %% [markdown]
# ## Distribute the PandasDF across the cluster and run Kriging in parallel

# %%
krigingPairsRdd = ss.sparkContext.parallelize(krigingPairs)
def paralKriging(v):
    import pandas
    from sklearn.gaussian_process import GaussianProcessRegressor
    from sklearn.gaussian_process.kernels import Matern
    aKnownPoints = v[0]
    aKrigingGrid = v[1]
    if( len(aKnownPoints) > 2 and len(aKrigingGrid) > 0):
        kernel =   Matern(1.0, (1e-2, 1e-1))

        gp = GaussianProcessRegressor(kernel=kernel,n_restarts_optimizer=30)#,  normalize_y=True)
        gp.fit(aKnownPoints.values[:,0:2], aKnownPoints.values[:,2])

        y_pred,sigma = gp.predict(aKrigingGrid.values[:,0:2], return_std=True)
        aKrigingGrid["y_pred"] = y_pred
        aKrigingGrid["sigma"] = sigma
        return aKrigingGrid
    
krigingPairsRdd = krigingPairsRdd.map(paralKriging)

# %%
sTotalResultPd = pd.concat(krigingPairsRdd.collect())
sTotalResultPdSorted = sTotalResultPd.sort_index()
#sTotalResultPdSorted.loc[:,"y_pred"].loc[0]

# %%
sTotalResultPdSorted_WithObs = sTotalResultPdSorted
sTotalResultPdSorted_WithObs["Observations"] = aDF["AirTemperature"]
sTotalResultPdSorted_WithObs["ID"] = aDF["ID"]
#sTotalResultPdSorted_WithObs

# %%
sTotalResultPdSorted_WithObs.values[1]
# Out:
# array([47.8741, 8.0044, 3.658621455351808, 0.8261662994030426, 0.6,
#        u'01346'], dtype=object)

# %%
data = sTotalResultPdSorted_WithObs.values[:,0:3].tolist()
from folium.plugins import HeatMap

m = folium.Map([48., 5.], tiles='stamentoner', zoom_start=6)

HeatMap(data).add_to(m)


m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m = folium.Map([51, 9.], tiles='cartodbpositron', zoom_start=6)
for aRow in sTotalResultPdSorted_WithObs.values:
    folium.map.Marker(
        [aRow[0], aRow[1]],
                    popup='ID:{0},Obs:{1},Pred:{2}.'.format(aRow[5],aRow[4],aRow[2])).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Kriging + Visualization
# 1. Load deutschLandGeoJSON
# 2. Calculate the centroid of each json
# 3. Assign centroids to partitioned tiles
# 4. Apply Kriging in different partitions to predict the air temperature of each centroid in parallel
# 5. Use the predictions to represent the air temperature of each geojson and plot the result with Folium

# %%
#fname = "./deutschlandGeoJSON/1_deutschland/4_niedrig.geojson"
#fname = "./deutschlandGeoJSON/2_bundeslaender/4_niedrig.geojson"
#fname = "./deutschlandGeoJSON/3_regierungsbezirke/4_niedrig.geojson"
## ChangeME
fname = Helper.Helper.DeutschlandJSON+"/deutschlandGeoJSON/4_kreise/4_niedrig.geojson"
#fname = "./deutschlandGeoJSON/4_kreise/2_hoch.geojson"
deutschLandGeoJSON = json.loads(open(fname).read())

# %%
for aJSON in deutschLandGeoJSON['features']:
    #print(np.asarray(aJSON['geometry']['coordinates'][0]).shape)
    #print(aJSON['id'])
    if(len(np.asarray(aJSON['geometry']['coordinates'][0]).shape) != 2):
        aJSON[u'centroid'] = [np.asarray(aJSON['geometry']['coordinates'][0][0])[:,0].mean(),np.asarray(aJSON['geometry']['coordinates'][0][0])[:,1].mean()]
    else:
        aJSON[u'centroid'] = [np.asarray(aJSON['geometry']['coordinates'][0])[:,0].mean(),np.asarray(aJSON['geometry']['coordinates'][0])[:,1].mean()]
    
    #print(aJSON[u'id'],aJSON[u'centroid'][1],aJSON[u'centroid'][0])

# %%
deutschLandGeoJSONRdd = ss.sparkContext.parallelize(deutschLandGeoJSON['features'])

def addCentroid(aGeoJSON):
    import numpy as np
    if(len(np.asarray(aGeoJSON['geometry']['coordinates'][0]).shape) != 2):
        aGeoJSON[u'centroid'] = [np.asarray(aGeoJSON['geometry']['coordinates'][0][0])[:,0].mean(),np.asarray(aGeoJSON['geometry']['coordinates'][0][0])[:,1].mean()]
    else:
        aGeoJSON[u'centroid'] = [np.asarray(aGeoJSON['geometry']['coordinates'][0])[:,0].mean(),np.asarray(aGeoJSON['geometry']['coordinates'][0])[:,1].mean()]

    return (aGeoJSON[u'id'],aGeoJSON[u'centroid'][1],aGeoJSON[u'centroid'][0])

krigingGrid = deutschLandGeoJSONRdd.map(addCentroid).collect()
cols = ["Id","Latitude","Longitude"]
krigingGridDF = pd.DataFrame.from_records(krigingGrid, columns = cols)

# %%
def assignToTile(latlon):
    for aIndex in tileTable.index:
        if(latlon[0] >= tileTable.loc[aIndex,"Latitude"]["min"]
           and latlon[0] <= tileTable.loc[aIndex,"Latitude"]["max"]
           and latlon[1] >= tileTable.loc[aIndex,"Longitude"]["min"]
           and latlon[1] <= tileTable.loc[aIndex,"Longitude"]["max"]):
            return int(aIndex)
krigingGridDF.loc[:,"key"] = krigingGridDF.loc[:,"Latitude"].map(lambda x: [x])+krigingGridDF.loc[:,"Longitude"].map(lambda x: [x])
#tempDf["idx"] = tempDf["idx"].map(assignToTile2)
krigingGridDF.loc[:,"key"] = krigingGridDF.loc[:,"key"].map(assignToTile)

# %% [markdown]
# ### Parallel with spark

# %%
sTotalResult = []
krigingPairs = []
for aIndex in tileTable.index.values:
    
    #aIndex = tileTable.index.values[0]
    aKnownPoints = observations.loc[observations.key == aIndex,["Latitude","Longitude","AirTemperature"]].dropna()
    aKrigingGrid = krigingGridDF.loc[krigingGridDF.key == aIndex,["Latitude","Longitude"]].apply(pd.to_numeric,errors="coerce")
    krigingPairs.append((aKnownPoints,aKrigingGrid))
krigingPairsRdd = ss.sparkContext.parallelize(krigingPairs)

# %%
def paralKriging(v):
    import pandas
    from sklearn.gaussian_process import GaussianProcessRegressor
    from sklearn.gaussian_process.kernels import Matern
    aKnownPoints = v[0]
    aKrigingGrid = v[1]
    if( len(aKnownPoints) > 2 and len(aKrigingGrid) > 0):
        kernel =   Matern(1.0, (1e-2, 1e-1))

        gp = GaussianProcessRegressor(kernel=kernel,n_restarts_optimizer=30)#,  normalize_y=True)
        gp.fit(aKnownPoints.values[:,0:2], aKnownPoints.values[:,2])

        y_pred,sigma = gp.predict(aKrigingGrid.values[:,0:2], return_std=True)
        aKrigingGrid.shape
        aKrigingGrid["y_pred"] = y_pred
        aKrigingGrid["sigma"] = sigma
        return aKrigingGrid
    
krigingPairsRdd = krigingPairsRdd.map(paralKriging)

# %%
sTotalResultPd = pd.concat(krigingPairsRdd.collect())
sTotalResultPdSorted = sTotalResultPd.sort_index()
#sTotalResultPdSorted.loc[:,"y_pred"].loc[0]

# %%
sTotalResultPdSorted

# %% [markdown]
# ## Visualization with Folium

# %%
## sTotalResultPdSorted.loc[:,"y_pred"].values.min()


import branca.colormap as cm
linearCM = cm.LinearColormap(
    ['purple','blue','green','red','black'],
    index = [-7,0,5,10,21.5],
    vmin=-7, vmax=19
)

linearCM.caption="Air Temperature"

# %%
m = folium.Map([51, 9.], tiles='cartodbpositron', zoom_start=6)
folium.GeoJson(deutschLandGeoJSON,
              style_function=lambda feature: {
        'fillColor': linearCM(sTotalResultPdSorted.loc[:,"y_pred"].loc[feature['id']]),
        'color': 'black',
        'weight': 1
    }).add_to(m)
m.add_child(linearCM)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
