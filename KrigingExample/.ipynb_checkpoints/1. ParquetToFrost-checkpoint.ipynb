# %% [markdown]
# ## Parquet to SensorThings

# %%
import csv
import re
import math
import time
import random
import numpy as np
import sys
import json
import requests

# %%
from pyspark.sql import SparkSession
from pyspark.conf import SparkConf
#spark conf
conf = ( SparkConf()
         .setMaster("local[*]")
         .setAppName('pyspark')
        )
ss = SparkSession.builder.config(conf=conf).getOrCreate()
sc = ss.sparkContext

# %%
inputDir = "./out/outAllSortByTimeStampAndIDBig/TimeStamp=20150128/"
dataFileDF = ss.read.option("basepath",inputDir).parquet(inputDir)#+"TimeStamp=20160504/ID=I72406BI1")
dataFileDF = dataFileDF.withColumnRenamed("AitTemperature","AirTemperature")

# %%
#Date|    Time|Latitude|Longitude|AitTemperature|Humidity|AirPressure|       ID
dataFileDF.show(10)
# Out:
# +----------+--------+--------+---------+--------------+--------+-----------+---------+
# |      Date|    Time|Latitude|Longitude|AirTemperature|Humidity|AirPressure|       ID|
# +----------+--------+--------+---------+--------------+--------+-----------+---------+
# |2015-01-28|11:45:00|  48.961|    8.577|           5.1|      81|     1011.7|IKNIGSBA9|
# |2015-01-28|12:25:00|  48.961|    8.577|           5.7|      76|     1010.7|IKNIGSBA9|
# |2015-01-28|13:05:00|  48.961|    8.577|           5.8|      75|     1009.4|IKNIGSBA9|
# |2015-01-28|13:45:00|  48.961|    8.577|           5.7|      75|     1008.4|IKNIGSBA9|
# |2015-01-28|15:06:00|  48.961|    8.577|           6.0|      73|     1006.0|IKNIGSBA9|
# |2015-01-28|15:46:00|  48.961|    8.577|           5.8|      72|     1005.0|IKNIGSBA9|
# |2015-01-28|09:04:00|  48.961|    8.577|           2.5|      92|     1014.1|IKNIGSBA9|
# |2015-01-28|09:45:00|  48.961|    8.577|           2.9|      90|     1013.4|IKNIGSBA9|
# |2015-01-28|10:25:00|  48.961|    8.577|           3.6|      86|     1013.1|IKNIGSBA9|
# |2015-01-28|11:05:00|  48.961|    8.577|           4.4|      85|     1012.4|IKNIGSBA9|
# +----------+--------+--------+---------+--------------+--------+-----------+---------+
# only showing top 10 rows

# %%
idDF = dataFileDF["ID","Latitude","Longitude"]
from pyspark.sql import functions as F



idDF = idDF.withColumn("LatLon",F.array("Latitude","Longitude"))
idDF = idDF.groupBy(idDF.ID).agg(F.first(idDF.LatLon).alias("LatLon"))

idDF = idDF.withColumn("DSUID",F.format_string("Datastream-uid-%s",idDF.ID))
idDF = idDF.withColumn("FoIUID",F.format_string("FoI-uid-%s",idDF.ID))
idDF = idDF.withColumn("SensorUID",F.format_string("Sensor-uid-%s",idDF.ID))

idDF.show()
# Out:
# +---------+----------------+--------------------+-----------------+--------------------+
# |       ID|          LatLon|               DSUID|           FoIUID|           SensorUID|
# +---------+----------------+--------------------+-----------------+--------------------+
# |IKNIGSBA9| [48.961, 8.577]|Datastream-uid-IK...|FoI-uid-IKNIGSBA9|Sensor-uid-IKNIGSBA9|
# |IKNIGSBA6| [48.964, 8.616]|Datastream-uid-IK...|FoI-uid-IKNIGSBA6|Sensor-uid-IKNIGSBA6|
# |IKNIGSEG2| [47.928, 9.419]|Datastream-uid-IK...|FoI-uid-IKNIGSEG2|Sensor-uid-IKNIGSEG2|
# |IKNIGSBA8| [48.965, 8.646]|Datastream-uid-IK...|FoI-uid-IKNIGSBA8|Sensor-uid-IKNIGSBA8|
# |IKNIGSBR2|[48.256, 10.887]|Datastream-uid-IK...|FoI-uid-IKNIGSBR2|Sensor-uid-IKNIGSBR2|
# |IKNIGSBO2|[52.136, 11.770]|Datastream-uid-IK...|FoI-uid-IKNIGSBO2|Sensor-uid-IKNIGSBO2|
# +---------+----------------+--------------------+-----------------+--------------------+

# %% [markdown]
# ## Thing

# %%
idDF = dataFileDF["ID","Latitude","Longitude"]
from pyspark.sql import functions as F
idDF = idDF.withColumn("LatLon",F.array("Latitude","Longitude"))
idDF = idDF.groupBy(idDF.ID).agg(F.first(idDF.LatLon).alias("LatLon"))
urlHome = 'http://smartaqnet-dev.teco.edu:8080/FROST-Server/v1.0'
#urlHome = 'http://smartaqnet.teco.edu:8080/FROST-Server/v1.0'
urlThings = urlHome + '/Things'

# %%
urlThings
# Out:
# 'http://smartaqnet-dev.teco.edu:8080/FROST-Server/v1.0/Things'

# %%
row = idDF.collect()[0]
data =  {
        "name": "DWD-Sensor-" + row.ID,
        "description": "This is DWD-Sensor-" + row.ID,
        "@iot.id": "002" + row.ID,
    "Locations": [
    {
        "name":"Location-DWD-Sensor-"+row.ID,
        "description": "This is the location of DWD-Sensor-" + row.ID,
        "encodingType": "application/vnd.geo+json",
        "location": {
          "type": "Point",
          "coordinates": [float(row.LatLon[0]), float(row.LatLon[1])]
        },
        "@iot.id": "GGLocation-DWD-Sensor/" + row.ID 
    }
  ]
    }
p = requests.post(urlThings, json.dumps(data))
if (p.status_code  == 201):
    print(201)
else:
    print("Error:", p.status_code)
    
for chunk in p.iter_content(chunk_size=128):
    print(chunk)
# Out:
# 201

# %% [markdown]
# ## Sensor

# %%
idDF = dataFileDF["ID","Latitude","Longitude"]
from pyspark.sql import functions as F
idDF = idDF.withColumn("LatLon",F.array("Latitude","Longitude"))
idDF = idDF.groupBy(idDF.ID).agg(F.first(idDF.LatLon).alias("LatLon"))
#urlHome = 'http://smartaqnet-dev.teco.edu:8080/FROST-Server/v1.0'
urlThings = urlHome + '/Sensors'

# %%
row = idDF.collect()[1]
mytypes = ["Temperature","Humidity","Pressure"]
deviceAddr = "https://www.wunderground.com/personal-weather-station/dashboard?ID="+row.ID
for mytype in mytypes:
    data = {
        "name": "GG-DWD-Sensor/" + row.ID,
        "description": "This is a Sensor from Netatmo Weather Station",
        "encodingType": "application/pdf",
        "metadata": deviceAddr,
        "@iot.id": "GG-DWD-Sensor-"+ mytype +"/" + row.ID
    }
    p = requests.post(urlThings, json.dumps(data))
    if (p.status_code  == 201):
        print(201)
    else:
        print("Error:", p.status_code)

    for chunk in p.iter_content(chunk_size=128):
        print(chunk)
# Out:
# ('Error:', 500)
# Failed to store data.
# ('Error:', 500)
# Failed to store data.
# ('Error:', 500)
# Failed to store data.

# %% [markdown]
# ## ObservedProperty

# %%
idDF = dataFileDF["ID","Latitude","Longitude"]
from pyspark.sql import functions as F
idDF = idDF.withColumn("LatLon",F.array("Latitude","Longitude"))
idDF = idDF.groupBy(idDF.ID).agg(F.first(idDF.LatLon).alias("LatLon"))

# %%
#urlHome = 'http://smartaqnet-dev.teco.edu:8080/FROST-Server/v1.0'
urlObservedProperty = urlHome + '/ObservedProperties'
data ={
    "name": "Area Temperature",
    "description": "The degree or intensity of heat present in the area",
    "definition": "http://www.qudt.org/qudt/owl/1.0.0/quantity/Instances.html#AreaTemperature",
    "@iot.id": "Area Temperature"
}
p = requests.post(urlObservedProperty, json.dumps(data))
if (p.status_code  == 201):
    print(201)
else:
    print("Error:", p.status_code)

for chunk in p.iter_content(chunk_size=128):
    print(chunk)
# Out:
# 201

# %% [markdown]
# ## Datastream

# %%
idDF = dataFileDF["ID","Latitude","Longitude"]
from pyspark.sql import functions as F
idDF = idDF.withColumn("LatLon",F.array("Latitude","Longitude"))
idDF = idDF.groupBy(idDF.ID).agg(F.first(idDF.LatLon).alias("LatLon"))
row = idDF.collect()[1]
#urlHome = 'http://smartaqnet.teco.edu:8080/FROST-Server/v1.0'
#urlHome = 'http://smartaqnet-dev.teco.edu:8080/FROST-Server/v1.0'
urlDataStream = urlHome + '/Datastreams'
data = {
  "name": "Air Temperature DS",
  "description": "Datastream for recording temperature",
  "observationType": "http://www.opengis.net/def/observationType/OGC-OM/2.0/OM_Measurement",
    "@iot.id":"DS-AT-"+row.ID,
  "unitOfMeasurement": {
    "name": "Degree Celsius",
    "symbol": "degC",
    "definition": "http://www.qudt.org/qudt/owl/1.0.0/unit/Instances.html#DegreeCelsius"
  },
  "Thing":{"@iot.id":"GGDWD-Sensor/IKNIGSBA9"},
  "ObservedProperty":{"@iot.id":"Area Temperature"},
  "Sensor":{"@iot.id":"GG-DWD-Sensor-Temperature/" + row.ID}
}
p = requests.post(urlDataStream, json.dumps(data))
if (p.status_code  == 201):
    print(201)
else:
    print("Error:", p.status_code)

for chunk in p.iter_content(chunk_size=128):
    print(chunk)
# Out:
# 201

# %% [markdown]
# ## Feature of interest

# %%
idDF = dataFileDF["ID","Latitude","Longitude"]
from pyspark.sql import functions as F
idDF = idDF.withColumn("LatLon",F.array("Latitude","Longitude"))
idDF = idDF.groupBy(idDF.ID).agg(F.first(idDF.LatLon).alias("LatLon"))
row = idDF.collect()[1]
#urlHome = 'http://smartaqnet.teco.edu:8080/FROST-Server/v1.0'
#urlHome = 'http://smartaqnet-dev.teco.edu:8080/FROST-Server/v1.0'
urlFoI = urlHome + '/FeaturesOfInterest'
data = {
  "name": "Weather Station-" + row.ID,
  "description": "Weather Station-" + row.ID,
  "encodingType": "application/vnd.geo+json",
    "@iot.id":"FoIxx-"+row.ID,
  "feature": {
    "type": "Point",
    "coordinates": [float(row.LatLon[0]), float(row.LatLon[1])]
  }
}
p = requests.post(urlFoI, json.dumps(data))
if (p.status_code  == 201):
    print(201)
else:
    print("Error:", p.status_code)

for chunk in p.iter_content(chunk_size=128):
    print(chunk)
# Out:
# 201

# %%
p.headers["location"]
# Out:
# "http://localhost:8080/FROST-Server/v1.0/FeaturesOfInterest('FoIxx-IKNIGSBA6')"

# %% [markdown]
# ## Observation

# %%
urlObs = urlHome + '/Observations'

for row in dataFileDF.collect():
    #
    data = {
      "phenomenonTime": "2017-02-07T18:02:00.000Z",
      "resultTime" : "2017-02-07T18:02:05.000Z",
      "result" : 21.6,
      "Datastream":{"@iot.id":8}
    }
    p = requests.post(urlFoI, json.dumps(data))
    if (p.status_code  == 201):
        print(201)
    else:
        print("Error:", p.status_code)

    for chunk in p.iter_content(chunk_size=128):
        print(chunk)

#dataFileDF.show(60)
# Out:
# +----------+--------+--------+---------+--------------+--------+-----------+---------+
# |      Date|    Time|Latitude|Longitude|AitTemperature|Humidity|AirPressure|       ID|
# +----------+--------+--------+---------+--------------+--------+-----------+---------+
# |2015-01-28|11:45:00|  48.961|    8.577|           5.1|      81|     1011.7|IKNIGSBA9|
# |2015-01-28|12:25:00|  48.961|    8.577|           5.7|      76|     1010.7|IKNIGSBA9|
# |2015-01-28|13:05:00|  48.961|    8.577|           5.8|      75|     1009.4|IKNIGSBA9|
# |2015-01-28|13:45:00|  48.961|    8.577|           5.7|      75|     1008.4|IKNIGSBA9|
# |2015-01-28|15:06:00|  48.961|    8.577|           6.0|      73|     1006.0|IKNIGSBA9|
# |2015-01-28|15:46:00|  48.961|    8.577|           5.8|      72|     1005.0|IKNIGSBA9|
# |2015-01-28|09:04:00|  48.961|    8.577|           2.5|      92|     1014.1|IKNIGSBA9|
# |2015-01-28|09:45:00|  48.961|    8.577|           2.9|      90|     1013.4|IKNIGSBA9|
# |2015-01-28|10:25:00|  48.961|    8.577|           3.6|      86|     1013.1|IKNIGSBA9|
# |2015-01-28|11:05:00|  48.961|    8.577|           4.4|      85|     1012.4|IKNIGSBA9|
# |2015-01-28|00:43:00|  48.961|    8.577|           2.1|      97|     1018.2|IKNIGSBA9|
# |2015-01-28|01:23:00|  48.961|    8.577|           2.1|      97|     1017.8|IKNIGSBA9|
# |2015-01-28|02:03:00|  48.961|    8.577|           2.0|      97|     1017.8|IKNIGSBA9|
# |2015-01-28|02:43:00|  48.961|    8.577|           1.9|      97|     1017.5|IKNIGSBA9|
# |2015-01-28|03:23:00|  48.961|    8.577|           2.1|      97|     1017.2|IKNIGSBA9|
# |2015-01-28|04:03:00|  48.961|    8.577|           2.2|      97|     1016.8|IKNIGSBA9|
# |2015-01-28|04:44:00|  48.961|    8.577|           2.2|      96|     1016.5|IKNIGSBA9|
# |2015-01-28|05:24:00|  48.961|    8.577|           2.3|      96|     1015.8|IKNIGSBA9|
# |2015-01-28|06:24:00|  48.961|    8.577|           2.2|      95|     1015.5|IKNIGSBA9|
# |2015-01-28|07:44:00|  48.961|    8.577|           2.1|      94|     1014.8|IKNIGSBA9|
# |2015-01-28|08:24:00|  48.961|    8.577|           2.2|      93|     1014.4|IKNIGSBA9|
# |2015-01-28|18:26:00|  48.961|    8.577|           5.1|      73|     1000.2|IKNIGSBA9|
# |2015-01-28|19:06:00|  48.961|    8.577|           5.4|      73|      998.5|IKNIGSBA9|
# |2015-01-28|19:46:00|  48.961|    8.577|           5.5|      77|      997.5|IKNIGSBA9|
# |2015-01-28|20:26:00|  48.961|    8.577|           5.5|      80|      996.8|IKNIGSBA9|
# |2015-01-28|21:07:00|  48.961|    8.577|           4.9|      88|      996.2|IKNIGSBA9|
# |2015-01-28|21:37:00|  48.961|    8.577|           5.0|      88|      995.8|IKNIGSBA9|
# |2015-01-28|22:07:00|  48.961|    8.577|           5.4|      86|      995.1|IKNIGSBA9|
# |2015-01-28|22:37:00|  48.961|    8.577|           5.3|      89|      995.8|IKNIGSBA9|
# |2015-01-28|23:07:00|  48.961|    8.577|           4.5|      93|      996.5|IKNIGSBA9|
# |2015-01-28|23:46:00|  48.961|    8.577|           4.0|      93|      996.2|IKNIGSBA9|
# |2015-01-28|06:17:00|  48.256|   10.887|           0.5|      99|     1020.2|IKNIGSBR2|
# |2015-01-28|06:48:00|  48.256|   10.887|           0.5|      99|     1020.2|IKNIGSBR2|
# |2015-01-28|07:25:00|  48.256|   10.887|           0.4|      99|     1020.5|IKNIGSBR2|
# |2015-01-28|00:03:00|  48.256|   10.887|           1.1|      99|     1021.6|IKNIGSBR2|
# |2015-01-28|00:43:00|  48.256|   10.887|           1.2|      99|     1021.9|IKNIGSBR2|
# |2015-01-28|01:24:00|  48.256|   10.887|           1.1|      99|     1021.9|IKNIGSBR2|
# |2015-01-28|02:04:00|  48.256|   10.887|           1.0|      99|     1021.9|IKNIGSBR2|
# |2015-01-28|12:21:00|  48.256|   10.887|           1.9|      99|     1017.2|IKNIGSBR2|
# |2015-01-28|04:45:00|  48.256|   10.887|           0.9|      99|     1020.9|IKNIGSBR2|
# |2015-01-28|05:16:00|  48.256|   10.887|           0.8|      99|     1020.5|IKNIGSBR2|
# |2015-01-28|05:55:00|  48.256|   10.887|           0.6|      98|     1020.5|IKNIGSBR2|
# |2015-01-28|09:39:00|  48.256|   10.887|           0.6|      99|     1019.5|IKNIGSBR2|
# |2015-01-28|10:20:00|  48.256|   10.887|           1.0|      99|     1019.5|IKNIGSBR2|
# |2015-01-28|11:00:00|  48.256|   10.887|           1.4|      99|     1018.8|IKNIGSBR2|
# |2015-01-28|11:41:00|  48.256|   10.887|           1.6|      99|     1017.8|IKNIGSBR2|
# |2015-01-28|16:54:00|  52.136|   11.770|           5.4|      80|     1001.2|IKNIGSBO2|
# |2015-01-28|17:34:00|  52.136|   11.770|           5.2|      81|      999.5|IKNIGSBO2|
# |2015-01-28|18:15:00|  52.136|   11.770|           5.1|      80|      997.9|IKNIGSBO2|
# |2015-01-28|18:55:00|  52.136|   11.770|           5.1|      80|      996.8|IKNIGSBO2|
# |2015-01-28|19:36:00|  52.136|   11.770|           4.9|      84|      996.2|IKNIGSBO2|
# |2015-01-28|20:26:00|  52.136|   11.770|           4.6|      87|      994.8|IKNIGSBO2|
# |2015-01-28|20:57:00|  52.136|   11.770|           4.4|      87|      994.1|IKNIGSBO2|
# |2015-01-28|21:37:00|  52.136|   11.770|           4.3|      88|      993.8|IKNIGSBO2|
# |2015-01-28|22:08:00|  52.136|   11.770|           4.4|      89|      994.1|IKNIGSBO2|
# |2015-01-28|23:08:00|  52.136|   11.770|           4.0|      85|      994.5|IKNIGSBO2|
# |2015-01-28|23:46:00|  52.136|   11.770|           3.7|      85|      994.5|IKNIGSBO2|
# |2015-01-28|23:07:00|  48.964|    8.616|           5.5|      85|      996.2|IKNIGSBA6|
# |2015-01-28|21:36:00|  48.964|    8.616|           5.5|      83|      995.1|IKNIGSBA6|
# |2015-01-28|22:07:00|  48.964|    8.616|           5.7|      83|      994.8|IKNIGSBA6|
# +----------+--------+--------+---------+--------------+--------+-----------+---------+
# only showing top 60 rows

# %%
from datetime import tzinfo, timedelta, datetime
row = dataFileDF.first()
row.Date.split("-")[0]
class TZ(tzinfo):
    def utcoffset(self, dt): return timedelta(minutes=120)
datetime(int(row.Date.split('-')[0]),
         int(row.Date.split("-")[1]),
         int(row.Date.split("-")[2]),
         int(row.Time.split(':')[0]),
         int(row.Time.split(':')[1]),
         int(row.Time.split(':')[2]),tzinfo=TZ()).isoformat()
# Out:
# '2015-01-28T11:45:00+02:00'

# %% [markdown]
# ## Tryouts

# %%
row = idDF.collect()[1]
urlHome = 'http://smartaqnet.teco.edu:8080/FROST-Server/v1.0'
urlThings = urlHome + '/Things'
data =  {
        "name": "DWD-Sensor-noSens" + row[0],
        "description": "DWD_Sensor-" + row[0],
        "@iot.id": "DWD-Sensor/noSensblblb" + row[0]
    }
p = requests.post(urlThings, json.dumps(data))
if (p.status_code  == 201):
    print(201)
else:
    print("Error:", p.status_code)
    
    for chunk in p.iter_content(chunk_size=128):
        print(chunk)

# %%
idDF = idDF.groupBy(idDF.ID).agg(F.first(idDF.LatLon).alias("LatLon"))#.show(3)#.agg(F.first(idDF.Longitude))

# %%
urlHome = 'http://smartaqnet-dev01.teco.edu:8080/FROST-Server/v1.0'
#urlHome = 'http://smartaqnet-dev.teco.edu:8080/FROST-Server/v1.0'
urlThings = urlHome + '/Things'

# %%
#idDF2 = idDF.select("ID","LatLon").rdd.map(DfToSensorthings)

# %%
row = idDF.collect()[1]
import requests
urlHome = 'http://smartaqnet.teco.edu:8080/FROST-Server/v1.0'
urlThings = urlHome + '/Things'
sensorAddr = "https://www.wunderground.com/personal-weather-station/dashboard?ID="+row[0]
data =  {
        "name": "DWD-Sensor-" + row[0],
        "description": "DWD_Sensor-" + row[0],
        "@iot.id": "DWD-Sensor/" + row[0]
    }
p = requests.get(urlThings+"('DWD-Sensor/noSensblbl" + row[0]+"')")
if (p.status_code  == 200):
    print(200)
else:
    print("Error:", p.status_code)
    
for chunk in p.iter_content(chunk_size=128):
    print(chunk)
# Out:
# 200
# {
#   "name" : "DWD-Sensor-noSensIKNIGSBA6",
#   "description" : "DWD_Sensor-IKNIGSBA6",
#   "Locations@iot.navigationLink" : "http://
# localhost:8080/FROST-Server/v1.0/Things('DWD-Sensor/noSensblblIKNIGSBA6')/Locations",
#   "HistoricalLocations@iot.navigationLink"
#  : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensor/noSensblblIKNIGSBA6')/HistoricalLocations",
#   "Datastreams@iot.na
# vigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensor/noSensblblIKNIGSBA6')/Datastreams",
#   "MultiDatastre
# ams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensor/noSensblblIKNIGSBA6')/MultiDatastreams",
#
#  "@iot.id" : "DWD-Sensor/noSensblblIKNIGSBA6",
#   "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensor/n
# oSensblblIKNIGSBA6')"
# }

# %%
# Out:
# 201

# %%
# Out:
# <bound method Response.json of <Response [500]>>

# %%
row
# Out:
# [Row(ID=u'IKNIGSBA9', LatLon=[u'48.961', u'8.577']),
#  Row(ID=u'IKNIGSBA6', LatLon=[u'48.964', u'8.616']),
#  Row(ID=u'IKNIGSEG2', LatLon=[u'47.928', u'9.419']),
#  Row(ID=u'IKNIGSBA8', LatLon=[u'48.965', u'8.646']),
#  Row(ID=u'IKNIGSBR2', LatLon=[u'48.256', u'10.887']),
#  Row(ID=u'IKNIGSBO2', LatLon=[u'52.136', u'11.770'])]

# %%
p = requests.post(urlThings, json.dumps(data))
if (p.status_code  == 201):
    print("Creation successful")
else:
    print("Error:", p.status_code)
    for chunk in p.iter_content(chunk_size=128):
        print(chunk)
# Out:
# Creation successful

# %%
#Delete a thing

deleteID = urlThings + "('DWD-Sensors/IBREUNA2')"
print(deleteID)
p = requests.delete(urlThings)
if (p.status_code  == 201):
    print("Deletion successful")
else:
    print("Error:", p.status_code)
    for chunk in p.iter_content(chunk_size=128):
        print(chunk)
# Out:
# http://smartaqnet.teco.edu:8080/FROST-Server/v1.0/Things('DWD-Sensors/IBREUNA2')
# ('Error:', 400)
# DELETE only allowed on Entities.

# %%
#Query a thing

getID = urlThings + "(\"teco.edu/Test-2\")"
print(getID)
p = requests.get(urlThings)
if (p.status_code  == 201):
    print("Get successful")
else:
    print("Error:", p.status_code)
    for chunk in p.iter_content(chunk_size=128):
        print(chunk)
# Out:
# http://smartaqnet.teco.edu:8080/FROST-Server/v1.0/Things("teco.edu/Test-2")
# ('Error:', 200)
# {
#   "value" : [ {
#     "name" : "Teco test",
#     "description" : "Teco test",
#     "Locations@iot.navigationLink" : "http://localh
# ost:8080/FROST-Server/v1.0/Things('teco.edu/Test-0')/Locations",
#     "HistoricalLocations@iot.navigationLink" : "http://localhos
# t:8080/FROST-Server/v1.0/Things('teco.edu/Test-0')/HistoricalLocations",
#     "Datastreams@iot.navigationLink" : "http://localhos
# t:8080/FROST-Server/v1.0/Things('teco.edu/Test-0')/Datastreams",
#     "MultiDatastreams@iot.navigationLink" : "http://localhost:8
# 080/FROST-Server/v1.0/Things('teco.edu/Test-0')/MultiDatastreams",
#     "@iot.id" : "teco.edu/Test-0",
#     "@iot.selfLink" : "htt
# p://localhost:8080/FROST-Server/v1.0/Things('teco.edu/Test-0')"
#   }, {
#     "name" : "Teco test",
#     "description" : "Teco test"
# ,
#     "Locations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('teco.edu/Test-1')/Locations",
#     "Histo
# ricalLocations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('teco.edu/Test-1')/HistoricalLocations",
#
#   "Datastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('teco.edu/Test-1')/Datastreams",
#     "Multi
# Datastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('teco.edu/Test-1')/MultiDatastreams",
#     "@io
# t.id" : "teco.edu/Test-1",
#     "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Things('teco.edu/Test-1')"
#   }, {
#
# "name" : "Teco test",
#     "description" : "Teco test",
#     "Locations@iot.navigationLink" : "http://localhost:8080/FROST-Server/
# v1.0/Things('teco.edu/Test-2')/Locations",
#     "HistoricalLocations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1
# .0/Things('teco.edu/Test-2')/HistoricalLocations",
#     "Datastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1
# .0/Things('teco.edu/Test-2')/Datastreams",
#     "MultiDatastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/
# Things('teco.edu/Test-2')/MultiDatastreams",
#     "@iot.id" : "teco.edu/Test-2",
#     "@iot.selfLink" : "http://localhost:8080/FRO
# ST-Server/v1.0/Things('teco.edu/Test-2')"
#   }, {
#     "name" : "Teco test",
#     "description" : "Teco test",
#     "Locations@iot.n
# avigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('teco.edu/Test-3')/Locations",
#     "HistoricalLocations@iot.nav
# igationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('teco.edu/Test-3')/HistoricalLocations",
#     "Datastreams@iot.nav
# igationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('teco.edu/Test-3')/Datastreams",
#     "MultiDatastreams@iot.naviga
# tionLink" : "http://localhost:8080/FROST-Server/v1.0/Things('teco.edu/Test-3')/MultiDatastreams",
#     "@iot.id" : "teco.edu/Test
# -3",
#     "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Things('teco.edu/Test-3')"
#   }, {
#     "name" : "Teco test",
#
#     "description" : "Teco test",
#     "Locations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('teco.edu/
# Test-4')/Locations",
#     "HistoricalLocations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('teco.edu/Te
# st-4')/HistoricalLocations",
#     "Datastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('teco.edu/Te
# st-4')/Datastreams",
#     "MultiDatastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('teco.edu/Test-
# 4')/MultiDatastreams",
#     "@iot.id" : "teco.edu/Test-4",
#     "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Things(
# 'teco.edu/Test-4')"
#   }, {
#     "name" : "Teco test",
#     "description" : "Teco test",
#     "Locations@iot.navigationLink" : "http
# ://localhost:8080/FROST-Server/v1.0/Things('teco.edu/Test-5')/Locations",
#     "HistoricalLocations@iot.navigationLink" : "http:/
# /localhost:8080/FROST-Server/v1.0/Things('teco.edu/Test-5')/HistoricalLocations",
#     "Datastreams@iot.navigationLink" : "http:/
# /localhost:8080/FROST-Server/v1.0/Things('teco.edu/Test-5')/Datastreams",
#     "MultiDatastreams@iot.navigationLink" : "http://lo
# calhost:8080/FROST-Server/v1.0/Things('teco.edu/Test-5')/MultiDatastreams",
#     "@iot.id" : "teco.edu/Test-5",
#     "@iot.selfLin
# k" : "http://localhost:8080/FROST-Server/v1.0/Things('teco.edu/Test-5')"
#   }, {
#     "name" : "Air polution Monitoring Station (U
# rban Background Augsburg)",
#     "description" : "The air pollution monitoring station is located at an urban background site in
# Augsburg, a mid-sized city with about 250 000 inhabitants in Bavaria, southern Germany. The monitoring station was placed on the
#  campus of the University of Applied Sciences Augsburg which is approximately 1 km to the south-east of the city centre. The loc
# ation was carefully selected taking the representativeness of a single monitoring station for the exposure of the general popula
# tion to ultrafine particles into account. Details of the site and surroundings are described elsewhere.  (PMID:18754352)",
#     "
# Locations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('geo.uni-augsburg.de/Fixed-Wing-UAV-0')/Location
# s",
#     "HistoricalLocations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('geo.uni-augsburg.de/Fixed-Wi
# ng-UAV-0')/HistoricalLocations",
#     "Datastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('geo.uni
# -augsburg.de/Fixed-Wing-UAV-0')/Datastreams",
#     "MultiDatastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1
# .0/Things('geo.uni-augsburg.de/Fixed-Wing-UAV-0')/MultiDatastreams",
#     "@iot.id" : "geo.uni-augsburg.de/Fixed-Wing-UAV-0",
#
#  "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Things('geo.uni-augsburg.de/Fixed-Wing-UAV-0')"
#   }, {
#     "name" :
# "DWD-Sensor-IBREUNA2",
#     "description" : "DWD_Sensor-IBREUNA2",
#     "properties" : {
#       "@iot.id" : "DWD-Sensors/IBREUNA2"
#
#     },
#     "Locations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('dfeb0e68-495d-11e8-8de5-4f67f7686a0
# f')/Locations",
#     "HistoricalLocations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('dfeb0e68-495d-11
# e8-8de5-4f67f7686a0f')/HistoricalLocations",
#     "Datastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Thi
# ngs('dfeb0e68-495d-11e8-8de5-4f67f7686a0f')/Datastreams",
#     "MultiDatastreams@iot.navigationLink" : "http://localhost:8080/FRO
# ST-Server/v1.0/Things('dfeb0e68-495d-11e8-8de5-4f67f7686a0f')/MultiDatastreams",
#     "@iot.id" : "dfeb0e68-495d-11e8-8de5-4f67f7
# 686a0f",
#     "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Things('dfeb0e68-495d-11e8-8de5-4f67f7686a0f')"
#   }, {
#
#    "name" : "DWD-Sensor-IBADENWR282",
#     "description" : "DWD_Sensor-IBADENWR282",
#     "properties" : {
#       "@iot.id" : "DWD-
# Sensors/IBADENWR282"
#     },
#     "Locations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('dff9d7b8-495d-
# 11e8-8de5-9ffe0e279cdf')/Locations",
#     "HistoricalLocations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Thi
# ngs('dff9d7b8-495d-11e8-8de5-9ffe0e279cdf')/HistoricalLocations",
#     "Datastreams@iot.navigationLink" : "http://localhost:8080/
# FROST-Server/v1.0/Things('dff9d7b8-495d-11e8-8de5-9ffe0e279cdf')/Datastreams",
#     "MultiDatastreams@iot.navigationLink" : "http
# ://localhost:8080/FROST-Server/v1.0/Things('dff9d7b8-495d-11e8-8de5-9ffe0e279cdf')/MultiDatastreams",
#     "@iot.id" : "dff9d7b8-
# 495d-11e8-8de5-9ffe0e279cdf",
#     "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Things('dff9d7b8-495d-11e8-8de5-9ff
# e0e279cdf')"
#   }, {
#     "name" : "DWD-Sensor-IBERLIN434",
#     "description" : "DWD_Sensor-IBERLIN434",
#     "properties" : {
#
#   "@iot.id" : "DWD-Sensors/IBERLIN434"
#     },
#     "Locations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Thin
# gs('dffdfcbc-495d-11e8-8de5-bb77b2e9ea6b')/Locations",
#     "HistoricalLocations@iot.navigationLink" : "http://localhost:8080/FRO
# ST-Server/v1.0/Things('dffdfcbc-495d-11e8-8de5-bb77b2e9ea6b')/HistoricalLocations",
#     "Datastreams@iot.navigationLink" : "http
# ://localhost:8080/FROST-Server/v1.0/Things('dffdfcbc-495d-11e8-8de5-bb77b2e9ea6b')/Datastreams",
#     "MultiDatastreams@iot.navig
# ationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('dffdfcbc-495d-11e8-8de5-bb77b2e9ea6b')/MultiDatastreams",
#     "@io
# t.id" : "dffdfcbc-495d-11e8-8de5-bb77b2e9ea6b",
#     "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Things('dffdfcbc-
# 495d-11e8-8de5-bb77b2e9ea6b')"
#   }, {
#     "name" : "DWD-Sensor-IAHAUSEN3",
#     "description" : "DWD_Sensor-IAHAUSEN3",
#     "prop
# erties" : {
#       "@iot.id" : "DWD-Sensors/IAHAUSEN3"
#     },
#     "Locations@iot.navigationLink" : "http://localhost:8080/FROST-S
# erver/v1.0/Things('e0020e60-495d-11e8-8de5-07350a068508')/Locations",
#     "HistoricalLocations@iot.navigationLink" : "http://loc
# alhost:8080/FROST-Server/v1.0/Things('e0020e60-495d-11e8-8de5-07350a068508')/HistoricalLocations",
#     "Datastreams@iot.navigati
# onLink" : "http://localhost:8080/FROST-Server/v1.0/Things('e0020e60-495d-11e8-8de5-07350a068508')/Datastreams",
#     "MultiDatast
# reams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('e0020e60-495d-11e8-8de5-07350a068508')/MultiDatastr
# eams",
#     "@iot.id" : "e0020e60-495d-11e8-8de5-07350a068508",
#     "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Th
# ings('e0020e60-495d-11e8-8de5-07350a068508')"
#   }, {
#     "name" : "DWD-Sensor-IBAMBERG67",
#     "description" : "DWD_Sensor-IBAMB
# ERG67",
#     "properties" : {
#       "@iot.id" : "DWD-Sensors/IBAMBERG67"
#     },
#     "Locations@iot.navigationLink" : "http://loca
# lhost:8080/FROST-Server/v1.0/Things('e0061a0a-495d-11e8-8de5-db088d641594')/Locations",
#     "HistoricalLocations@iot.navigationL
# ink" : "http://localhost:8080/FROST-Server/v1.0/Things('e0061a0a-495d-11e8-8de5-db088d641594')/HistoricalLocations",
#     "Datast
# reams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('e0061a0a-495d-11e8-8de5-db088d641594')/Datastreams"
# ,
#     "MultiDatastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('e0061a0a-495d-11e8-8de5-db088d641
# 594')/MultiDatastreams",
#     "@iot.id" : "e0061a0a-495d-11e8-8de5-db088d641594",
#     "@iot.selfLink" : "http://localhost:8080/FR
# OST-Server/v1.0/Things('e0061a0a-495d-11e8-8de5-db088d641594')"
#   }, {
#     "name" : "DWD-Sensor-IBIELEFE172",
#     "description"
# : "DWD_Sensor-IBIELEFE172",
#     "properties" : {
#       "@iot.id" : "DWD-Sensors/IBIELEFE172"
#     },
#     "Locations@iot.navigatio
# nLink" : "http://localhost:8080/FROST-Server/v1.0/Things('e0097538-495d-11e8-8de5-0394eefecb61')/Locations",
#     "HistoricalLoca
# tions@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('e0097538-495d-11e8-8de5-0394eefecb61')/HistoricalLo
# cations",
#     "Datastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('e0097538-495d-11e8-8de5-0394ee
# fecb61')/Datastreams",
#     "MultiDatastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('e0097538-495
# d-11e8-8de5-0394eefecb61')/MultiDatastreams",
#     "@iot.id" : "e0097538-495d-11e8-8de5-0394eefecb61",
#     "@iot.selfLink" : "htt
# p://localhost:8080/FROST-Server/v1.0/Things('e0097538-495d-11e8-8de5-0394eefecb61')"
#   }, {
#     "name" : "DWD-Sensor-IBINZ15",
#
#    "description" : "DWD_Sensor-IBINZ15",
#     "properties" : {
#       "@iot.id" : "DWD-Sensors/IBINZ15"
#     },
#     "Locations@iot.
# navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('e00c6f2c-495d-11e8-8de5-ebd4e28aba7b')/Locations",
#     "Histo
# ricalLocations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('e00c6f2c-495d-11e8-8de5-ebd4e28aba7b')/His
# toricalLocations",
#     "Datastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('e00c6f2c-495d-11e8-8d
# e5-ebd4e28aba7b')/Datastreams",
#     "MultiDatastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('e00
# c6f2c-495d-11e8-8de5-ebd4e28aba7b')/MultiDatastreams",
#     "@iot.id" : "e00c6f2c-495d-11e8-8de5-ebd4e28aba7b",
#     "@iot.selfLin
# k" : "http://localhost:8080/FROST-Server/v1.0/Things('e00c6f2c-495d-11e8-8de5-ebd4e28aba7b')"
#   }, {
#     "name" : "DWD-Sensor-IB
# ADHOMB34",
#     "description" : "DWD_Sensor-IBADHOMB34",
#     "properties" : {
#       "@iot.id" : "DWD-Sensors/IBADHOMB34"
#     },
#
#    "Locations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('e00fbc5e-495d-11e8-8de5-979e6a1fd2e7')/Loca
# tions",
#     "HistoricalLocations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('e00fbc5e-495d-11e8-8de5-
# 979e6a1fd2e7')/HistoricalLocations",
#     "Datastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('e00
# fbc5e-495d-11e8-8de5-979e6a1fd2e7')/Datastreams",
#     "MultiDatastreams@iot.navigationLink" : "http://localhost:8080/FROST-Serve
# r/v1.0/Things('e00fbc5e-495d-11e8-8de5-979e6a1fd2e7')/MultiDatastreams",
#     "@iot.id" : "e00fbc5e-495d-11e8-8de5-979e6a1fd2e7",
#
#     "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Things('e00fbc5e-495d-11e8-8de5-979e6a1fd2e7')"
#   }, {
#     "name
# " : "DWD-Sensor-IBEVERN2",
#     "description" : "DWD_Sensor-IBEVERN2",
#     "properties" : {
#       "@iot.id" : "DWD-Sensors/IBEVER
# N2"
#     },
#     "Locations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('e012ad7e-495d-11e8-8de5-179e5f4
# 78d78')/Locations",
#     "HistoricalLocations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('e012ad7e-495
# d-11e8-8de5-179e5f478d78')/HistoricalLocations",
#     "Datastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0
# /Things('e012ad7e-495d-11e8-8de5-179e5f478d78')/Datastreams",
#     "MultiDatastreams@iot.navigationLink" : "http://localhost:8080
# /FROST-Server/v1.0/Things('e012ad7e-495d-11e8-8de5-179e5f478d78')/MultiDatastreams",
#     "@iot.id" : "e012ad7e-495d-11e8-8de5-17
# 9e5f478d78",
#     "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Things('e012ad7e-495d-11e8-8de5-179e5f478d78')"
#   },
#  {
#     "name" : "DWD-Sensor-IBADLIEB13",
#     "description" : "DWD_Sensor-IBADLIEB13",
#     "properties" : {
#       "@iot.id" : "DW
# D-Sensors/IBADLIEB13"
#     },
#     "Locations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('e015a524-495d
# -11e8-8de5-8bdf007b3db6')/Locations",
#     "HistoricalLocations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Th
# ings('e015a524-495d-11e8-8de5-8bdf007b3db6')/HistoricalLocations",
#     "Datastreams@iot.navigationLink" : "http://localhost:8080
# /FROST-Server/v1.0/Things('e015a524-495d-11e8-8de5-8bdf007b3db6')/Datastreams",
#     "MultiDatastreams@iot.navigationLink" : "htt
# p://localhost:8080/FROST-Server/v1.0/Things('e015a524-495d-11e8-8de5-8bdf007b3db6')/MultiDatastreams",
#     "@iot.id" : "e015a524
# -495d-11e8-8de5-8bdf007b3db6",
#     "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Things('e015a524-495d-11e8-8de5-8b
# df007b3db6')"
#   }, {
#     "name" : "DWD-Sensor-IBADENWR550",
#     "description" : "DWD_Sensor-IBADENWR550",
#     "properties" : {
#
#      "@iot.id" : "DWD-Sensors/IBADENWR550"
#     },
#     "Locations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/
# Things('e0181e76-495d-11e8-8de5-7f8a11ba7005')/Locations",
#     "HistoricalLocations@iot.navigationLink" : "http://localhost:8080
# /FROST-Server/v1.0/Things('e0181e76-495d-11e8-8de5-7f8a11ba7005')/HistoricalLocations",
#     "Datastreams@iot.navigationLink" : "
# http://localhost:8080/FROST-Server/v1.0/Things('e0181e76-495d-11e8-8de5-7f8a11ba7005')/Datastreams",
#     "MultiDatastreams@iot.n
# avigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('e0181e76-495d-11e8-8de5-7f8a11ba7005')/MultiDatastreams",
#
# "@iot.id" : "e0181e76-495d-11e8-8de5-7f8a11ba7005",
#     "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Things('e0181
# e76-495d-11e8-8de5-7f8a11ba7005')"
#   }, {
#     "name" : "DWD-Sensor-IBERLIN2736",
#     "description" : "DWD_Sensor-IBERLIN2736",
#
#    "properties" : {
#       "@iot.id" : "DWD-Sensors/IBERLIN2736"
#     },
#     "Locations@iot.navigationLink" : "http://localhost:80
# 80/FROST-Server/v1.0/Things('e01ad4ae-495d-11e8-8de5-2babcb2fad55')/Locations",
#     "HistoricalLocations@iot.navigationLink" : "
# http://localhost:8080/FROST-Server/v1.0/Things('e01ad4ae-495d-11e8-8de5-2babcb2fad55')/HistoricalLocations",
#     "Datastreams@io
# t.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('e01ad4ae-495d-11e8-8de5-2babcb2fad55')/Datastreams",
#     "M
# ultiDatastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('e01ad4ae-495d-11e8-8de5-2babcb2fad55')/Mu
# ltiDatastreams",
#     "@iot.id" : "e01ad4ae-495d-11e8-8de5-2babcb2fad55",
#     "@iot.selfLink" : "http://localhost:8080/FROST-Serv
# er/v1.0/Things('e01ad4ae-495d-11e8-8de5-2babcb2fad55')"
#   }, {
#     "name" : "DWD-Sensor-IBADSAUL2",
#     "description" : "DWD_Sen
# sor-IBADSAUL2",
#     "properties" : {
#       "@iot.id" : "DWD-Sensors/IBADSAUL2"
#     },
#     "Locations@iot.navigationLink" : "http
# ://localhost:8080/FROST-Server/v1.0/Things('e01d82c6-495d-11e8-8de5-cf6e865af30d')/Locations",
#     "HistoricalLocations@iot.navi
# gationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('e01d82c6-495d-11e8-8de5-cf6e865af30d')/HistoricalLocations",
#
# "Datastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('e01d82c6-495d-11e8-8de5-cf6e865af30d')/Datas
# treams",
#     "MultiDatastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('e01d82c6-495d-11e8-8de5-cf
# 6e865af30d')/MultiDatastreams",
#     "@iot.id" : "e01d82c6-495d-11e8-8de5-cf6e865af30d",
#     "@iot.selfLink" : "http://localhost:
# 8080/FROST-Server/v1.0/Things('e01d82c6-495d-11e8-8de5-cf6e865af30d')"
#   }, {
#     "name" : "DWD-Sensor-IALZEY13",
#     "descripti
# on" : "DWD_Sensor-IALZEY13",
#     "properties" : {
#       "@iot.id" : "DWD-Sensors/IALZEY13"
#     },
#     "Locations@iot.navigationL
# ink" : "http://localhost:8080/FROST-Server/v1.0/Things('e01fed72-495d-11e8-8de5-f34e70c2f14f')/Locations",
#     "HistoricalLocati
# ons@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('e01fed72-495d-11e8-8de5-f34e70c2f14f')/HistoricalLoca
# tions",
#     "Datastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('e01fed72-495d-11e8-8de5-f34e70c2
# f14f')/Datastreams",
#     "MultiDatastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('e01fed72-495d-
# 11e8-8de5-f34e70c2f14f')/MultiDatastreams",
#     "@iot.id" : "e01fed72-495d-11e8-8de5-f34e70c2f14f",
#     "@iot.selfLink" : "http:
# //localhost:8080/FROST-Server/v1.0/Things('e01fed72-495d-11e8-8de5-f34e70c2f14f')"
#   }, {
#     "name" : "DWD-Sensor-I90579130",
#
#    "description" : "DWD_Sensor-I90579130",
#     "properties" : {
#       "@iot.id" : "DWD-Sensors/I90579130"
#     },
#     "Locations@
# iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('e02245ea-495d-11e8-8de5-23085cc66a3e')/Locations",
#     "H
# istoricalLocations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('e02245ea-495d-11e8-8de5-23085cc66a3e')
# /HistoricalLocations",
#     "Datastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('e02245ea-495d-11e
# 8-8de5-23085cc66a3e')/Datastreams",
#     "MultiDatastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things(
# 'e02245ea-495d-11e8-8de5-23085cc66a3e')/MultiDatastreams",
#     "@iot.id" : "e02245ea-495d-11e8-8de5-23085cc66a3e",
#     "@iot.sel
# fLink" : "http://localhost:8080/FROST-Server/v1.0/Things('e02245ea-495d-11e8-8de5-23085cc66a3e')"
#   }, {
#     "name" : "DWD-Senso
# r-IARNSBER1",
#     "description" : "DWD_Sensor-IARNSBER1",
#     "properties" : {
#       "@iot.id" : "DWD-Sensors/IARNSBER1"
#     },
#
#     "Locations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('e024e3c2-495d-11e8-8de5-0ba530c494e6')/Loc
# ations",
#     "HistoricalLocations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('e024e3c2-495d-11e8-8de5
# -0ba530c494e6')/HistoricalLocations",
#     "Datastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('e0
# 24e3c2-495d-11e8-8de5-0ba530c494e6')/Datastreams",
#     "MultiDatastreams@iot.navigationLink" : "http://localhost:8080/FROST-Serv
# er/v1.0/Things('e024e3c2-495d-11e8-8de5-0ba530c494e6')/MultiDatastreams",
#     "@iot.id" : "e024e3c2-495d-11e8-8de5-0ba530c494e6"
# ,
#     "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Things('e024e3c2-495d-11e8-8de5-0ba530c494e6')"
#   }, {
#     "nam
# e" : "DWD-Sensor-IBAIERSD4",
#     "description" : "DWD_Sensor-IBAIERSD4",
#     "properties" : {
#       "@iot.id" : "DWD-Sensors/IBA
# IERSD4"
#     },
#     "Locations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('e0276ee4-495d-11e8-8de5-5b9
# c1f9034d6')/Locations",
#     "HistoricalLocations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('e0276ee4
# -495d-11e8-8de5-5b9c1f9034d6')/HistoricalLocations",
#     "Datastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/
# v1.0/Things('e0276ee4-495d-11e8-8de5-5b9c1f9034d6')/Datastreams",
#     "MultiDatastreams@iot.navigationLink" : "http://localhost:
# 8080/FROST-Server/v1.0/Things('e0276ee4-495d-11e8-8de5-5b9c1f9034d6')/MultiDatastreams",
#     "@iot.id" : "e0276ee4-495d-11e8-8de
# 5-5b9c1f9034d6",
#     "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Things('e0276ee4-495d-11e8-8de5-5b9c1f9034d6')"
#
#   }, {
#     "name" : "DWD-Sensor-IBADMNST12",
#     "description" : "DWD_Sensor-IBADMNST12",
#     "properties" : {
#       "@iot.id" :
#  "DWD-Sensors/IBADMNST12"
#     },
#     "Locations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('e02abc3e-
# 495d-11e8-8de5-83c0994310fa')/Locations",
#     "HistoricalLocations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.
# 0/Things('e02abc3e-495d-11e8-8de5-83c0994310fa')/HistoricalLocations",
#     "Datastreams@iot.navigationLink" : "http://localhost:
# 8080/FROST-Server/v1.0/Things('e02abc3e-495d-11e8-8de5-83c0994310fa')/Datastreams",
#     "MultiDatastreams@iot.navigationLink" :
# "http://localhost:8080/FROST-Server/v1.0/Things('e02abc3e-495d-11e8-8de5-83c0994310fa')/MultiDatastreams",
#     "@iot.id" : "e02a
# bc3e-495d-11e8-8de5-83c0994310fa",
#     "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Things('e02abc3e-495d-11e8-8de
# 5-83c0994310fa')"
#   }, {
#     "name" : "DWD-Sensor-IBERLIN324",
#     "description" : "DWD_Sensor-IBERLIN324",
#     "properties" : {
#
#       "@iot.id" : "DWD-Sensors/IBERLIN324"
#     },
#     "Locations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0
# /Things('e02e1f32-495d-11e8-8de5-d77d29254d0f')/Locations",
#     "HistoricalLocations@iot.navigationLink" : "http://localhost:808
# 0/FROST-Server/v1.0/Things('e02e1f32-495d-11e8-8de5-d77d29254d0f')/HistoricalLocations",
#     "Datastreams@iot.navigationLink" :
# "http://localhost:8080/FROST-Server/v1.0/Things('e02e1f32-495d-11e8-8de5-d77d29254d0f')/Datastreams",
#     "MultiDatastreams@iot.
# navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('e02e1f32-495d-11e8-8de5-d77d29254d0f')/MultiDatastreams",
#
#  "@iot.id" : "e02e1f32-495d-11e8-8de5-d77d29254d0f",
#     "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Things('e02e
# 1f32-495d-11e8-8de5-d77d29254d0f')"
#   }, {
#     "name" : "DWD-Sensor-I90578762",
#     "description" : "DWD_Sensor-I90578762",
#
# "properties" : {
#       "@iot.id" : "DWD-Sensors/I90578762"
#     },
#     "Locations@iot.navigationLink" : "http://localhost:8080/FR
# OST-Server/v1.0/Things('e030685a-495d-11e8-8de5-37af3648bbf3')/Locations",
#     "HistoricalLocations@iot.navigationLink" : "http:
# //localhost:8080/FROST-Server/v1.0/Things('e030685a-495d-11e8-8de5-37af3648bbf3')/HistoricalLocations",
#     "Datastreams@iot.nav
# igationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('e030685a-495d-11e8-8de5-37af3648bbf3')/Datastreams",
#     "MultiD
# atastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('e030685a-495d-11e8-8de5-37af3648bbf3')/MultiDa
# tastreams",
#     "@iot.id" : "e030685a-495d-11e8-8de5-37af3648bbf3",
#     "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1
# .0/Things('e030685a-495d-11e8-8de5-37af3648bbf3')"
#   }, {
#     "name" : "DWD-Sensor-IBECKUM11",
#     "description" : "DWD_Sensor-I
# BECKUM11",
#     "properties" : {
#       "@iot.id" : "DWD-Sensors/IBECKUM11"
#     },
#     "Locations@iot.navigationLink" : "http://lo
# calhost:8080/FROST-Server/v1.0/Things('e03306aa-495d-11e8-8de5-afe63404e1a4')/Locations",
#     "HistoricalLocations@iot.navigatio
# nLink" : "http://localhost:8080/FROST-Server/v1.0/Things('e03306aa-495d-11e8-8de5-afe63404e1a4')/HistoricalLocations",
#     "Data
# streams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('e03306aa-495d-11e8-8de5-afe63404e1a4')/Datastream
# s",
#     "MultiDatastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('e03306aa-495d-11e8-8de5-afe6340
# 4e1a4')/MultiDatastreams",
#     "@iot.id" : "e03306aa-495d-11e8-8de5-afe63404e1a4",
#     "@iot.selfLink" : "http://localhost:8080/
# FROST-Server/v1.0/Things('e03306aa-495d-11e8-8de5-afe63404e1a4')"
#   }, {
#     "name" : "DWD-Sensor-IBERLIN1165",
#     "description
# " : "DWD_Sensor-IBERLIN1165",
#     "properties" : {
#       "@iot.id" : "DWD-Sensors/IBERLIN1165"
#     },
#     "Locations@iot.navigat
# ionLink" : "http://localhost:8080/FROST-Server/v1.0/Things('e038acc2-495d-11e8-8de5-53dfd8f44593')/Locations",
#     "HistoricalLo
# cations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('e038acc2-495d-11e8-8de5-53dfd8f44593')/Historical
# Locations",
#     "Datastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('e038acc2-495d-11e8-8de5-53df
# d8f44593')/Datastreams",
#     "MultiDatastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('e038acc2-4
# 95d-11e8-8de5-53dfd8f44593')/MultiDatastreams",
#     "@iot.id" : "e038acc2-495d-11e8-8de5-53dfd8f44593",
#     "@iot.selfLink" : "h
# ttp://localhost:8080/FROST-Server/v1.0/Things('e038acc2-495d-11e8-8de5-53dfd8f44593')"
#   }, {
#     "name" : "DWD-Sensor-IAHOLFIN2
# ",
#     "description" : "DWD_Sensor-IAHOLFIN2",
#     "properties" : {
#       "@iot.id" : "DWD-Sensors/IAHOLFIN2"
#     },
#     "Locati
# ons@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('e03bec66-495d-11e8-8de5-cb2b6d332a46')/Locations",
#
#   "HistoricalLocations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('e03bec66-495d-11e8-8de5-cb2b6d332a
# 46')/HistoricalLocations",
#     "Datastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('e03bec66-495d
# -11e8-8de5-cb2b6d332a46')/Datastreams",
#     "MultiDatastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Thi
# ngs('e03bec66-495d-11e8-8de5-cb2b6d332a46')/MultiDatastreams",
#     "@iot.id" : "e03bec66-495d-11e8-8de5-cb2b6d332a46",
#     "@iot
# .selfLink" : "http://localhost:8080/FROST-Server/v1.0/Things('e03bec66-495d-11e8-8de5-cb2b6d332a46')"
#   }, {
#     "name" : "DWD-S
# ensor-IANHAUSE4",
#     "description" : "DWD_Sensor-IANHAUSE4",
#     "properties" : {
#       "@iot.id" : "DWD-Sensors/IANHAUSE4"
#
#  },
#     "Locations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('e03e31b0-495d-11e8-8de5-6331e972cfb7')
# /Locations",
#     "HistoricalLocations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('e03e31b0-495d-11e8-
# 8de5-6331e972cfb7')/HistoricalLocations",
#     "Datastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things
# ('e03e31b0-495d-11e8-8de5-6331e972cfb7')/Datastreams",
#     "MultiDatastreams@iot.navigationLink" : "http://localhost:8080/FROST-
# Server/v1.0/Things('e03e31b0-495d-11e8-8de5-6331e972cfb7')/MultiDatastreams",
#     "@iot.id" : "e03e31b0-495d-11e8-8de5-6331e972c
# fb7",
#     "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Things('e03e31b0-495d-11e8-8de5-6331e972cfb7')"
#   }, {
#
# "name" : "DWD-Sensor-IBADBERK8",
#     "description" : "DWD_Sensor-IBADBERK8",
#     "properties" : {
#       "@iot.id" : "DWD-Sensors
# /IBADBERK8"
#     },
#     "Locations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('e04109b2-495d-11e8-8de5
# -1ba9a0f9ec82')/Locations",
#     "HistoricalLocations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('e041
# 09b2-495d-11e8-8de5-1ba9a0f9ec82')/HistoricalLocations",
#     "Datastreams@iot.navigationLink" : "http://localhost:8080/FROST-Ser
# ver/v1.0/Things('e04109b2-495d-11e8-8de5-1ba9a0f9ec82')/Datastreams",
#     "MultiDatastreams@iot.navigationLink" : "http://localh
# ost:8080/FROST-Server/v1.0/Things('e04109b2-495d-11e8-8de5-1ba9a0f9ec82')/MultiDatastreams",
#     "@iot.id" : "e04109b2-495d-11e8
# -8de5-1ba9a0f9ec82",
#     "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Things('e04109b2-495d-11e8-8de5-1ba9a0f9ec82
# ')"
#   }, {
#     "name" : "DWD-Sensor-IBAYERNW20",
#     "description" : "DWD_Sensor-IBAYERNW20",
#     "properties" : {
#       "@iot.i
# d" : "DWD-Sensors/IBAYERNW20"
#     },
#     "Locations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('e0436
# 9a0-495d-11e8-8de5-0fdfb8af9f77')/Locations",
#     "HistoricalLocations@iot.navigationLink" : "http://localhost:8080/FROST-Server
# /v1.0/Things('e04369a0-495d-11e8-8de5-0fdfb8af9f77')/HistoricalLocations",
#     "Datastreams@iot.navigationLink" : "http://localh
# ost:8080/FROST-Server/v1.0/Things('e04369a0-495d-11e8-8de5-0fdfb8af9f77')/Datastreams",
#     "MultiDatastreams@iot.navigationLink
# " : "http://localhost:8080/FROST-Server/v1.0/Things('e04369a0-495d-11e8-8de5-0fdfb8af9f77')/MultiDatastreams",
#     "@iot.id" : "
# e04369a0-495d-11e8-8de5-0fdfb8af9f77",
#     "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Things('e04369a0-495d-11e8
# -8de5-0fdfb8af9f77')"
#   }, {
#     "name" : "DWD-Sensor-IBADSCHW15",
#     "description" : "DWD_Sensor-IBADSCHW15",
#     "properties"
#  : {
#       "@iot.id" : "DWD-Sensors/IBADSCHW15"
#     },
#     "Locations@iot.navigationLink" : "http://localhost:8080/FROST-Server/
# v1.0/Things('e045c4f2-495d-11e8-8de5-af84f7a2f398')/Locations",
#     "HistoricalLocations@iot.navigationLink" : "http://localhost
# :8080/FROST-Server/v1.0/Things('e045c4f2-495d-11e8-8de5-af84f7a2f398')/HistoricalLocations",
#     "Datastreams@iot.navigationLink
# " : "http://localhost:8080/FROST-Server/v1.0/Things('e045c4f2-495d-11e8-8de5-af84f7a2f398')/Datastreams",
#     "MultiDatastreams@
# iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('e045c4f2-495d-11e8-8de5-af84f7a2f398')/MultiDatastreams",
#
#     "@iot.id" : "e045c4f2-495d-11e8-8de5-af84f7a2f398",
#     "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Things('
# e045c4f2-495d-11e8-8de5-af84f7a2f398')"
#   }, {
#     "name" : "DWD-Sensor-IBHL16",
#     "description" : "DWD_Sensor-IBHL16",
#     "p
# roperties" : {
#       "@iot.id" : "DWD-Sensors/IBHL16"
#     },
#     "Locations@iot.navigationLink" : "http://localhost:8080/FROST-S
# erver/v1.0/Things('e048717a-495d-11e8-8de5-27e93a26a5cc')/Locations",
#     "HistoricalLocations@iot.navigationLink" : "http://loc
# alhost:8080/FROST-Server/v1.0/Things('e048717a-495d-11e8-8de5-27e93a26a5cc')/HistoricalLocations",
#     "Datastreams@iot.navigati
# onLink" : "http://localhost:8080/FROST-Server/v1.0/Things('e048717a-495d-11e8-8de5-27e93a26a5cc')/Datastreams",
#     "MultiDatast
# reams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('e048717a-495d-11e8-8de5-27e93a26a5cc')/MultiDatastr
# eams",
#     "@iot.id" : "e048717a-495d-11e8-8de5-27e93a26a5cc",
#     "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Th
# ings('e048717a-495d-11e8-8de5-27e93a26a5cc')"
#   }, {
#     "name" : "DWD-Sensor-IBERLIN339",
#     "description" : "DWD_Sensor-IBERL
# IN339",
#     "properties" : {
#       "@iot.id" : "DWD-Sensors/IBERLIN339"
#     },
#     "Locations@iot.navigationLink" : "http://loca
# lhost:8080/FROST-Server/v1.0/Things('e04b46de-495d-11e8-8de5-a3f091dfb5cb')/Locations",
#     "HistoricalLocations@iot.navigationL
# ink" : "http://localhost:8080/FROST-Server/v1.0/Things('e04b46de-495d-11e8-8de5-a3f091dfb5cb')/HistoricalLocations",
#     "Datast
# reams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('e04b46de-495d-11e8-8de5-a3f091dfb5cb')/Datastreams"
# ,
#     "MultiDatastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('e04b46de-495d-11e8-8de5-a3f091dfb
# 5cb')/MultiDatastreams",
#     "@iot.id" : "e04b46de-495d-11e8-8de5-a3f091dfb5cb",
#     "@iot.selfLink" : "http://localhost:8080/FR
# OST-Server/v1.0/Things('e04b46de-495d-11e8-8de5-a3f091dfb5cb')"
#   }, {
#     "name" : "DWD-Sensor-IBIELEFE130",
#     "description"
# : "DWD_Sensor-IBIELEFE130",
#     "properties" : {
#       "@iot.id" : "DWD-Sensors/IBIELEFE130"
#     },
#     "Locations@iot.navigatio
# nLink" : "http://localhost:8080/FROST-Server/v1.0/Things('e04d85a2-495d-11e8-8de5-77a209d3b6ae')/Locations",
#     "HistoricalLoca
# tions@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('e04d85a2-495d-11e8-8de5-77a209d3b6ae')/HistoricalLo
# cations",
#     "Datastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('e04d85a2-495d-11e8-8de5-77a209
# d3b6ae')/Datastreams",
#     "MultiDatastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('e04d85a2-495
# d-11e8-8de5-77a209d3b6ae')/MultiDatastreams",
#     "@iot.id" : "e04d85a2-495d-11e8-8de5-77a209d3b6ae",
#     "@iot.selfLink" : "htt
# p://localhost:8080/FROST-Server/v1.0/Things('e04d85a2-495d-11e8-8de5-77a209d3b6ae')"
#   }, {
#     "name" : "DWD-Sensor-IBERLIN1696
# ",
#     "description" : "DWD_Sensor-IBERLIN1696",
#     "properties" : {
#       "@iot.id" : "DWD-Sensors/IBERLIN1696"
#     },
#     "Lo
# cations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('e050129a-495d-11e8-8de5-2f7c97ae0dcf')/Locations"
# ,
#     "HistoricalLocations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('e050129a-495d-11e8-8de5-2f7c97
# ae0dcf')/HistoricalLocations",
#     "Datastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('e050129a-
# 495d-11e8-8de5-2f7c97ae0dcf')/Datastreams",
#     "MultiDatastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0
# /Things('e050129a-495d-11e8-8de5-2f7c97ae0dcf')/MultiDatastreams",
#     "@iot.id" : "e050129a-495d-11e8-8de5-2f7c97ae0dcf",
#     "
# @iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Things('e050129a-495d-11e8-8de5-2f7c97ae0dcf')"
#   }, {
#     "name" : "D
# WD-Sensor-I72406BI1",
#     "description" : "DWD_Sensor-I72406BI1",
#     "properties" : {
#       "@iot.id" : "DWD-Sensors/I72406BI1"
#
#     },
#     "Locations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('e052a6ae-495d-11e8-8de5-b722f37f20
# 11')/Locations",
#     "HistoricalLocations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('e052a6ae-495d-1
# 1e8-8de5-b722f37f2011')/HistoricalLocations",
#     "Datastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Th
# ings('e052a6ae-495d-11e8-8de5-b722f37f2011')/Datastreams",
#     "MultiDatastreams@iot.navigationLink" : "http://localhost:8080/FR
# OST-Server/v1.0/Things('e052a6ae-495d-11e8-8de5-b722f37f2011')/MultiDatastreams",
#     "@iot.id" : "e052a6ae-495d-11e8-8de5-b722f
# 37f2011",
#     "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Things('e052a6ae-495d-11e8-8de5-b722f37f2011')"
#   }, {
#
#     "name" : "DWD-Sensor-IBADDRIB8",
#     "description" : "DWD_Sensor-IBADDRIB8",
#     "properties" : {
#       "@iot.id" : "DWD-Sen
# sors/IBADDRIB8"
#     },
#     "Locations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('e0558590-495d-11e8-
# 8de5-8b97045e55a1')/Locations",
#     "HistoricalLocations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('
# e0558590-495d-11e8-8de5-8b97045e55a1')/HistoricalLocations",
#     "Datastreams@iot.navigationLink" : "http://localhost:8080/FROST
# -Server/v1.0/Things('e0558590-495d-11e8-8de5-8b97045e55a1')/Datastreams",
#     "MultiDatastreams@iot.navigationLink" : "http://lo
# calhost:8080/FROST-Server/v1.0/Things('e0558590-495d-11e8-8de5-8b97045e55a1')/MultiDatastreams",
#     "@iot.id" : "e0558590-495d-
# 11e8-8de5-8b97045e55a1",
#     "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Things('e0558590-495d-11e8-8de5-8b97045e
# 55a1')"
#   }, {
#     "name" : "Air polution Monitoring Station (Urban Background Augsburg)",
#     "description" : "The air pollutio
# n monitoring station is located at an urban background site in Augsburg, a mid-sized city with about 250 000 inhabitants in Bava
# ria, southern Germany. The monitoring station was placed on the campus of the University of Applied Sciences Augsburg which is a
# pproximately 1 km to the south-east of the city centre. The location was carefully selected taking the representativeness of a s
# ingle monitoring station for the exposure of the general population to ultrafine particles into account. Details of the site and
#  surroundings are described elsewhere.  (PMID:18754352)",
#     "properties" : {
#       "@iot.id" : "wzu.uni-augsburg.de/Aerosolmes
# sstation-0111"
#     },
#     "Locations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('44f7a046-49ef-11e8-8
# de5-2b5c964968fd')/Locations",
#     "HistoricalLocations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('4
# 4f7a046-49ef-11e8-8de5-2b5c964968fd')/HistoricalLocations",
#     "Datastreams@iot.navigationLink" : "http://localhost:8080/FROST-
# Server/v1.0/Things('44f7a046-49ef-11e8-8de5-2b5c964968fd')/Datastreams",
#     "MultiDatastreams@iot.navigationLink" : "http://loc
# alhost:8080/FROST-Server/v1.0/Things('44f7a046-49ef-11e8-8de5-2b5c964968fd')/MultiDatastreams",
#     "@iot.id" : "44f7a046-49ef-1
# 1e8-8de5-2b5c964968fd",
#     "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Things('44f7a046-49ef-11e8-8de5-2b5c96496
# 8fd')"
#   }, {
#     "name" : "Air polution Monitoring Station (Urban Background Augsburg)",
#     "description" : "The air pollution
#  monitoring station is located at an urban background site in Augsburg, a mid-sized city with about 250 000 inhabitants in Bavar
# ia, southern Germany. The monitoring station was placed on the campus of the University of Applied Sciences Augsburg which is ap
# proximately 1 km to the south-east of the city centre. The location was carefully selected taking the representativeness of a si
# ngle monitoring station for the exposure of the general population to ultrafine particles into account. Details of the site and
# surroundings are described elsewhere.  (PMID:18754352)",
#     "Locations@iot.navigationLink" : "http://localhost:8080/FROST-Serve
# r/v1.0/Things('geo.uni-augsburg.de/Fixed-Wing-UAV-0lll')/Locations",
#     "HistoricalLocations@iot.navigationLink" : "http://loca
# lhost:8080/FROST-Server/v1.0/Things('geo.uni-augsburg.de/Fixed-Wing-UAV-0lll')/HistoricalLocations",
#     "Datastreams@iot.naviga
# tionLink" : "http://localhost:8080/FROST-Server/v1.0/Things('geo.uni-augsburg.de/Fixed-Wing-UAV-0lll')/Datastreams",
#     "MultiD
# atastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('geo.uni-augsburg.de/Fixed-Wing-UAV-0lll')/Mult
# iDatastreams",
#     "@iot.id" : "geo.uni-augsburg.de/Fixed-Wing-UAV-0lll",
#     "@iot.selfLink" : "http://localhost:8080/FROST-Ser
# ver/v1.0/Things('geo.uni-augsburg.de/Fixed-Wing-UAV-0lll')"
#   }, {
#     "name" : "DWD-Sensor-IBREUNA2",
#     "description" : "DWD-
# Sensor-IBREUNA2",
#     "Locations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IBREUNA2')/L
# ocations",
#     "HistoricalLocations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IBREUNA2'
# )/HistoricalLocations",
#     "Datastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IBRE
# UNA2')/Datastreams",
#     "MultiDatastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IB
# REUNA2')/MultiDatastreams",
#     "@iot.id" : "DWD-Sensors/IBREUNA2",
#     "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1
# .0/Things('DWD-Sensors/IBREUNA2')"
#   }, {
#     "name" : "DWD-Sensor-IBADENWR282",
#     "description" : "DWD_Sensor-IBADENWR282",
#
#    "Locations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IBADENWR282')/Locations",
#     "
# HistoricalLocations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IBADENWR282')/HistoricalL
# ocations",
#     "Datastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IBADENWR282')/Dat
# astreams",
#     "MultiDatastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IBADENWR282'
# )/MultiDatastreams",
#     "@iot.id" : "DWD-Sensors/IBADENWR282",
#     "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/T
# hings('DWD-Sensors/IBADENWR282')"
#   }, {
#     "name" : "DWD-Sensor-IBERLIN434",
#     "description" : "DWD_Sensor-IBERLIN434",
#
# "Locations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IBERLIN434')/Locations",
#     "Hist
# oricalLocations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IBERLIN434')/HistoricalLocati
# ons",
#     "Datastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IBERLIN434')/Datastrea
# ms",
#     "MultiDatastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IBERLIN434')/Multi
# Datastreams",
#     "@iot.id" : "DWD-Sensors/IBERLIN434",
#     "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Things('D
# WD-Sensors/IBERLIN434')"
#   }, {
#     "name" : "DWD-Sensor-IAHAUSEN3",
#     "description" : "DWD_Sensor-IAHAUSEN3",
#     "Locations@
# iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IAHAUSEN3')/Locations",
#     "HistoricalLocati
# ons@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IAHAUSEN3')/HistoricalLocations",
#     "Da
# tastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IAHAUSEN3')/Datastreams",
#     "Mult
# iDatastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IAHAUSEN3')/MultiDatastreams",
#
#    "@iot.id" : "DWD-Sensors/IAHAUSEN3",
#     "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IAHAU
# SEN3')"
#   }, {
#     "name" : "DWD-Sensor-IBAMBERG67",
#     "description" : "DWD_Sensor-IBAMBERG67",
#     "Locations@iot.navigationL
# ink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IBAMBERG67')/Locations",
#     "HistoricalLocations@iot.naviga
# tionLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IBAMBERG67')/HistoricalLocations",
#     "Datastreams@iot
# .navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IBAMBERG67')/Datastreams",
#     "MultiDatastreams
# @iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IBAMBERG67')/MultiDatastreams",
#     "@iot.id
# " : "DWD-Sensors/IBAMBERG67",
#     "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IBAMBERG67')"
#
#  }, {
#     "name" : "DWD-Sensor-IBIELEFE172",
#     "description" : "DWD_Sensor-IBIELEFE172",
#     "Locations@iot.navigationLink" :
# "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IBIELEFE172')/Locations",
#     "HistoricalLocations@iot.navigationLi
# nk" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IBIELEFE172')/HistoricalLocations",
#     "Datastreams@iot.navi
# gationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IBIELEFE172')/Datastreams",
#     "MultiDatastreams@iot
# .navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IBIELEFE172')/MultiDatastreams",
#     "@iot.id" :
#  "DWD-Sensors/IBIELEFE172",
#     "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IBIELEFE172')"
#
# }, {
#     "name" : "DWD-Sensor-IBINZ15",
#     "description" : "DWD_Sensor-IBINZ15",
#     "Locations@iot.navigationLink" : "http://l
# ocalhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IBINZ15')/Locations",
#     "HistoricalLocations@iot.navigationLink" : "http:/
# /localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IBINZ15')/HistoricalLocations",
#     "Datastreams@iot.navigationLink" : "ht
# tp://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IBINZ15')/Datastreams",
#     "MultiDatastreams@iot.navigationLink" : "h
# ttp://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IBINZ15')/MultiDatastreams",
#     "@iot.id" : "DWD-Sensors/IBINZ15",
#
#    "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IBINZ15')"
#   }, {
#     "name" : "DWD-Sensor-IBA
# DHOMB34",
#     "description" : "DWD_Sensor-IBADHOMB34",
#     "Locations@iot.navigationLink" : "http://localhost:8080/FROST-Server/
# v1.0/Things('DWD-Sensors/IBADHOMB34')/Locations",
#     "HistoricalLocations@iot.navigationLink" : "http://localhost:8080/FROST-Se
# rver/v1.0/Things('DWD-Sensors/IBADHOMB34')/HistoricalLocations",
#     "Datastreams@iot.navigationLink" : "http://localhost:8080/F
# ROST-Server/v1.0/Things('DWD-Sensors/IBADHOMB34')/Datastreams",
#     "MultiDatastreams@iot.navigationLink" : "http://localhost:80
# 80/FROST-Server/v1.0/Things('DWD-Sensors/IBADHOMB34')/MultiDatastreams",
#     "@iot.id" : "DWD-Sensors/IBADHOMB34",
#     "@iot.sel
# fLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IBADHOMB34')"
#   }, {
#     "name" : "DWD-Sensor-IBEVERN2",
#
#    "description" : "DWD_Sensor-IBEVERN2",
#     "Locations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('
# DWD-Sensors/IBEVERN2')/Locations",
#     "HistoricalLocations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Thing
# s('DWD-Sensors/IBEVERN2')/HistoricalLocations",
#     "Datastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/
# Things('DWD-Sensors/IBEVERN2')/Datastreams",
#     "MultiDatastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.
# 0/Things('DWD-Sensors/IBEVERN2')/MultiDatastreams",
#     "@iot.id" : "DWD-Sensors/IBEVERN2",
#     "@iot.selfLink" : "http://localh
# ost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IBEVERN2')"
#   }, {
#     "name" : "DWD-Sensor-IBADLIEB13",
#     "description" : "DWD
# _Sensor-IBADLIEB13",
#     "Locations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IBADLIEB1
# 3')/Locations",
#     "HistoricalLocations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IBAD
# LIEB13')/HistoricalLocations",
#     "Datastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Senso
# rs/IBADLIEB13')/Datastreams",
#     "MultiDatastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-S
# ensors/IBADLIEB13')/MultiDatastreams",
#     "@iot.id" : "DWD-Sensors/IBADLIEB13",
#     "@iot.selfLink" : "http://localhost:8080/FR
# OST-Server/v1.0/Things('DWD-Sensors/IBADLIEB13')"
#   }, {
#     "name" : "DWD-Sensor-IBADENWR550",
#     "description" : "DWD_Sensor-
# IBADENWR550",
#     "Locations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IBADENWR550')/Lo
# cations",
#     "HistoricalLocations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IBADENWR55
# 0')/HistoricalLocations",
#     "Datastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IB
# ADENWR550')/Datastreams",
#     "MultiDatastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Senso
# rs/IBADENWR550')/MultiDatastreams",
#     "@iot.id" : "DWD-Sensors/IBADENWR550",
#     "@iot.selfLink" : "http://localhost:8080/FROS
# T-Server/v1.0/Things('DWD-Sensors/IBADENWR550')"
#   }, {
#     "name" : "DWD-Sensor-IBERLIN2736",
#     "description" : "DWD_Sensor-I
# BERLIN2736",
#     "Locations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IBERLIN2736')/Loc
# ations",
#     "HistoricalLocations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IBERLIN2736
# ')/HistoricalLocations",
#     "Datastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IBE
# RLIN2736')/Datastreams",
# ...
#   }, {
#     "name" : "DWD-Sensor-IBADSAUL2",
#     "description" : "DWD_Sensor-IBAD
# SAUL2",
#     "Locations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IBADSAUL2')/Locations"
# ,
#     "HistoricalLocations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IBADSAUL2')/Histor
# icalLocations",
#     "Datastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IBADSAUL2')/
# Datastreams",
#     "MultiDatastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IBADSAUL2
# ')/MultiDatastreams",
#     "@iot.id" : "DWD-Sensors/IBADSAUL2",
#     "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Th
# ings('DWD-Sensors/IBADSAUL2')"
#   }, {
#     "name" : "DWD-Sensor-IALZEY13",
#     "description" : "DWD_Sensor-IALZEY13",
#     "Locati
# ons@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IALZEY13')/Locations",
#     "HistoricalLoc
# ations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IALZEY13')/HistoricalLocations",
#     "
# Datastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IALZEY13')/Datastreams",
#     "Mul
# tiDatastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IALZEY13')/MultiDatastreams",
#
#    "@iot.id" : "DWD-Sensors/IALZEY13",
#     "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IALZEY
# 13')"
#   }, {
#     "name" : "DWD-Sensor-I90579130",
#     "description" : "DWD_Sensor-I90579130",
#     "Locations@iot.navigationLink"
#  : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/I90579130')/Locations",
#     "HistoricalLocations@iot.navigationL
# ink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/I90579130')/HistoricalLocations",
#     "Datastreams@iot.navig
# ationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/I90579130')/Datastreams",
#     "MultiDatastreams@iot.na
# vigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/I90579130')/MultiDatastreams",
#     "@iot.id" : "DWD
# -Sensors/I90579130",
#     "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/I90579130')"
#   }, {
#
# "name" : "DWD-Sensor-IARNSBER1",
#     "description" : "DWD_Sensor-IARNSBER1",
#     "Locations@iot.navigationLink" : "http://localh
# ost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IARNSBER1')/Locations",
#     "HistoricalLocations@iot.navigationLink" : "http://lo
# calhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IARNSBER1')/HistoricalLocations",
#     "Datastreams@iot.navigationLink" : "htt
# p://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IARNSBER1')/Datastreams",
#     "MultiDatastreams@iot.navigationLink" : "
# http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IARNSBER1')/MultiDatastreams",
#     "@iot.id" : "DWD-Sensors/IARNSBER
# 1",
#     "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IARNSBER1')"
#   }, {
#     "name" : "DWD-Sen
# sor-IBAIERSD4",
#     "description" : "DWD_Sensor-IBAIERSD4",
#     "Locations@iot.navigationLink" : "http://localhost:8080/FROST-Se
# rver/v1.0/Things('DWD-Sensors/IBAIERSD4')/Locations",
#     "HistoricalLocations@iot.navigationLink" : "http://localhost:8080/FROS
# T-Server/v1.0/Things('DWD-Sensors/IBAIERSD4')/HistoricalLocations",
#     "Datastreams@iot.navigationLink" : "http://localhost:808
# 0/FROST-Server/v1.0/Things('DWD-Sensors/IBAIERSD4')/Datastreams",
#     "MultiDatastreams@iot.navigationLink" : "http://localhost:
# 8080/FROST-Server/v1.0/Things('DWD-Sensors/IBAIERSD4')/MultiDatastreams",
#     "@iot.id" : "DWD-Sensors/IBAIERSD4",
#     "@iot.sel
# fLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IBAIERSD4')"
#   }, {
#     "name" : "DWD-Sensor-IBADMNST12",
#
#     "description" : "DWD_Sensor-IBADMNST12",
#     "Locations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Thing
# s('DWD-Sensors/IBADMNST12')/Locations",
#     "HistoricalLocations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/
# Things('DWD-Sensors/IBADMNST12')/HistoricalLocations",
#     "Datastreams@iot.navigationLink" : "http://localhost:8080/FROST-Serve
# r/v1.0/Things('DWD-Sensors/IBADMNST12')/Datastreams",
#     "MultiDatastreams@iot.navigationLink" : "http://localhost:8080/FROST-S
# erver/v1.0/Things('DWD-Sensors/IBADMNST12')/MultiDatastreams",
#     "@iot.id" : "DWD-Sensors/IBADMNST12",
#     "@iot.selfLink" : "
# http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IBADMNST12')"
#   }, {
#     "name" : "DWD-Sensor-IBERLIN324",
#     "desc
# ription" : "DWD_Sensor-IBERLIN324",
#     "Locations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Se
# nsors/IBERLIN324')/Locations",
#     "HistoricalLocations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('D
# WD-Sensors/IBERLIN324')/HistoricalLocations",
#     "Datastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Th
# ings('DWD-Sensors/IBERLIN324')/Datastreams",
#     "MultiDatastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.
# 0/Things('DWD-Sensors/IBERLIN324')/MultiDatastreams",
#     "@iot.id" : "DWD-Sensors/IBERLIN324",
#     "@iot.selfLink" : "http://lo
# calhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IBERLIN324')"
#   }, {
#     "name" : "DWD-Sensor-I90578762",
#     "description" :
#  "DWD_Sensor-I90578762",
#     "Locations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/I9057
# 8762')/Locations",
#     "HistoricalLocations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/I
# 90578762')/HistoricalLocations",
#     "Datastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sen
# sors/I90578762')/Datastreams",
#     "MultiDatastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-
# Sensors/I90578762')/MultiDatastreams",
#     "@iot.id" : "DWD-Sensors/I90578762",
#     "@iot.selfLink" : "http://localhost:8080/FRO
# ST-Server/v1.0/Things('DWD-Sensors/I90578762')"
#   }, {
#     "name" : "DWD-Sensor-IBECKUM11",
#     "description" : "DWD_Sensor-IBEC
# KUM11",
#     "Locations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IBECKUM11')/Locations"
# ,
#     "HistoricalLocations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IBECKUM11')/Histor
# icalLocations",
#     "Datastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IBECKUM11')/
# Datastreams",
#     "MultiDatastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IBECKUM11
# ')/MultiDatastreams",
#     "@iot.id" : "DWD-Sensors/IBECKUM11",
#     "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Th
# ings('DWD-Sensors/IBECKUM11')"
#   }, {
#     "name" : "DWD-Sensor-IBERLIN1165",
#     "description" : "DWD_Sensor-IBERLIN1165",
#     "
# Locations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IBERLIN1165')/Locations",
#     "Hist
# oricalLocations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IBERLIN1165')/HistoricalLocat
# ions",
#     "Datastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IBERLIN1165')/Datastr
# eams",
#     "MultiDatastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IBERLIN1165')/Mu
# ltiDatastreams",
#     "@iot.id" : "DWD-Sensors/IBERLIN1165",
#     "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Thing
# s('DWD-Sensors/IBERLIN1165')"
#   }, {
#     "name" : "DWD-Sensor-IAHOLFIN2",
#     "description" : "DWD_Sensor-IAHOLFIN2",
#     "Locat
# ions@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IAHOLFIN2')/Locations",
#     "HistoricalL
# ocations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IAHOLFIN2')/HistoricalLocations",
#
#   "Datastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IAHOLFIN2')/Datastreams",
#
# "MultiDatastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IAHOLFIN2')/MultiDatastream
# s",
#     "@iot.id" : "DWD-Sensors/IAHOLFIN2",
#     "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/
# IAHOLFIN2')"
#   }, {
#     "name" : "DWD-Sensor-IANHAUSE4",
#     "description" : "DWD_Sensor-IANHAUSE4",
#     "Locations@iot.navigati
# onLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IANHAUSE4')/Locations",
#     "HistoricalLocations@iot.navi
# gationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IANHAUSE4')/HistoricalLocations",
#     "Datastreams@io
# t.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IANHAUSE4')/Datastreams",
#     "MultiDatastreams
# @iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IANHAUSE4')/MultiDatastreams",
#     "@iot.id"
#  : "DWD-Sensors/IANHAUSE4",
#     "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IANHAUSE4')"
#   },
#  {
#     "name" : "DWD-Sensor-IBADBERK8",
#     "description" : "DWD_Sensor-IBADBERK8",
#     "Locations@iot.navigationLink" : "http:/
# /localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IBADBERK8')/Locations",
#     "HistoricalLocations@iot.navigationLink" : "ht
# tp://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IBADBERK8')/HistoricalLocations",
#     "Datastreams@iot.navigationLink"
#  : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IBADBERK8')/Datastreams",
#     "MultiDatastreams@iot.navigationLi
# nk" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IBADBERK8')/MultiDatastreams",
#     "@iot.id" : "DWD-Sensors/I
# BADBERK8",
#     "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IBADBERK8')"
#   }, {
#     "name" : "
# DWD-Sensor-IBAYERNW20",
#     "description" : "DWD_Sensor-IBAYERNW20",
#     "Locations@iot.navigationLink" : "http://localhost:8080
# /FROST-Server/v1.0/Things('DWD-Sensors/IBAYERNW20')/Locations",
#     "HistoricalLocations@iot.navigationLink" : "http://localhost
# :8080/FROST-Server/v1.0/Things('DWD-Sensors/IBAYERNW20')/HistoricalLocations",
#     "Datastreams@iot.navigationLink" : "http://lo
# calhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IBAYERNW20')/Datastreams",
#     "MultiDatastreams@iot.navigationLink" : "http:
# //localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IBAYERNW20')/MultiDatastreams",
#     "@iot.id" : "DWD-Sensors/IBAYERNW20",
#
#     "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IBAYERNW20')"
#   }, {
#     "name" : "DWD-Senso
# r-IBADSCHW15",
#     "description" : "DWD_Sensor-IBADSCHW15",
#     "Locations@iot.navigationLink" : "http://localhost:8080/FROST-Se
# rver/v1.0/Things('DWD-Sensors/IBADSCHW15')/Locations",
#     "HistoricalLocations@iot.navigationLink" : "http://localhost:8080/FRO
# ST-Server/v1.0/Things('DWD-Sensors/IBADSCHW15')/HistoricalLocations",
#     "Datastreams@iot.navigationLink" : "http://localhost:8
# 080/FROST-Server/v1.0/Things('DWD-Sensors/IBADSCHW15')/Datastreams",
#     "MultiDatastreams@iot.navigationLink" : "http://localho
# st:8080/FROST-Server/v1.0/Things('DWD-Sensors/IBADSCHW15')/MultiDatastreams",
#     "@iot.id" : "DWD-Sensors/IBADSCHW15",
#     "@io
# t.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IBADSCHW15')"
#   }, {
#     "name" : "DWD-Sensor-IBHL16"
# ,
#     "description" : "DWD_Sensor-IBHL16",
#     "Locations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things(
# 'DWD-Sensors/IBHL16')/Locations",
#     "HistoricalLocations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things
# ('DWD-Sensors/IBHL16')/HistoricalLocations",
#     "Datastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Thi
# ngs('DWD-Sensors/IBHL16')/Datastreams",
#     "MultiDatastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Thi
# ngs('DWD-Sensors/IBHL16')/MultiDatastreams",
#     "@iot.id" : "DWD-Sensors/IBHL16",
#     "@iot.selfLink" : "http://localhost:8080/
# FROST-Server/v1.0/Things('DWD-Sensors/IBHL16')"
#   }, {
#     "name" : "DWD-Sensor-IBERLIN339",
#     "description" : "DWD_Sensor-IBE
# RLIN339",
#     "Locations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IBERLIN339')/Locatio
# ns",
#     "HistoricalLocations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IBERLIN339')/Hi
# storicalLocations",
#     "Datastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IBERLIN3
# 39')/Datastreams",
#     "MultiDatastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IBER
# LIN339')/MultiDatastreams",
#     "@iot.id" : "DWD-Sensors/IBERLIN339",
#     "@iot.selfLink" : "http://localhost:8080/FROST-Server/
# v1.0/Things('DWD-Sensors/IBERLIN339')"
#   }, {
#     "name" : "DWD-Sensor-IBIELEFE130",
#     "description" : "DWD_Sensor-IBIELEFE130
# ",
#     "Locations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IBIELEFE130')/Locations",
#
#    "HistoricalLocations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IBIELEFE130')/Histori
# calLocations",
#     "Datastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IBIELEFE130')
# /Datastreams",
#     "MultiDatastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IBIELEFE
# 130')/MultiDatastreams",
#     "@iot.id" : "DWD-Sensors/IBIELEFE130",
#     "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1
# .0/Things('DWD-Sensors/IBIELEFE130')"
#   }, {
#     "name" : "DWD-Sensor-IBERLIN1696",
#     "description" : "DWD_Sensor-IBERLIN1696"
# ,
#     "Locations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IBERLIN1696')/Locations",
#
#   "HistoricalLocations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IBERLIN1696')/Historic
# alLocations",
#     "Datastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IBERLIN1696')/
# Datastreams",
#     "MultiDatastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IBERLIN16
# 96')/MultiDatastreams",
#     "@iot.id" : "DWD-Sensors/IBERLIN1696",
#     "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.
# 0/Things('DWD-Sensors/IBERLIN1696')"
#   }, {
#     "name" : "DWD-Sensor-I72406BI1",
#     "description" : "DWD_Sensor-I72406BI1",
#
#  "Locations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/I72406BI1')/Locations",
#     "Hist
# oricalLocations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/I72406BI1')/HistoricalLocatio
# ns",
#     "Datastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/I72406BI1')/Datastreams
# ",
#     "MultiDatastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/I72406BI1')/MultiDat
# astreams",
#     "@iot.id" : "DWD-Sensors/I72406BI1",
#     "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-S
# ensors/I72406BI1')"
#   }, {
#     "name" : "DWD-Sensor-IBADDRIB8",
#     "description" : "DWD_Sensor-IBADDRIB8",
#     "Locations@iot.n
# avigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IBADDRIB8')/Locations",
#     "HistoricalLocations@i
# ot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IBADDRIB8')/HistoricalLocations",
#     "Datastr
# eams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IBADDRIB8')/Datastreams",
#     "MultiData
# streams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IBADDRIB8')/MultiDatastreams",
#     "@
# iot.id" : "DWD-Sensors/IBADDRIB8",
#     "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Things('DWD-Sensors/IBADDRIB8'
# )"
#   } ]
# }

# %%
p.content
# Out:
# '{\n  "value" : [ {\n    "name" : "Teco test",\n    "description" : "Teco test",\n    "Locations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things(\'teco.edu/Test-0\')/Locations",\n    "HistoricalLocations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things(\'teco.edu/Test-0\')/HistoricalLocations",\n    "Datastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things(\'teco.edu/Test-0\')/Datastreams",\n    "MultiDatastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things(\'teco.edu/Test-0\')/MultiDatastreams",\n    "@iot.id" : "teco.edu/Test-0",\n    "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Things(\'teco.edu/Test-0\')"\n  }, {\n    "name" : "Teco test",\n    "description" : "Teco test",\n    "Locations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things(\'teco.edu/Test-1\')/Locations",\n    "HistoricalLocations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things(\'teco.edu/Test-1\')/HistoricalLocations",\n    "Datastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things(\'teco.edu/Test-1\')/Datastreams",\n    "MultiDatastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things(\'teco.edu/Test-1\')/MultiDatastreams",\n    "@iot.id" : "teco.edu/Test-1",\n    "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Things(\'teco.edu/Test-1\')"\n  }, {\n    "name" : "Teco test",\n    "description" : "Teco test",\n    "Locations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things(\'teco.edu/Test-2\')/Locations",\n    "HistoricalLocations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things(\'teco.edu/Test-2\')/HistoricalLocations",\n    "Datastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things(\'teco.edu/Test-2\')/Datastreams",\n    "MultiDatastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things(\'teco.edu/Test-2\')/MultiDatastreams",\n    "@iot.id" : "teco.edu/Test-2",\n    "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Things(\'teco.edu/Test-2\')"\n  }, {\n    "name" : "Teco test",\n    "description" : "Teco test",\n    "Locations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things(\'teco.edu/Test-3\')/Locations",\n    "HistoricalLocations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things(\'teco.edu/Test-3\')/HistoricalLocations",\n    "Datastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things(\'teco.edu/Test-3\')/Datastreams",\n    "MultiDatastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things(\'teco.edu/Test-3\')/MultiDatastreams",\n    "@iot.id" : "teco.edu/Test-3",\n    "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Things(\'teco.edu/Test-3\')"\n  }, {\n    "name" : "Teco test",\n    "description" : "Teco test",\n    "Locations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things(\'teco.edu/Test-4\')/Locations",\n    "HistoricalLocations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things(\'teco.edu/Test-4\')/HistoricalLocations",\n    "Datastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things(\'teco.edu/Test-4\')/Datastreams",\n    "MultiDatastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things(\'teco.edu/Test-4\')/MultiDatastreams",\n    "@iot.id" : "teco.edu/Test-4",\n    "@iot.selfLink" : "http://localhost:8080/FROST-Server/v1.0/Things(\'teco.edu/Test-4\')"\n  }, {\n    "name" : "Teco test",\n    "description" : "Teco test",\n    "Locations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things(\'teco.edu/Test-5\')/Locations",\n    "HistoricalLocations@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things(\'teco.edu/Test-5\')/HistoricalLocations",\n    "Datastreams@iot.navigationLink" : "http://localhost:8080/FROST-Server/v1.0/Things(\'teco.edu/Te ...

# %%
sensors = idDF.collect()
for sensor in sensors:
    print(DfToSensorthingsPost(sensor))
    #self link
# Out:
# Fail:Failed to store data.
# Fail:Failed to store data.
# Fail:Failed to store data.
# Fail:Failed to store data.
# Fail:Failed to store data.
# Fail:Failed to store data.
# Fail:Failed to store data.
# Fail:Failed to store data.
# Fail:Failed to store data.
# Fail:Failed to store data.
# Fail:Failed to store data.
# Fail:Failed to store data.
# Fail:Failed to store data.
# Fail:Failed to store data.
# Fail:Failed to store data.
# Fail:Failed to store data.
# Fail:Failed to store data.
# Fail:Failed to store data.
# Fail:Failed to store data.
# Fail:Failed to store data.
# Fail:Failed to store data.
# Fail:Failed to store data.
# Fail:Failed to store data.
# Fail:Failed to store data.
# Fail:Failed to store data.
# Fail:Failed to store data.
# Fail:Failed to store data.
# Fail:Failed to store data.
# Fail:Failed to store data.
# Fail:Failed to store data.
# Fail:Failed to store data.
# Fail:Failed to store data.
# Fail:Failed to store data.

# %%
import requests

# %%
dataFileDF = ss.read.parquet(inputDir)
outDir = "./outDir/outAllAll5/"
print(csv.__file__)
# Out:
# /gpfs/software/x86_64/anaconda/envs/jupyterhub/lib/python3.5/csv.py

# %%
validFileNames = [inputDir+f for f in os.listdir(inputDir) if ('.' not in f) and ("part-" in f)]
validFileNames
# Out:
# ['./outDir/outAll4/part-00000']

# %%
for aFile in validFileNames:
    with open(aFile) as csvfile:
        for row in csvfile:
            k = row[1:9]
            v = row[13:-3]+'\n'
            vNew = re.sub(';','\n',v)
            outFile = open(outDir+k,"w")
            outFile.write(vNew)
            outFile.close()

# %%
row = csvfile.readline()

# %%
k = row[1:9]
v = row[13:-3].split(";")
k,v
# Out:
# ('20150128',
#  ['IKNIGSBR2,2015-01-28,06:17:00,48.256,10.887,0.5',
#   'IKNIGSBR2,2015-01-28,06:48:00,48.256,10.887,0.5',
#   'IKNIGSBR2,2015-01-28,07:25:00,48.256,10.887,0.4'])

# %%
with open(inputFile) as csvfile:
    for row in csvfile:
        k = row[1:9]
        v = row[13:-3]+'\n'
        vNew = re.sub(';','\n',v)
        outFile = open(outDir+k,"w")
        outFile.write(vNew)
        outFile.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-a2a9bfb121ce> in <module>()
#       3         k = row[1:9]
#       4         v = row[13:-3]+'\n'
# ----> 5         vNew = re.sub(';','\n',v)
#       6         outFile = open(outDir+k,"w")
#       7         outFile.write(vNew)
#
# NameError: name 're' is not defined

# %%
import re

print(vNew)
# Out:
# IKNIGSBA5,2015-01-29,11:14:00,48.950,8.667,3.4
# IKNIGSBA8,2015-01-29,17:39:00,48.965,8.646,6.3
# IKNIGSBA8,2015-01-29,18:36:00,48.965,8.646,6.1
# IKNIGSBA8,2015-01-29,18:59:00,48.965,8.646,5.8
# IKNIGSBA8,2015-01-29,19:40:00,48.965,8.646,5.4

# %%
outFile = open(outDir+k,"w")
outFile.write(vNew)
outFile.close()

# %%
with open(inputFile,'rb') as csvfile:
    reader = csv.Reader(csvfile)
    row = reader.__next__()
row
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-ca7f3b917576> in <module>()
#       1 with open(inputFile,'rb') as csvfile:
# ----> 2     reader = csv.Reader(csvfile)
#       3     row = reader.__next__()
#       4 row
#
# AttributeError: module 'csv' has no attribute 'Reader'

# %%
row
# Out:
# OrderedDict([('(20150128', '(20150129'),
#              (' \'{{"id": "IKNIGSBR2"', ' \'{{"id": "IKNIGSBA5"'),
#              (' "date": "2015-01-28"', ' "date": "2015-01-29"'),
#              (' "time": "06:17:00"', ' "time": "11:14:00"'),
#              (' "latitude": "48.256"', ' "latitude": "48.965"'),
#              (' "longitude": "10.887"', ' "longitude": "8.646"'),
#              (' "airtemperature": "0.5"}', ' "airtemperature": "4.2"}'),
#              ('{"id": "IKNIGSBA9"', '{"id": "IKNIGSBO2"'),
#              (' "time": "04:44:00"', ' "time": "17:39:00"'),
#              (' "latitude": "48.961"', ' "latitude": "52.136"'),
#              (' "longitude": "8.577"', ' "longitude": "11.770"'),
#              (' "airtemperature": "2.2"}', ' "airtemperature": "2.6"}'),
#              (' "time": "05:24:00"', ' "time": "18:36:00"'),
#              (' "airtemperature": "2.3"}', ' "airtemperature": "2.0"}'),
#              (' "time": "06:24:00"', ' "time": "10:06:00"'),
#              (' "time": "07:44:00"', ' "time": "20:59:00"'),
#              (' "airtemperature": "2.1"}', ' "airtemperature": "1.9"}'),
#              (' "time": "08:24:00"', ' "time": "21:40:00"'),
#              ('{"id": "IKNIGSEG2"', '{"id": "IKNIGSBA6"'),
#              (' "time": "06:21:00"', ' "time": "22:20:00"'),
#              (' "latitude": "47.928"', ' "latitude": "48.964"'),
#              (' "longitude": "9.419"', ' "longitude": "8.616"'),
#              (' "airtemperature": "-1.2"}', ' "airtemperature": "2.1"}'),
#              ('{"id": "IKNIGSBR2"', '{"id": "IKNIGSBA8"'),
#              (' "time": "13:01:00"', ' "time": "23:00:00"'),
#              (' "airtemperature": "1.9"}', ' "airtemperature": "1.5"}'),
#              (' "time": "07:03:00"', ' "time": "23:40:00"'),
#              (' "airtemperature": "-0.8"}', ' "airtemperature": "2.4"}'),
#              (' "time": "07:36:00"', ' "time": "00:16:00"'),
#              (' "airtemperature": "-0.7"}', ' "airtemperature": "2.1"}'),
#              ('{"id": "IKNIGSBA6"', '{"id": "IKNIGSBA8"'),
#              (' "time": "23:07:00"', ' "time": "08:04:00"'),
#              (' "latitude": "48.964"', ' "latitude": "48.965"'),
#              (' "longitude": "8.616"', ' "longitude": "8.646"'),
#              (' "airtemperature": "5.5"}', ' "airtemperature": "3.0"}'),
#              (' "time": "11:45:00"', ' "time": "00:46:00"'),
#              (' "airtemperature": "5.1"}', ' "airtemperature": "3.5"}'),
#              (' "time": "12:25:00"', ' "time": "18:59:00"'),
#              (' "airtemperature": "5.7"}', ' "airtemperature": "2.4"}'),
#              (' "time": "13:05:00"', ' "time": "19:40:00"'),
#              (' "airtemperature": "5.8"}', ' "airtemperature": "2.6"}'),
#              (' "time": "13:45:00"', ' "time": "20:44:00"'),
#              (' "time": "06:48:00"', ' "time": "21:24:00"'),
#              (' "time": "07:25:00"', ' "time": "22:05:00"'),
#              (' "airtemperature": "0.4"}', ' "airtemperature": "4.4"}'),
#              (' "time": "13:42:00"', ' "time": "22:45:00"'),
#              (' "time": "14:22:00"', ' "time": "18:45:00"'),
#              (' "airtemperature": "2.0"}', ' "airtemperature": "1.2"}'),
#              (' "time": "08:22:00"', ' "time": "23:25:00"'),
#              (' "time": "11:28:00"', ' "time": "19:26:00"'),
#              (' "airtemperature": "0.6"}', ' "airtemperature": "1.3"}'),
#              (' "time": "03:55:00"', ' "time": "19:59:00"'),
#              (' "airtemperature": "-0.6"}', ' "airtemperature": "2.1"}'),
#              (' "time": "04:45:00"', ' "time": "09:54:00"'),
#              (' "time": "12:21:00"', ' "time": "00:16:00"'),
#              (' "time": "05:31:00"', ' "time": "00:39:00"'),
#              (' "airtemperature": "-0.9"}', ' "airtemperature": "3.1"}'),
#              (' "time": "15:03:00"', ' "time": "01:20:00"'),
#              (' "time": "15:43:00"', ' "time": "02:00:00"'),
#              (' "time": "16:23:00"', ' "time": "02:41:00"'),
#              (' "time": "17:04:00"', ' "time": "03:21:00"'),
#              (' "airtemperature": "1.7"}', ' "airtemperature": "2.0"}'),
#              (' "time": "12:09:00"', ' "time": "14:57:00"'),
#              (' "airtemperature": "1.3"}', ' "airtemperature": "5.5"}'),
#              ('{"id": "IKNIGSBO2"', '{"id": "IKNIGSBA8"'),
#              (' "time": "16:54:00"', ' "time": "15:27:00"'),
#              (' "latitude": "52.136"', ' "latitude": "48.965"'),
#              (' "longitude": "11.770"', ' "longitude": "8.646"'),
#              (' "airtemperature": "5.4"}', ' "airtemperature": "2.4"}'),
#              (' "time": "17:34:00"', ' "time": "15:57:00"'),
#              (' "airtemperature": "5.2"}', ' "airtemperature": "3.6"}'),
#              (' "time": "16:03:00"', ' "time": "16:28:00"'),
#              (' "airtemperature": "5.9"}', ' "airtemperature": "5.5"}'),
#              (' "time": "18:15:00"', ' "time": "17:08:00"'),
#              ('{"id": "IKNIGSBA8"', '{"id": "IKNIGSBA6"'),
#              (' "time": "21:45:00"', ' "time": "17:38:00"'),
#              (' "latitude": "48.965"', ' "latitude": "48.964"'),
#              (' "longitude": "8.646"', ' "longitude": "8.616"'),
#              (' "airtemperature": "6.4"}', ' "airtemperature": "5.1"}'),
#              (' "time": "16:43:00"', ' "time": "18:19:00"'),
#              (' "time": "18:55:00"', ' "time": "18:59:00"'),
#              (' "time": "19:36:00"', ' "time": "19:29:00"'),
#              (' "airtemperature": "4.9"}', ' "airtemperature": "3.0"}'),
#              (' "time": "18:04:00"', ' "time": "00:16:00"'),
#              (' "time": "20:26:00"', ' "time": "09:14:00"'),
#              (' "airtemperature": "4.6"}', ' "airtemperature": "3.1"}'),
#              (' "time": "18:44:00"', ' "time": "12:05:00"'),
#              (' "time": "20:57:00"', ' "time": "17:09:00"'),
#              (' "airtemperature": "4.4"}', ' "airtemperature": "6.2"}'),
#              (' "time": "19:25:00"', ' "time": "12:06:00"'),
#              (' "airtemperature": "5.6"}', ' "airtemperature": "6.1"}'),
#              (' "time": "21:37:00"', ' "time": "05:22:00"'),
#              (' "airtemperature": "4.3"}', ' "airtemperature": "6.7"}'),
#              (' "time": "22:08:00"', ' "time": "13:06:00"'),
#              (' "time": "23:08:00"', ' "time": "13:28:00"'),
#              (' "airtemperature": "4.0"}', ' "airtemperature": "2.5"}'),
#              (' "time": "23:46:00"', ' "time": "08:44:00"'),
#              (' "airtemperature": "3.7"}', ' "airtemperature": "6.3"}'),
#              (' "time": "23:05:00"', ' "time": "14:36:00"'),
#              (' "airtemperature": "6.1"}', ' "airtemperature": "6.3"}'),
#              (' "time": "23:45:00"', ' "time": "01:48:00"'),
#              (' "time": "18:26:00"', ' "time": "02:18:00"'),
#              (' "time": "19:06:00"', ' "time": "02:56:00"'),
#              (' "time": "19:46:00"', ' "time": "08:34:00"'),
#              (' "time": "00:23:00"', ' "time": "03:59:00"'),
#              (' "airtemperature": "-0.1"}', ' "airtemperature": "3.0"}'),
#              (' "time": "21:07:00"', ' "time": "04:39:00"'),
#              (' "airtemperature": "5.0"}', ' "airtemperature": "2.7"}'),
#              (' "time": "22:07:00"', ' "time": "19:02:00"'),
#              (' "time": "22:37:00"', ' "time": "05:05:00"'),
#              (' "airtemperature": "5.3"}', ' "airtemperature": "2.2"}'),
#              (' "time": "09:39:00"', ' "time": "07:23:00"'),
#              (' "airtemperature": "4.5"}', ' "airtemperature": "2.1"}'),
#              (' "time": "01:33:00"', ' "time": "09:24:00"'),
#              (' "airtemperature": "0.9"}', ' "airtemperature": "3.4"}'),
#              (' "time": "05:16:00"', ' "time": "04:02:00"'),
#              (' "airtemperature": "0.8"}', ' "airtemperature": "2.0"}'),
#              (' "time": "05:55:00"', ' "time": "03:53:00"'),
#              (' "time": "15:06:00"', ' "time": "04:42:00"'),
#              (' "airtemperature": "6.0"}', ' "airtemperature": "2.0"}'),
#              (' "time": "15:46:00"', ' "time": "00:26:00"'),
#              (' "time": "00:03:00"', ' "time": "05:23:00"'),
#              (' "airtemperature": "1.1"}', ' "airtemperature": "4.2"}'),
#              (' "time": "00:43:00"', ' "time": "08:05:00"'),
#              (' "airtemperature": "1.2"}', ' "airtemperature": "1.8"}'),
#              (' "time": "01:24:00"', ' "time": "01:06:00"'),
#              (' "time": "02:04:00"', ' "time": "01:56:00"'),
#              (' "airtemperature": "1.0"}', ' "airtemperature": "3.5"}'),
#              (' "time": "20:46:00"', ' "time": "07:24:00"'),
#              (' "time": "01:23:00"', ' "time": "02:46:00"'),
#              (' "time": "02:03:00"', ' "time": "08:45:00"'),
#              (' "time": "02:43:00"', ' "time": "09:26:00"'),
#              (' "time": "03:23:00"', ' "time": "10:06:00"'),
#              (' "time": "04:03:00"', ' "time": "10:47:00"'),
#              (' "time": "09:04:00"', ' "time": "03:26:00"'),
#              (' "airtemperature": "2.5"}', ' "airtemperature": "3.3"}'),
#              (' "time": "21:36:00"', ' "time": "11:16:00"'),
#              (' "time": "09:45:00"', ' "time": "11:56:00"'),
#              (' "airtemperature": "2.9"}', ' "airtemperature": "3.8"}'),
#              (' "time": "10:25:00"', ' "time": "05:53:00"'),
#              (' "airtemperature": "3.6"}', ' "airtemperature": "0.7"}'),
#              (' "time": "11:05:00"', ' "time": "19:43:00"'),
#              (' "airtemperature": "4.4"}}\')', ' "airtemperature": "2.1"}'),
#              (None,
#               ['{"id": "IKNIGSBO2"',
#                ' "date": "2015-01-29"',
#                ' "time": "20:23:00"',
#                ' "latitude": "52.136"',
#                ' "longitude": "11.770"',
#                ' "airtemperature": "1.7"}',
#                '{"id": "IKNIGSBA8"',
#                ' "date": "2015-01-29"',
#                ' "time": "05:46:00"',
#                ' "latitude": "48.965"',
#                ' "longitude": "8.646"',
#                ' "airtemperature": "2.2"}',
#                '{"id": "IKNIGSBO2"',
#                ' "date": "2015-01-29"',
#                ' "time": "21:04:00"',
#                ' "latitude": "52.136"',
#                ' "longitude": "11.770"',
#                ' "airtemperature": "1.4"}',
#                '{"id": "IKNIGSBA8"',
#                ' "date": "2015-01-29"',
#                ' "time": "06:36:00"',
#                ' "latitude": "48.965"',
#                ' "longitude": "8.646"',
#                ' "airtemperature": "2.0"}',
#                '{"id": "IKNIGSBO2"',
#                ' "date": "2015-01-29"',
#                ' "time": "21:44:00"',
#                ' "latitude": "52.136"',
#                ' "longitude": "11.770"',
#                ' "airtemperature": "1.6"}',
#                '{"id": "IKNIGSBO2"',
#                ' "date": "2015-01-29"',
#                ' "time": "22:25:00"',
#                ' "latitude": "52.136"',
#                ' "longitude": "11.770"',
#                ' "airtemperature": "2.0"}',
#                '{"id": "IKNIGSBO2"',
#                ' "date": "2015-01-29"',
#                ' "time": "23:05:00"',
#                ' "latitude": "52.136"',
#                ' "longitude": "11.770"',
#                ' "airtemperature": "1.7"}',
#                '{"id": "IKNIGSBO2"',
#                ' "date": "2015-01-29"',
#                ' "time": "23:45:00"',
#                ' "latitude": "52.136"',
#                ' "longitude": "11.770"',
#                ' "airtemperature": "1.7"}',
#                '{"id": "IKNIGSBA8"',
#                ' "date": "2015-01-29"',
#                ' "time": "07:26:00"',
#                ' "latitude": "48.965"',
#                ' "longitude": "8.646"',
#                ' "airtemperature": "2.2"}',
#                '{"id": "IKNIGSBA8"',
#                ' "date": "2015-01-29"',
#                ' "time": "08:16:00"',
#                ' "latitude": "48.965"',
#                ' "longitude": "8.646"',
#                ' "airtemperature": "2.4"}',
#                '{"id": "IKNIGSBA8"',
#                ' "date": "2015-01-29"',
#                ' "time": "08:56:00"',
#                ' "latitude": "48.965"',
#                ' "longitude": "8.646"',
#                ' "airtemperature": "2.9"}',
#                '{"id": "IKNIGSBA5"',
#                ' "date": "2015-01-29"',
#                ' "time": "06:33:00"',
#                ' "latitude": "48.950"',
#                ' "longitude": "8.667"',
#                ' "airtemperature": "0.7"}',
#                '{"id": "IKNIGSBA5"',
#                ' "date": "2015-01-29"',
#                ' "time": "07:54:00"',
#                ' "latitude": "48.950"',
#                ' "longitude": "8.667"',
#                ' "airtemperature": "0.4"}',
#                '{"id": "IKNIGSBA8"',
#                ' "date": "2015-01-29"',
#                ' "time": "09:27:00"',
#                ' "latitude": "48.965"',
#                ' "longitude": "8.646"',
#                ' "airtemperature": "6.0"}',
#                '{"id": "IKNIGSBA8"',
#                ' "date": "2015-01-29"',
#                ' "time": "10:36:00"',
#                ' "latitude": "48.965"',
#                ' "longitude": "8.646"',
#                ' "airtemperature": "7.2"}',
#                '{"id": "IKNIGSBA8"',
#                ' "date": "2015-01-29"',
#                ' "time": "10:57:00"',
#                ' "latitude": "48.965"',
#                ' "longitude": "8.646"',
#                ' "airtemperature": "6.3"}}\')'])])

# %%
all=string.maketrans('','')
nodigs=all.translate(all, string.digits)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-ba0f531ab614> in <module>()
# ----> 1 all=string.maketrans('','')
#       2 nodigs=all.translate(all, string.digits)
#
# AttributeError: module 'string' has no attribute 'maketrans'

# %%
class Del:
  def __init__(self, keep=string.digits):
    self.comp = dict((ord(c),c) for c in keep)
  def __getitem__(self, k):
    return self.comp.get(k)

# %%
with open(inputPath) as csvfile:
    reader = csv.DictReader(csvfile)
    for i in range(10):
        row = reader.__next__()
        
        lineID = row['id']
        timeStamp = row['time'].translate(Del())
        print(lineID, timeStamp)
# Out:
# I17SAINT2 2016081912000002
# I17SAINT2 2016081812000002
# I17SAINT2 2016081712000002
# I17SAINT2 2016081612000002
# I17SAINT2 2016081512000002
# I17SAINT2 2016081412000002
# I17SAINT2 2016081312000002
# I17SAINT2 2016081212000002
# I17SAINT2 2016081112000002
# I17SAINT2 2016081012000002
